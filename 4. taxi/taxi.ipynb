# %% [markdown]
# #  Прогнозирование количества заказов такси на следующий час

# %% [markdown]
# Компания, занимающаяся пассажирскими перевозками, собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час
#
# ---
#
# **Цель исследования:** построить модель, которая будет прогнозировать количество заказов в определённый отрезок времени
#
# ---
#
# **План выполнения работы:**
#
# - загрузка и предварительное изучение данных
# - предобработка данных
# - исследовательский анализ данных
# - создание новых признаков и подготовка данных к обучению
# - обучение моделей
# - выбор лучшей модели
# - тестирование итоговой модели
#
# Каждый шаг исследования содержит промежуточный вывод. В конце исследования даётся общий подробный вывод
#
# ---
#
# - количество заказов находится в столбце `num_orders`, а дата и время — в столбце `datetime`
# - размер тестовой выборки должен быть равен 10% от исходных данных
# - итоговая метрика RMSE должна быть не больше 48
#
# ---

# %%
# установка широкоформатного jupyter

from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# импорт библиотек

import os
import copy
from IPython.display import display

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from statsmodels.tsa.seasonal import seasonal_decompose

from sklearn.model_selection import RandomizedSearchCV, ParameterGrid, train_test_split, TimeSeriesSplit, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_squared_error

# %%
# константы

RANDOM_STATE = 42
TEST_SIZE = 0.10
FIGSIZE = (15, 5)

TARGET = 'num_orders'
PATH = 'D:\\datasets\\taxi.csv'

# %% [markdown]
# ---

# %%
def get_info(data):
    
    """
    Функция get_info выводит на экран пять случайных строк таблицы и общую информацию, полученную с помощью info()

    Аргументы:
    data (DataFrame): датафрейм

    """
    
    print('Пять случайных строк таблицы:')
    display(data.sample(5))
    print(' ')
    print('Общая информация о таблице:')
    print(' ')
    print(data.info())

# %%
def lineplot(data):
    
    """
    Функция lineplot строит линейный график для визуализации временного ряда
    
    Аргументы:
    data (DataFrame) : датафрейм
    
    """
    
    sns.set(style='darkgrid')
    
    plt.figure(figsize=FIGSIZE)
    sns.lineplot(data=data, x='datetime', y='num_orders', color='#f0c188')
    
    plt.title('График количества заказов по времени', fontsize=16)
    plt.xlabel('Дата и время')
    plt.ylabel('Количество заказов')
    
    plt.show()

# %%
def rolling_mean_plot(data):
    
    """
    Функция rolling_mean_plot создаёт график скользящего среднего
    
    Аргументы:
    data (DataFrame) : датафрейм
    
    """
    
    sns.set(style='darkgrid')

    plt.figure(figsize=FIGSIZE)
    sns.lineplot(data=data, x='datetime', y='num_orders', color='#518b94')

    plt.title('Скользящее среднее', fontsize=16)
    plt.xlabel('Месяц', fontsize=12)
    plt.ylabel('Среднее количество заказов', fontsize=12)

    plt.show()

# %%
def seasonal_decompose_plots(decomposed_data):
    
    """
    Функция seasonal_decompose_plots раскладывает временной ряд на три составляющие:
    тренд, сезонность и остаток; для каждой составляющей строит линейный график
    
    Аргументы:
    decomposed_data (DecomposeResult) : объект структуры DecomposeResult
    
    """
    
    sns.set(style="darkgrid")

    plt.figure(figsize=(12.5, 12))

    plt.subplot(3, 1, 1)
    decomposed_data.trend.plot(ax=plt.gca(), color="#51947c")
    plt.title('Тренд', fontsize=16)
    plt.xlabel('Месяц')
    plt.ylabel('Количество заказов')

    plt.subplot(3, 1, 2)
    decomposed_data.seasonal.plot(ax=plt.gca(), color="#518b94")
    plt.title('Сезонность', fontsize=16)
    plt.xlabel('Месяц')
    plt.ylabel('Количество заказов')

    plt.subplot(3, 1, 3)
    decomposed_data.resid.plot(ax=plt.gca(), color="#516a94")
    plt.title('Остатки', fontsize=16)
    plt.xlabel('Месяц')
    plt.ylabel('Количество заказов')

    plt.tight_layout()

    plt.show()

# %%
def make_features(data, max_lag, rolling_mean_size):
    
    """
    Функция make_features создаёт и присваивает исходному датафрейму три новых признака:
    3 календарных признака, «отстающие значения» и скользящее среднее
    
    Аргуменрты:
    data (DataFrame) : датафрейм
    max_lag (int) : максимальный размер отставания
    rolling_mean_size (int) : ширина окна
    
    """
    
    # календарные признаки
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    
    # «отстающие значения»
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    # скользящее среднее   
    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()

# %%
def split(data, target):
    
    """
    Функция split делит исходные данные на тренировочную и тестовую выборки
    
    Аргументы:
    data (DataFrame) : датафрейм
    target (str) : название столбца с целевым признаком
    
    """
    
    X = data.drop(columns=target, axis=1)
    y = data[target]
    
    X_train, X_test, y_train, y_test = train_test_split(
        X,
        y,
        shuffle=False,
        test_size=TEST_SIZE,
        random_state=RANDOM_STATE
    )
    
    return X_train, X_test, y_train, y_test

# %%
def train_test_size(X_train, X_test, y_train, y_test):
                                    
    """
    Функция train_test_size выводит на экран размерность разделённых на выборки данных
    
    Аргументы:
    X_train (DataFrame) : входные признаки тренировочной выборки
    X_test (DataFrame) : входные признаки тестовой выборки
    y_train (Series) : целевой признак тренировочной выборки
    y_test (Series) : целевой признак тестовой выборки
    
    """

    print('Тренировочная выборка')
    print(f'Размерность матрицы со входными признаками: {X_train.shape}')
    print(f'Размерность матрицы с целевым признаком: {y_train.shape}')
    print(' ')
    print('Тестовая выборка')
    print(f'Размерность матрицы со входными признаками: {X_test.shape}')
    print(f'Размерность матрицы с целевым признаком: {y_test.shape}')

# %% [markdown]
# ---
#
# <div style="background-color: rgba(255, 255, 255, 0.8); padding: 20px; font-size: 25px; color: rgba(28, 28, 28, 1);">
# Загрузка и предварительное изучение данных
# </div>
#
# ---

# %%
# загрузка данных

if os.path.exists(PATH):
    filename = os.path.basename(PATH)
    print(f'Файл {filename} успешно загружен!')
    taxi = pd.read_csv(PATH, parse_dates=[0], index_col=[0])
else:
    print(f'Упс, что-то пошло не так при загрузке файла {os.path.basename(PATH)}!')
# Out:
# Файл taxi.csv успешно загружен!

# %%
# изучим общую информацию о таблице

get_info(taxi)
# Out:
# Пять случайных строк таблицы:
#                      num_orders
# datetime
# 2018-05-25 05:50:00           0
# 2018-07-19 11:40:00          16
# 2018-06-29 15:20:00          10
# 2018-07-17 09:40:00          10
# 2018-06-21 18:40:00          11
#
# Общая информация о таблице:
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB
# None

# %% [markdown]
# - загруженая таблица содержит 26496 строк и 1 столбец
# - названия столбцов не требуют переименования
# - столбец `datetime` корректно назначен индексом
# - тип данных в столбце `num_orders` определён верно
# - в таблице нет пропусков

# %% [markdown]
# <div style="border: 1px solid rgba(0, 0, 0, 0.2); border-radius: 10px; background-color: rgba(255, 255, 255, 0.8); padding: 10px;">
#
# Таблица успешно загружена, данные полностью соответствуют описанию. Типы данных и названия столбцов не требуют изменений, пропусков в таблице не обнаружено
#
# </div>

# %% [markdown]
# ---
#
# <div style="background-color: rgba(255, 255, 255, 0.8); padding: 20px; font-size: 25px; color: rgba(28, 28, 28, 1);">
# Предобработка данных
# </div>
#
# ---

# %%
# отсортируем таблицу по значению индекса

taxi = taxi.sort_index()

# %%
# проверим, расположены ли данные в хронологическом порядке

if taxi.index.is_monotonic_increasing == True:
    print('Данные о времени расположены в хронологическом порядке!')
else:
    print('Данные о времени расположены НЕ в хронологическом порядке')
# Out:
# Данные о времени расположены в хронологическом порядке!

# %%
# выполним ресемплирование по одному часу, суммировав количество заказов по этому интервалу

taxi = taxi.resample('1H').sum()

# %%
# проверим результат

get_info(taxi)
# Out:
# Пять случайных строк таблицы:
#                      num_orders
# datetime
# 2018-07-25 23:00:00         138
# 2018-05-25 08:00:00          90
# 2018-03-16 19:00:00          65
# 2018-07-20 09:00:00         137
# 2018-08-23 08:00:00         113
#
# Общая информация о таблице:
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4416 entries, 2018-03-01 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  4416 non-null   int64
# dtypes: int64(1)
# memory usage: 69.0 KB
# None

# %% [markdown]
# <div style="border: 1px solid rgba(0, 0, 0, 0.2); border-radius: 10px; background-color: rgba(255, 255, 255, 0.8); padding: 10px;">
#
# Дата и время определены индексом и расположены в хронологическом порядке. Временной интервал был изменён с 10 минут на 1 час, а по этому интервалу суммировано количество заказов
#
# </div>

# %% [markdown]
# ---
#
# <div style="background-color: rgba(255, 255, 255, 0.8); padding: 20px; font-size: 25px; color: rgba(28, 28, 28, 1);">
# Исследовательский анализ данных
# </div>
#
# ---

# %%
# выведем на экран минимальное и максимальное значения даты и времени в таблице

print(f'Минимальное значение даты и времени: {taxi.index.min()}')
print(f'Максимальное значение даты и времени: {taxi.index.max()}')
# Out:
# Минимальное значение даты и времени: 2018-03-01 00:00:00
# Максимальное значение даты и времени: 2018-08-31 23:00:00

# %% [markdown]
# В нашем распоряжении находятся данные в промежутке от полуночи 1 марта 2018 года до одиннадцати вечера 31 августа 2018 года. Построим график, отображающий почасовое количество заказов такси

# %%
# построим линейный график

lineplot(taxi)

# %% [markdown]
# До начала августа почасовое количество заказов в сервисе обычно не превышало 200-300 штук. В начале августа количество заказов резко возросло. Неизвестно, с чем это может быть связано — может, сервис запустил новую акцию или успешную рекламу, а может, спрос на такси растёт в конце августа каждого года, то есть, регулярно
#
# Чтобы сгладить данные, вычислим *скользящее среднее*. Оно покажет значения, которые меньше всего подвержены колебаниям — то есть, среднее арифметическое

# %%
# создадим переменную со скользящим средним

rolling_mean = taxi.rolling(100).mean()

# %%
# проверим результат

display(rolling_mean.head(), rolling_mean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4416 entries, 2018-03-01 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  4317 non-null   float64
# dtypes: float64(1)
# memory usage: 69.0 KB
#                      num_orders
# datetime
# 2018-03-01 00:00:00         NaN
# 2018-03-01 01:00:00         NaN
# 2018-03-01 02:00:00         NaN
# 2018-03-01 03:00:00         NaN
# 2018-03-01 04:00:00         NaN
# None

# %%
# удалим пропуски

rolling_mean = rolling_mean.dropna()

# %%
# проверим результат

get_info(rolling_mean)
# Out:
# Пять случайных строк таблицы:
#                      num_orders
# datetime
# 2018-08-11 08:00:00      110.71
# 2018-04-07 09:00:00       55.95
# 2018-04-27 10:00:00       66.98
# 2018-07-19 20:00:00       98.79
# 2018-03-23 22:00:00       57.69
#
# Общая информация о таблице:
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4317 entries, 2018-03-05 03:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  4317 non-null   float64
# dtypes: float64(1)
# memory usage: 67.5 KB
# None

# %%
# построим график скользящего среднего

rolling_mean_plot(rolling_mean)

# %% [markdown]
# Снова видим плавный рост количества заказов со временем, пик в текущих данных приходится на последний месяц. Чтобы лучше понимать временной ряд, разберём тренды и сезонность

# %%
# применим функцию seasonal_decompose

decomposed = seasonal_decompose(taxi)

# %%
# выведем графики на экран

seasonal_decompose_plots(decomposed)

# %% [markdown]
# **Тренд** — это плавное изменение среднего значения ряда без повторяющихся закономерностей. Снова видим, как количество заказов плавно стремится вверх
#
# **Сезонность** — циклично повторяющиеся закономерности во временном ряду. В нашем случае у сезонности период меньше недели, его можно исследователь и поближе
#
# **Остатки** необъяснимы. Это компонента, которая не объясняется трендом и сезонностью, это шум. Здесь они колеблятся в районе нуля, за исключением августовских выбросов

# %%
# построим график для суточной сезонности

plt.figure(figsize=FIGSIZE)
decomposed.seasonal['2018-03-01':'2018-03-01'].plot(ax=plt.gca())

plt.title('Суточная сезонность')
plt.show()

# %% [markdown]
# Около полуночи количество заказов является пиковым, затем плавно снижается к 6 утра. Это объяснимо, в полночь общественный транспорт уже не работает, а к 6 утра все, как правило, уже спят. Ещё один пик — примерно в 9 утра, как раз когда людям нужно спешить на работу. К 12 часам дня количество заказов падает снова, в 16-17 часов — снова пик, в 18 — снижение, а затем плавный рост, переходящий в полночь

# %%
# построим график для дневной сезонности

decomposed_by_day = seasonal_decompose(taxi.resample('D').sum())

plt.figure(figsize=FIGSIZE)
plt.title('Дневная сезонность')
decomposed_by_day.seasonal['2018-08-01':'2018-08-31'].plot(ax=plt.gca())
plt.show()

# %% [markdown]
# Подтверждается догадка о том, что сезонность в этих данных имеет период чуть меньше недели. Так, количество заказов постепенно растёт с начала недели до её середины, затем резко падает и снова резко растёт на выходных

# %% [markdown]
# ---
#
# <div style="background-color: rgba(255, 255, 255, 0.8); padding: 20px; font-size: 25px; color: rgba(28, 28, 28, 1);">
# Создание новых признаков. Подготовка данных к обучению
# </div>
#
# ---

# %% [markdown]
# В качестве новых признаков и на основании полученной с помощью графиков информации создадим: *календарные признаки*, такие как месяц, день месяца и день недели, *скользящее среднее*, которое в качестве признака задаёт общий тренд временного ряда и, наконец, *«отстающие значения»*

# %%
# применим функцию make_features

make_features(taxi, 52, 28)

# %%
# проверим результат

display(taxi.columns)
# Out:
# Index(['num_orders', 'month', 'day', 'dayofweek', 'lag_1', 'lag_2', 'lag_3',
#        'lag_4', 'lag_5', 'lag_6', 'lag_7', 'lag_8', 'lag_9', 'lag_10',
#        'lag_11', 'lag_12', 'lag_13', 'lag_14', 'lag_15', 'lag_16', 'lag_17',
#        'lag_18', 'lag_19', 'lag_20', 'lag_21', 'lag_22', 'lag_23', 'lag_24',
#        'lag_25', 'lag_26', 'lag_27', 'lag_28', 'lag_29', 'lag_30', 'lag_31',
#        'lag_32', 'lag_33', 'lag_34', 'lag_35', 'lag_36', 'lag_37', 'lag_38',
#        'lag_39', 'lag_40', 'lag_41', 'lag_42', 'lag_43', 'lag_44', 'lag_45',
#        'lag_46', 'lag_47', 'lag_48', 'lag_49', 'lag_50', 'lag_51', 'lag_52',
#        'rolling_mean'],
#       dtype='object')

# %%
# проверим результат

taxi.shape
# Out:
# (4416, 57)

# %% [markdown]
# ---

# %%
# разделим данные на тренировочную и тестовую выборки

train, test = train_test_split(taxi, shuffle=False, test_size=TEST_SIZE, random_state=RANDOM_STATE)

# %%
# удалим пропуски в тренировочной выборке

train = train.dropna()

# %%
# выделим входные и целевой признаки

X_train = train.drop(['num_orders'], axis=1)
y_train = train['num_orders']
X_test = test.drop(['num_orders'], axis=1)
y_test = test['num_orders']

# %%
# проверим результат

train_test_size(X_train, X_test, y_train, y_test)
# Out:
# Тренировочная выборка
# Размерность матрицы со входными признаками: (3922, 56)
# Размерность матрицы с целевым признаком: (3922,)
#
# Тестовая выборка
# Размерность матрицы со входными признаками: (442, 56)
# Размерность матрицы с целевым признаком: (442,)

# %%
# проверим корректность размера тестовой выборки

print(f'Размер тестовой выборки относительно изначального набора данных: {X_test.shape[0] / taxi.shape[0]}')
# Out:
# Размер тестовой выборки относительно изначального набора данных: 0.10009057971014493

# %% [markdown]
# <div style="border: 1px solid rgba(0, 0, 0, 0.2); border-radius: 10px; background-color: rgba(255, 255, 255, 0.8); padding: 10px;">
#
# Созданые новые столбцы-признаки: `month`, `day`, `dayofweek`, `rolling_mean`, а также столбцы, отображающие отстающие значения. Данные успешно разделены на тренировочную и тестовую выборки, исходное требование к размеру тестовой выборки (10% от начальных данных) соблюдено
#
# </div>

# %% [markdown]
# ---
#
# <div style="background-color: rgba(255, 255, 255, 0.8); padding: 20px; font-size: 25px; color: rgba(28, 28, 28, 1);">
# Обучение моделей
# </div>
#
# ---

# %% [markdown]
# ## `LinearRegression`

# %%
# инициализируем модель

model_1 = LinearRegression()

# %%
# обучим модель

model_1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# выполним предсказание на тренировочной выборке

y_train_pred_1 = model_1.predict(X_train)

# %%
# посчитаем метрику RMSE

rmse_train_1 = mean_squared_error(y_train, y_train_pred_1, squared=False)

# %%
# выведем результат на экран

print('RMSE на тренировочной выборке:', rmse_train_1)
# Out:
# RMSE на тренировочной выборке: 23.286511229736472

# %% [markdown]
# ## `DecisionTreeRegressor`

# %%
# инициализируем модель

model_2 = DecisionTreeRegressor()

# %%
# определим схему разделения временного ряда

tscv_2 = TimeSeriesSplit(n_splits=15)

# %%
# запишем гиперпараметры для модели

param_grid_2 = {
        'max_depth': range(1, 50),
        'min_samples_leaf': range(1, 50),
        'min_samples_split': range(2, 50)
}

# %%
# выполним кросс-валидацию

rs_2 = RandomizedSearchCV(model_2,
                          param_distributions=param_grid_2, 
                          n_jobs=-1, 
                          cv=tscv_2, 
                          verbose=False,
                          random_state=RANDOM_STATE)

rs_2.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=15, test_size=None),
#                    estimator=DecisionTreeRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': range(1, 50),
#                                         'min_samples_leaf': range(1, 50),
#                                         'min_samples_split': range(2, 50)},
#                    random_state=42, verbose=False)

# %%
# выполним предсказание на тренировочной выборке

y_train_pred_2 = rs_2.predict(X_train)

# %%
# посчитаем метрику RMSE

rmse_train_2 = mean_squared_error(y_train, y_train_pred_2, squared=False)

# %%
# выведем результат на экран

print('RMSE на тренировочной выборке:', rmse_train_2)
# Out:
# RMSE на тренировочной выборке: 21.59171393670548

# %% [markdown]
# ## `CatBoostRegressor`

# %%
# инициализируем модель

model_3 = CatBoostRegressor()

# %%
# определим схему разделения временного ряда

tscv_3 = TimeSeriesSplit(n_splits=5)

# %%
# запишем гиперпараметры для модели

param_grid_3 = {
    'iterations': [100, 500, 1000],
    'learning_rate': [0.01, 0.05, 0.1],
    'depth': [4, 6, 8],
    'l2_leaf_reg': [1, 3, 5],
    'random_strength': [0.1, 0.5, 1]
}

# %%
# выполним кросс-валидацию

rs_3 = RandomizedSearchCV(model_3, param_grid_3, cv=tscv_3, random_state=RANDOM_STATE)

rs_3.fit(X_train, y_train)
# Out:
# 0:	learn: 27.9753165	total: 139ms	remaining: 13.8s
# 1:	learn: 26.7403046	total: 141ms	remaining: 6.92s
# 2:	learn: 25.6803888	total: 142ms	remaining: 4.6s
# 3:	learn: 24.7551245	total: 143ms	remaining: 3.44s
# 4:	learn: 23.8828658	total: 144ms	remaining: 2.74s
# 5:	learn: 23.0853846	total: 145ms	remaining: 2.27s
# 6:	learn: 22.3776738	total: 146ms	remaining: 1.94s
# 7:	learn: 21.7624100	total: 147ms	remaining: 1.69s
# 8:	learn: 21.2403492	total: 148ms	remaining: 1.49s
# 9:	learn: 20.7656346	total: 149ms	remaining: 1.34s
# 10:	learn: 20.2735561	total: 150ms	remaining: 1.21s
# 11:	learn: 19.8187147	total: 151ms	remaining: 1.1s
# 12:	learn: 19.4487174	total: 151ms	remaining: 1.01s
# 13:	learn: 19.1382011	total: 152ms	remaining: 935ms
# 14:	learn: 18.8571659	total: 153ms	remaining: 868ms
# 15:	learn: 18.5642946	total: 154ms	remaining: 809ms
# 16:	learn: 18.3296429	total: 155ms	remaining: 757ms
# 17:	learn: 18.1068740	total: 156ms	remaining: 710ms
# 18:	learn: 17.8646626	total: 157ms	remaining: 667ms
# 19:	learn: 17.6535992	total: 157ms	remaining: 629ms
# 20:	learn: 17.4489691	total: 158ms	remaining: 595ms
# 21:	learn: 17.2742011	total: 159ms	remaining: 563ms
# 22:	learn: 17.0909828	total: 160ms	remaining: 534ms
# 23:	learn: 16.9417645	total: 160ms	remaining: 508ms
# 24:	learn: 16.8024460	total: 161ms	remaining: 483ms
# 25:	learn: 16.6674635	total: 162ms	remaining: 460ms
# 26:	learn: 16.5207952	total: 162ms	remaining: 439ms
# 27:	learn: 16.3848988	total: 163ms	remaining: 419ms
# 28:	learn: 16.2674628	total: 164ms	remaining: 401ms
# 29:	learn: 16.1580129	total: 165ms	remaining: 384ms
# 30:	learn: 16.0382113	total: 165ms	remaining: 368ms
# 31:	learn: 15.9426893	total: 166ms	remaining: 353ms
# 32:	learn: 15.8267408	total: 167ms	remaining: 338ms
# 33:	learn: 15.7093359	total: 167ms	remaining: 325ms
# 34:	learn: 15.5944650	total: 168ms	remaining: 312ms
# 35:	learn: 15.5348733	total: 169ms	remaining: 300ms
# 36:	learn: 15.4327481	total: 169ms	remaining: 289ms
# 37:	learn: 15.3233346	total: 170ms	remaining: 278ms
# 38:	learn: 15.2322209	total: 171ms	remaining: 267ms
# 39:	learn: 15.1275543	total: 171ms	remaining: 257ms
# 40:	learn: 15.0488039	total: 172ms	remaining: 248ms
# 41:	learn: 14.9601257	total: 173ms	remaining: 239ms
# 42:	learn: 14.8956870	total: 174ms	remaining: 230ms
# 43:	learn: 14.8285727	total: 174ms	remaining: 222ms
# 44:	learn: 14.7147150	total: 175ms	remaining: 214ms
# 45:	learn: 14.6563781	total: 175ms	remaining: 206ms
# 46:	learn: 14.5799994	total: 176ms	remaining: 199ms
# 47:	learn: 14.4856842	total: 177ms	remaining: 192ms
# 48:	learn: 14.4151800	total: 177ms	remaining: 185ms
# 49:	learn: 14.3627682	total: 178ms	remaining: 178ms
# 50:	learn: 14.3020114	total: 179ms	remaining: 172ms
# 51:	learn: 14.2006012	total: 179ms	remaining: 166ms
# 52:	learn: 14.1055657	total: 180ms	remaining: 160ms
# 53:	learn: 14.0466476	total: 181ms	remaining: 154ms
# 54:	learn: 13.9699274	total: 181ms	remaining: 148ms
# 55:	learn: 13.8880554	total: 182ms	remaining: 143ms
# 56:	learn: 13.8003383	total: 183ms	remaining: 138ms
# 57:	learn: 13.7322118	total: 183ms	remaining: 133ms
# 58:	learn: 13.7128560	total: 184ms	remaining: 128ms
# 59:	learn: 13.6405555	total: 185ms	remaining: 123ms
# 60:	learn: 13.5790999	total: 185ms	remaining: 119ms
# 61:	learn: 13.5409099	total: 186ms	remaining: 114ms
# 62:	learn: 13.4692913	total: 187ms	remaining: 110ms
# 63:	learn: 13.4108503	total: 188ms	remaining: 106ms
# 64:	learn: 13.3637478	total: 189ms	remaining: 102ms
# 65:	learn: 13.2859676	total: 189ms	remaining: 97.5ms
# 66:	learn: 13.2305851	total: 190ms	remaining: 93.6ms
# 67:	learn: 13.1983730	total: 191ms	remaining: 89.8ms
# 68:	learn: 13.1453044	total: 191ms	remaining: 86ms
# 69:	learn: 13.0735579	total: 192ms	remaining: 82.3ms
# 70:	learn: 13.0570997	total: 193ms	remaining: 78.7ms
# 71:	learn: 12.9896107	total: 193ms	remaining: 75.2ms
# 72:	learn: 12.9755603	total: 194ms	remaining: 71.8ms
# 73:	learn: 12.9291209	total: 195ms	remaining: 68.4ms
# 74:	learn: 12.8508863	total: 195ms	remaining: 65.2ms
# 75:	learn: 12.8112127	total: 196ms	remaining: 61.9ms
# 76:	learn: 12.7801366	total: 197ms	remaining: 58.8ms
# 77:	learn: 12.7669268	total: 197ms	remaining: 55.7ms
# 78:	learn: 12.7212909	total: 198ms	remaining: 52.7ms
# 79:	learn: 12.6641809	total: 199ms	remaining: 49.7ms
# 80:	learn: 12.6337183	total: 199ms	remaining: 46.8ms
# 81:	learn: 12.5768281	total: 200ms	remaining: 43.9ms
# 82:	learn: 12.5659763	total: 201ms	remaining: 41.1ms
# 83:	learn: 12.4835060	total: 201ms	remaining: 38.4ms
# 84:	learn: 12.4717105	total: 202ms	remaining: 35.7ms
# 85:	learn: 12.4313596	total: 203ms	remaining: 33ms
# 86:	learn: 12.4217570	total: 203ms	remaining: 30.4ms
# 87:	learn: 12.4086543	total: 204ms	remaining: 27.8ms
# 88:	learn: 12.3657569	total: 205ms	remaining: 25.3ms
# 89:	learn: 12.3090408	total: 205ms	remaining: 22.8ms
# 90:	learn: 12.2528929	total: 206ms	remaining: 20.4ms
# 91:	learn: 12.2205095	total: 207ms	remaining: 18ms
# 92:	learn: 12.2093175	total: 207ms	remaining: 15.6ms
# 93:	learn: 12.1241068	total: 208ms	remaining: 13.3ms
# 94:	learn: 12.0727136	total: 209ms	remaining: 11ms
# 95:	learn: 11.9996421	total: 209ms	remaining: 8.72ms
# 96:	learn: 11.9957337	total: 210ms	remaining: 6.5ms
# 97:	learn: 11.9873638	total: 211ms	remaining: 4.3ms
# 98:	learn: 11.9366742	total: 211ms	remaining: 2.13ms
# 99:	learn: 11.8784310	total: 212ms	remaining: 0us
# 0:	learn: 28.9827201	total: 1.12ms	remaining: 111ms
# 1:	learn: 27.7959683	total: 1.88ms	remaining: 92.1ms
# 2:	learn: 26.7067956	total: 2.65ms	remaining: 85.7ms
# 3:	learn: 25.7275628	total: 3.39ms	remaining: 81.4ms
# 4:	learn: 24.8976574	total: 4.16ms	remaining: 79ms
# 5:	learn: 24.1292474	total: 5.01ms	remaining: 78.6ms
# 6:	learn: 23.4629167	total: 5.86ms	remaining: 77.9ms
# 7:	learn: 22.8344105	total: 6.72ms	remaining: 77.3ms
# 8:	learn: 22.3289661	total: 7.55ms	remaining: 76.3ms
# 9:	learn: 21.8653410	total: 8.35ms	remaining: 75.1ms
# 10:	learn: 21.4362034	total: 9.15ms	remaining: 74ms
# 11:	learn: 21.0592363	total: 9.89ms	remaining: 72.5ms
# 12:	learn: 20.7037713	total: 10.7ms	remaining: 71.4ms
# 13:	learn: 20.3890648	total: 11.4ms	remaining: 70.2ms
# 14:	learn: 20.1077154	total: 12.2ms	remaining: 69.4ms
# 15:	learn: 19.8545208	total: 13ms	remaining: 68.4ms
# 16:	learn: 19.6022375	total: 13.8ms	remaining: 67.3ms
# 17:	learn: 19.4187639	total: 14.5ms	remaining: 66.1ms
# 18:	learn: 19.2338441	total: 15.3ms	remaining: 65.2ms
# 19:	learn: 19.0616503	total: 16.1ms	remaining: 64.2ms
# 20:	learn: 18.9082471	total: 16.8ms	remaining: 63.3ms
# 21:	learn: 18.7458622	total: 17.6ms	remaining: 62.4ms
# 22:	learn: 18.5829212	total: 18.4ms	remaining: 61.5ms
# 23:	learn: 18.4399669	total: 19.1ms	remaining: 60.6ms
# 24:	learn: 18.2952899	total: 19.9ms	remaining: 59.9ms
# 25:	learn: 18.1962479	total: 20.8ms	remaining: 59.1ms
# 26:	learn: 18.0695266	total: 21.6ms	remaining: 58.3ms
# 27:	learn: 17.9476653	total: 22.3ms	remaining: 57.4ms
# 28:	learn: 17.8592300	total: 23ms	remaining: 56.4ms
# 29:	learn: 17.7518218	total: 23.8ms	remaining: 55.6ms
# 30:	learn: 17.6667918	total: 24.7ms	remaining: 54.9ms
# 31:	learn: 17.5739440	total: 25.4ms	remaining: 54ms
# 32:	learn: 17.4786852	total: 26.2ms	remaining: 53.2ms
# 33:	learn: 17.4022971	total: 27.1ms	remaining: 52.5ms
# 34:	learn: 17.3944795	total: 27.7ms	remaining: 51.5ms
# 35:	learn: 17.3073169	total: 28.5ms	remaining: 50.8ms
# 36:	learn: 17.2347301	total: 29.3ms	remaining: 49.9ms
# 37:	learn: 17.1552613	total: 30.1ms	remaining: 49.2ms
# 38:	learn: 17.0577195	total: 31ms	remaining: 48.4ms
# 39:	learn: 16.9963295	total: 31.8ms	remaining: 47.6ms
# 40:	learn: 16.9220028	total: 32.5ms	remaining: 46.8ms
# 41:	learn: 16.8663307	total: 33.2ms	remaining: 45.9ms
# 42:	learn: 16.8044885	total: 34ms	remaining: 45.1ms
# 43:	learn: 16.7502106	total: 34.7ms	remaining: 44.2ms
# 44:	learn: 16.7419532	total: 35.5ms	remaining: 43.4ms
# 45:	learn: 16.6557530	total: 36.3ms	remaining: 42.6ms
# 46:	learn: 16.6228713	total: 37ms	remaining: 41.8ms
# 47:	learn: 16.5417477	total: 37.8ms	remaining: 40.9ms
# 48:	learn: 16.4915120	total: 38.6ms	remaining: 40.2ms
# 49:	learn: 16.4850722	total: 39.3ms	remaining: 39.3ms
# 50:	learn: 16.4786434	total: 40ms	remaining: 38.5ms
# 51:	learn: 16.4109683	total: 40.7ms	remaining: 37.6ms
# 52:	learn: 16.3706903	total: 41.5ms	remaining: 36.8ms
# 53:	learn: 16.3223354	total: 42.3ms	remaining: 36ms
# 54:	learn: 16.2704328	total: 43.1ms	remaining: 35.3ms
# 55:	learn: 16.2376537	total: 43.9ms	remaining: 34.5ms
# 56:	learn: 16.2312428	total: 44.6ms	remaining: 33.7ms
# 57:	learn: 16.1869355	total: 45.3ms	remaining: 32.8ms
# 58:	learn: 16.1613134	total: 46.2ms	remaining: 32.1ms
# 59:	learn: 16.1506420	total: 46.9ms	remaining: 31.3ms
# 60:	learn: 16.0946688	total: 47.7ms	remaining: 30.5ms
# 61:	learn: 16.0879503	total: 48.4ms	remaining: 29.6ms
# 62:	learn: 16.0292164	total: 49.1ms	remaining: 28.9ms
# 63:	learn: 15.9788207	total: 49.9ms	remaining: 28.1ms
# 64:	learn: 15.9318831	total: 50.7ms	remaining: 27.3ms
# 65:	learn: 15.9134197	total: 51.4ms	remaining: 26.5ms
# 66:	learn: 15.8991294	total: 52.1ms	remaining: 25.7ms
# 67:	learn: 15.8585353	total: 52.8ms	remaining: 24.8ms
# 68:	learn: 15.8030999	total: 53.6ms	remaining: 24.1ms
# 69:	learn: 15.7976466	total: 54.3ms	remaining: 23.3ms
# 70:	learn: 15.7922344	total: 55ms	remaining: 22.5ms
# 71:	learn: 15.7322480	total: 55.8ms	remaining: 21.7ms
# 72:	learn: 15.6989386	total: 56.6ms	remaining: 20.9ms
# 73:	learn: 15.6599596	total: 57.3ms	remaining: 20.1ms
# 74:	learn: 15.6462326	total: 58ms	remaining: 19.3ms
# 75:	learn: 15.6078492	total: 58.8ms	remaining: 18.6ms
# 76:	learn: 15.5705072	total: 59.5ms	remaining: 17.8ms
# 77:	learn: 15.5170162	total: 60.3ms	remaining: 17ms
# 78:	learn: 15.5121039	total: 61.2ms	remaining: 16.3ms
# 79:	learn: 15.5074933	total: 62ms	remaining: 15.5ms
# 80:	learn: 15.4669828	total: 62.9ms	remaining: 14.8ms
# 81:	learn: 15.4237597	total: 63.7ms	remaining: 14ms
# 82:	learn: 15.3774484	total: 64.5ms	remaining: 13.2ms
# 83:	learn: 15.3301653	total: 65.4ms	remaining: 12.4ms
# 84:	learn: 15.2925571	total: 66.3ms	remaining: 11.7ms
# 85:	learn: 15.2519220	total: 67ms	remaining: 10.9ms
# 86:	learn: 15.2049836	total: 67.9ms	remaining: 10.1ms
# 87:	learn: 15.1799912	total: 68.7ms	remaining: 9.37ms
# 88:	learn: 15.1150809	total: 69.6ms	remaining: 8.6ms
# 89:	learn: 15.0878152	total: 70.3ms	remaining: 7.81ms
# 90:	learn: 15.0387469	total: 71.2ms	remaining: 7.04ms
# 91:	learn: 14.9807323	total: 72.2ms	remaining: 6.27ms
# 92:	learn: 14.9345513	total: 73ms	remaining: 5.5ms
# 93:	learn: 14.8871272	total: 73.8ms	remaining: 4.71ms
# 94:	learn: 14.8825980	total: 74.6ms	remaining: 3.92ms
# 95:	learn: 14.8399335	total: 75.3ms	remaining: 3.14ms
# 96:	learn: 14.8164531	total: 76.2ms	remaining: 2.36ms
# 97:	learn: 14.7897350	total: 77.1ms	remaining: 1.57ms
# 98:	learn: 14.7535342	total: 77.9ms	remaining: 787us
# 99:	learn: 14.7208871	total: 78.9ms	remaining: 0us
# 0:	learn: 30.4937081	total: 1.7ms	remaining: 168ms
# 1:	learn: 29.2418311	total: 2.99ms	remaining: 147ms
# 2:	learn: 28.1189185	total: 4.02ms	remaining: 130ms
# 3:	learn: 27.0927472	total: 5.1ms	remaining: 122ms
# 4:	learn: 26.2005931	total: 6.22ms	remaining: 118ms
# 5:	learn: 25.3901202	total: 7.28ms	remaining: 114ms
# 6:	learn: 24.6880494	total: 8.34ms	remaining: 111ms
# 7:	learn: 24.0719069	total: 9.48ms	remaining: 109ms
# 8:	learn: 23.5612938	total: 10.5ms	remaining: 106ms
# 9:	learn: 23.0678619	total: 11.5ms	remaining: 103ms
# 10:	learn: 22.6221327	total: 12.5ms	remaining: 101ms
# 11:	learn: 22.2398189	total: 13.9ms	remaining: 102ms
# 12:	learn: 21.8855648	total: 15.2ms	remaining: 102ms
# 13:	learn: 21.5951567	total: 16.3ms	remaining: 100ms
# 14:	learn: 21.3119233	total: 17.7ms	remaining: 100ms
# 15:	learn: 21.0772346	total: 18.8ms	remaining: 98.9ms
# 16:	learn: 20.8463908	total: 20.2ms	remaining: 98.4ms
# 17:	learn: 20.6475868	total: 21.2ms	remaining: 96.7ms
# 18:	learn: 20.4678328	total: 22.3ms	remaining: 95.2ms
# 19:	learn: 20.2820361	total: 23.3ms	remaining: 93.3ms
# 20:	learn: 20.1040338	total: 24.6ms	remaining: 92.7ms
# 21:	learn: 19.9669582	total: 25.7ms	remaining: 91.1ms
# 22:	learn: 19.8311070	total: 26.7ms	remaining: 89.3ms
# 23:	learn: 19.6999858	total: 27.8ms	remaining: 87.9ms
# 24:	learn: 19.5759111	total: 29ms	remaining: 86.9ms
# 25:	learn: 19.4764065	total: 29.9ms	remaining: 85ms
# 26:	learn: 19.3450741	total: 30.8ms	remaining: 83.3ms
# 27:	learn: 19.2342222	total: 31.9ms	remaining: 82ms
# 28:	learn: 19.1357032	total: 33ms	remaining: 80.8ms
# 29:	learn: 19.0205071	total: 34.2ms	remaining: 79.8ms
# 30:	learn: 18.9166624	total: 35.4ms	remaining: 78.9ms
# 31:	learn: 18.8366791	total: 36.7ms	remaining: 78ms
# 32:	learn: 18.7815557	total: 38.1ms	remaining: 77.3ms
# 33:	learn: 18.6946913	total: 39.4ms	remaining: 76.4ms
# 34:	learn: 18.5994847	total: 40.5ms	remaining: 75.2ms
# 35:	learn: 18.5342711	total: 41.7ms	remaining: 74.1ms
# 36:	learn: 18.4387559	total: 42.8ms	remaining: 72.8ms
# 37:	learn: 18.4150886	total: 44.1ms	remaining: 71.9ms
# 38:	learn: 18.3436078	total: 45.2ms	remaining: 70.7ms
# 39:	learn: 18.3169186	total: 46.3ms	remaining: 69.5ms
# 40:	learn: 18.2526590	total: 47.5ms	remaining: 68.3ms
# 41:	learn: 18.1810587	total: 48.7ms	remaining: 67.2ms
# 42:	learn: 18.1290159	total: 49.9ms	remaining: 66.2ms
# 43:	learn: 18.0811255	total: 51.2ms	remaining: 65.2ms
# 44:	learn: 18.0054218	total: 52.6ms	remaining: 64.3ms
# 45:	learn: 17.9428872	total: 53.9ms	remaining: 63.3ms
# 46:	learn: 17.8987271	total: 55.2ms	remaining: 62.2ms
# 47:	learn: 17.8578182	total: 56.3ms	remaining: 61ms
# 48:	learn: 17.8198194	total: 57.3ms	remaining: 59.6ms
# 49:	learn: 17.7364694	total: 58.4ms	remaining: 58.4ms
# 50:	learn: 17.7192977	total: 59.6ms	remaining: 57.3ms
# 51:	learn: 17.6479836	total: 60.9ms	remaining: 56.2ms
# 52:	learn: 17.5904476	total: 62.1ms	remaining: 55.1ms
# 53:	learn: 17.5450069	total: 63.3ms	remaining: 53.9ms
# 54:	learn: 17.4984435	total: 64.4ms	remaining: 52.7ms
# 55:	learn: 17.4495354	total: 65.5ms	remaining: 51.4ms
# 56:	learn: 17.4065239	total: 66.6ms	remaining: 50.2ms
# 57:	learn: 17.3444175	total: 67.8ms	remaining: 49.1ms
# 58:	learn: 17.3142827	total: 69.1ms	remaining: 48ms
# 59:	learn: 17.3020631	total: 70.3ms	remaining: 46.9ms
# 60:	learn: 17.2825551	total: 71.4ms	remaining: 45.7ms
# 61:	learn: 17.2344152	total: 72.5ms	remaining: 44.4ms
# 62:	learn: 17.2072146	total: 73.7ms	remaining: 43.3ms
# 63:	learn: 17.1626520	total: 75ms	remaining: 42.2ms
# 64:	learn: 17.1102601	total: 76.2ms	remaining: 41ms
# 65:	learn: 17.0603436	total: 77.2ms	remaining: 39.8ms
# 66:	learn: 17.0148825	total: 78.1ms	remaining: 38.5ms
# 67:	learn: 16.9516449	total: 79.1ms	remaining: 37.2ms
# 68:	learn: 16.9128803	total: 80.1ms	remaining: 36ms
# 69:	learn: 16.8684899	total: 81.1ms	remaining: 34.8ms
# 70:	learn: 16.8229002	total: 82.1ms	remaining: 33.5ms
# 71:	learn: 16.7677107	total: 83.1ms	remaining: 32.3ms
# 72:	learn: 16.7268700	total: 84ms	remaining: 31.1ms
# 73:	learn: 16.6875513	total: 84.9ms	remaining: 29.8ms
# 74:	learn: 16.6527691	total: 85.8ms	remaining: 28.6ms
# 75:	learn: 16.5993855	total: 86.8ms	remaining: 27.4ms
# 76:	learn: 16.5665328	total: 87.7ms	remaining: 26.2ms
# 77:	learn: 16.5510773	total: 88.8ms	remaining: 25ms
# 78:	learn: 16.5103898	total: 89.8ms	remaining: 23.9ms
# 79:	learn: 16.5051349	total: 90.8ms	remaining: 22.7ms
# 80:	learn: 16.4626897	total: 91.8ms	remaining: 21.5ms
# 81:	learn: 16.4346597	total: 92.7ms	remaining: 20.3ms
# 82:	learn: 16.3952636	total: 93.6ms	remaining: 19.2ms
# 83:	learn: 16.3534394	total: 94.6ms	remaining: 18ms
# 84:	learn: 16.3299575	total: 95.6ms	remaining: 16.9ms
# 85:	learn: 16.2871772	total: 96.6ms	remaining: 15.7ms
# 86:	learn: 16.2490243	total: 97.5ms	remaining: 14.6ms
# 87:	learn: 16.2069457	total: 98.5ms	remaining: 13.4ms
# 88:	learn: 16.1892633	total: 99.4ms	remaining: 12.3ms
# 89:	learn: 16.1535588	total: 100ms	remaining: 11.2ms
# 90:	learn: 16.1220283	total: 101ms	remaining: 10ms
# 91:	learn: 16.0851346	total: 102ms	remaining: 8.9ms
# 92:	learn: 16.0360134	total: 103ms	remaining: 7.78ms
# 93:	learn: 16.0066909	total: 104ms	remaining: 6.66ms
# 94:	learn: 16.0008516	total: 105ms	remaining: 5.53ms
# 95:	learn: 15.9690492	total: 106ms	remaining: 4.42ms
# 96:	learn: 15.9384047	total: 107ms	remaining: 3.31ms
# 97:	learn: 15.8937264	total: 108ms	remaining: 2.21ms
# 98:	learn: 15.8512683	total: 109ms	remaining: 1.1ms
# 99:	learn: 15.8188776	total: 110ms	remaining: 0us
# 0:	learn: 31.8131585	total: 2.02ms	remaining: 200ms
# 1:	learn: 30.4755886	total: 3.29ms	remaining: 161ms
# 2:	learn: 29.2720496	total: 4.64ms	remaining: 150ms
# 3:	learn: 28.2114119	total: 6.1ms	remaining: 146ms
# 4:	learn: 27.2745984	total: 7.52ms	remaining: 143ms
# 5:	learn: 26.4613428	total: 8.89ms	remaining: 139ms
# 6:	learn: 25.7772726	total: 10.2ms	remaining: 136ms
# 7:	learn: 25.1396812	total: 11.5ms	remaining: 132ms
# 8:	learn: 24.5949115	total: 12.8ms	remaining: 129ms
# 9:	learn: 24.1354614	total: 14.2ms	remaining: 128ms
# 10:	learn: 23.7076025	total: 15.7ms	remaining: 127ms
# 11:	learn: 23.3231509	total: 17ms	remaining: 124ms
# 12:	learn: 22.9946095	total: 18.1ms	remaining: 121ms
# 13:	learn: 22.6851803	total: 19.4ms	remaining: 119ms
# 14:	learn: 22.4106413	total: 20.7ms	remaining: 117ms
# 15:	learn: 22.1710161	total: 22.1ms	remaining: 116ms
# 16:	learn: 21.9587320	total: 23.4ms	remaining: 114ms
# 17:	learn: 21.7560954	total: 24.7ms	remaining: 113ms
# 18:	learn: 21.5652223	total: 25.9ms	remaining: 110ms
# 19:	learn: 21.3807558	total: 27.2ms	remaining: 109ms
# 20:	learn: 21.2061181	total: 28.3ms	remaining: 106ms
# 21:	learn: 21.0532945	total: 29.5ms	remaining: 104ms
# 22:	learn: 20.9151770	total: 30.5ms	remaining: 102ms
# 23:	learn: 20.7644125	total: 31.6ms	remaining: 100ms
# 24:	learn: 20.6522123	total: 32.7ms	remaining: 98ms
# 25:	learn: 20.5295582	total: 33.8ms	remaining: 96.1ms
# 26:	learn: 20.4147857	total: 34.9ms	remaining: 94.4ms
# 27:	learn: 20.3008805	total: 36.1ms	remaining: 92.8ms
# 28:	learn: 20.2143513	total: 37.2ms	remaining: 91ms
# 29:	learn: 20.1134241	total: 38.2ms	remaining: 89.1ms
# 30:	learn: 20.0324682	total: 39.4ms	remaining: 87.8ms
# 31:	learn: 19.9536811	total: 40.5ms	remaining: 86ms
# 32:	learn: 19.8714290	total: 41.5ms	remaining: 84.2ms
# 33:	learn: 19.7996580	total: 42.6ms	remaining: 82.7ms
# 34:	learn: 19.7207238	total: 43.7ms	remaining: 81.2ms
# 35:	learn: 19.6506966	total: 44.9ms	remaining: 79.8ms
# 36:	learn: 19.5766479	total: 46ms	remaining: 78.3ms
# 37:	learn: 19.5362039	total: 47.4ms	remaining: 77.4ms
# 38:	learn: 19.4861258	total: 48.7ms	remaining: 76.2ms
# 39:	learn: 19.4194744	total: 50ms	remaining: 75ms
# 40:	learn: 19.3601743	total: 51ms	remaining: 73.4ms
# 41:	learn: 19.3013264	total: 52.1ms	remaining: 71.9ms
# 42:	learn: 19.2481650	total: 53.1ms	remaining: 70.4ms
# 43:	learn: 19.1930210	total: 54.6ms	remaining: 69.5ms
# 44:	learn: 19.1133284	total: 55.8ms	remaining: 68.2ms
# 45:	learn: 19.0570455	total: 56.9ms	remaining: 66.8ms
# 46:	learn: 19.0258323	total: 58ms	remaining: 65.4ms
# 47:	learn: 18.9935520	total: 59.1ms	remaining: 64ms
# 48:	learn: 18.9694981	total: 60.1ms	remaining: 62.6ms
# 49:	learn: 18.9202414	total: 61.3ms	remaining: 61.3ms
# 50:	learn: 18.8836724	total: 62.4ms	remaining: 59.9ms
# 51:	learn: 18.8279145	total: 63.5ms	remaining: 58.6ms
# 52:	learn: 18.7903585	total: 64.7ms	remaining: 57.4ms
# 53:	learn: 18.7642254	total: 65.9ms	remaining: 56.1ms
# 54:	learn: 18.7114111	total: 66.9ms	remaining: 54.7ms
# 55:	learn: 18.6589389	total: 68ms	remaining: 53.4ms
# 56:	learn: 18.6125853	total: 69.2ms	remaining: 52.2ms
# 57:	learn: 18.5700832	total: 70.2ms	remaining: 50.8ms
# 58:	learn: 18.5252222	total: 71.3ms	remaining: 49.5ms
# 59:	learn: 18.4988118	total: 72.4ms	remaining: 48.2ms
# 60:	learn: 18.4677222	total: 73.5ms	remaining: 47ms
# 61:	learn: 18.4277891	total: 74.6ms	remaining: 45.7ms
# 62:	learn: 18.3931715	total: 75.7ms	remaining: 44.4ms
# 63:	learn: 18.3561671	total: 76.7ms	remaining: 43.2ms
# 64:	learn: 18.3107274	total: 77.9ms	remaining: 41.9ms
# 65:	learn: 18.2822825	total: 79ms	remaining: 40.7ms
# 66:	learn: 18.2507028	total: 80.3ms	remaining: 39.6ms
# 67:	learn: 18.2144274	total: 81.7ms	remaining: 38.5ms
# 68:	learn: 18.1834538	total: 83.1ms	remaining: 37.3ms
# 69:	learn: 18.1471223	total: 84.3ms	remaining: 36.1ms
# 70:	learn: 18.1103773	total: 85.5ms	remaining: 34.9ms
# 71:	learn: 18.0679728	total: 86.7ms	remaining: 33.7ms
# 72:	learn: 18.0230965	total: 88.1ms	remaining: 32.6ms
# 73:	learn: 17.9781999	total: 89.4ms	remaining: 31.4ms
# 74:	learn: 17.9710368	total: 90.6ms	remaining: 30.2ms
# 75:	learn: 17.9284462	total: 92.1ms	remaining: 29.1ms
# 76:	learn: 17.8941006	total: 93.5ms	remaining: 27.9ms
# 77:	learn: 17.8611356	total: 95ms	remaining: 26.8ms
# 78:	learn: 17.8306109	total: 96ms	remaining: 25.5ms
# 79:	learn: 17.8069552	total: 97ms	remaining: 24.3ms
# 80:	learn: 17.7717955	total: 98.2ms	remaining: 23ms
# 81:	learn: 17.7650145	total: 99.1ms	remaining: 21.8ms
# 82:	learn: 17.7307528	total: 100ms	remaining: 20.5ms
# 83:	learn: 17.6924262	total: 101ms	remaining: 19.3ms
# 84:	learn: 17.6859580	total: 102ms	remaining: 18ms
# 85:	learn: 17.6804184	total: 104ms	remaining: 16.9ms
# 86:	learn: 17.6502860	total: 105ms	remaining: 15.7ms
# 87:	learn: 17.6264181	total: 107ms	remaining: 14.5ms
# 88:	learn: 17.5880095	total: 108ms	remaining: 13.3ms
# 89:	learn: 17.5482603	total: 109ms	remaining: 12.1ms
# 90:	learn: 17.5217883	total: 110ms	remaining: 10.9ms
# 91:	learn: 17.4711865	total: 111ms	remaining: 9.69ms
# 92:	learn: 17.4428961	total: 113ms	remaining: 8.47ms
# 93:	learn: 17.4184371	total: 114ms	remaining: 7.25ms
# 94:	learn: 17.4127056	total: 115ms	remaining: 6.03ms
# 95:	learn: 17.3703421	total: 116ms	remaining: 4.82ms
# 96:	learn: 17.3466999	total: 117ms	remaining: 3.61ms
# 97:	learn: 17.3417810	total: 118ms	remaining: 2.4ms
# 98:	learn: 17.3123512	total: 119ms	remaining: 1.2ms
# 99:	learn: 17.2866811	total: 120ms	remaining: 0us
# 0:	learn: 33.1294661	total: 2.06ms	remaining: 204ms
# 1:	learn: 31.6783646	total: 3.61ms	remaining: 177ms
# 2:	learn: 30.4381297	total: 5.19ms	remaining: 168ms
# 3:	learn: 29.3562400	total: 6.73ms	remaining: 161ms
# 4:	learn: 28.4104650	total: 8.23ms	remaining: 156ms
# 5:	learn: 27.5890574	total: 9.73ms	remaining: 152ms
# 6:	learn: 26.8239264	total: 11.2ms	remaining: 149ms
# 7:	learn: 26.1634653	total: 12.5ms	remaining: 144ms
# 8:	learn: 25.6129665	total: 13.8ms	remaining: 140ms
# 9:	learn: 25.1040705	total: 15.3ms	remaining: 138ms
# 10:	learn: 24.6619810	total: 16.7ms	remaining: 135ms
# 11:	learn: 24.2908418	total: 18.1ms	remaining: 133ms
# 12:	learn: 23.9531440	total: 19.6ms	remaining: 131ms
# 13:	learn: 23.6461748	total: 21.1ms	remaining: 130ms
# 14:	learn: 23.3506452	total: 22.7ms	remaining: 128ms
# 15:	learn: 23.0862832	total: 24.2ms	remaining: 127ms
# 16:	learn: 22.8516764	total: 25.7ms	remaining: 126ms
# 17:	learn: 22.6615895	total: 26.9ms	remaining: 123ms
# 18:	learn: 22.4830311	total: 28ms	remaining: 119ms
# 19:	learn: 22.3035325	total: 29.2ms	remaining: 117ms
# 20:	learn: 22.1520844	total: 30.4ms	remaining: 114ms
# 21:	learn: 22.0125217	total: 31.5ms	remaining: 112ms
# 22:	learn: 21.8842500	total: 32.6ms	remaining: 109ms
# 23:	learn: 21.7472528	total: 33.7ms	remaining: 107ms
# 24:	learn: 21.6232379	total: 35ms	remaining: 105ms
# 25:	learn: 21.5178128	total: 36.2ms	remaining: 103ms
# 26:	learn: 21.4168572	total: 37.4ms	remaining: 101ms
# 27:	learn: 21.3106778	total: 38.5ms	remaining: 99.1ms
# 28:	learn: 21.2228234	total: 39.7ms	remaining: 97.2ms
# 29:	learn: 21.1267869	total: 40.9ms	remaining: 95.5ms
# 30:	learn: 21.0476454	total: 42.1ms	remaining: 93.7ms
# 31:	learn: 20.9767999	total: 43.1ms	remaining: 91.7ms
# 32:	learn: 20.9128664	total: 44.5ms	remaining: 90.3ms
# 33:	learn: 20.8471464	total: 46ms	remaining: 89.2ms
# 34:	learn: 20.7785001	total: 47.4ms	remaining: 88ms
# 35:	learn: 20.7307518	total: 48.8ms	remaining: 86.8ms
# 36:	learn: 20.6774889	total: 50.3ms	remaining: 85.6ms
# 37:	learn: 20.6516700	total: 51.7ms	remaining: 84.3ms
# 38:	learn: 20.6043854	total: 53.2ms	remaining: 83.2ms
# 39:	learn: 20.5533645	total: 54.6ms	remaining: 81.9ms
# 40:	learn: 20.4895222	total: 56.1ms	remaining: 80.7ms
# 41:	learn: 20.4277989	total: 57.7ms	remaining: 79.6ms
# 42:	learn: 20.3864520	total: 59ms	remaining: 78.3ms
# 43:	learn: 20.3644502	total: 60.3ms	remaining: 76.8ms
# 44:	learn: 20.3212511	total: 61.5ms	remaining: 75.2ms
# 45:	learn: 20.2742601	total: 62.7ms	remaining: 73.6ms
# 46:	learn: 20.2381440	total: 63.8ms	remaining: 72ms
# 47:	learn: 20.1849016	total: 65ms	remaining: 70.4ms
# 48:	learn: 20.1478951	total: 66.1ms	remaining: 68.8ms
# 49:	learn: 20.1012112	total: 67.3ms	remaining: 67.3ms
# 50:	learn: 20.0406323	total: 68.4ms	remaining: 65.8ms
# 51:	learn: 20.0279466	total: 69.6ms	remaining: 64.2ms
# 52:	learn: 20.0083188	total: 70.8ms	remaining: 62.8ms
# 53:	learn: 19.9638393	total: 71.9ms	remaining: 61.3ms
# 54:	learn: 19.9050662	total: 73.1ms	remaining: 59.8ms
# 55:	learn: 19.8572026	total: 74.4ms	remaining: 58.4ms
# 56:	learn: 19.8150239	total: 75.6ms	remaining: 57.1ms
# 57:	learn: 19.7762427	total: 77.2ms	remaining: 55.9ms
# 58:	learn: 19.7552825	total: 78.6ms	remaining: 54.6ms
# 59:	learn: 19.7213435	total: 80ms	remaining: 53.3ms
# 60:	learn: 19.6693314	total: 81.5ms	remaining: 52.1ms
# 61:	learn: 19.6387327	total: 83ms	remaining: 50.9ms
# 62:	learn: 19.6023937	total: 84.4ms	remaining: 49.6ms
# 63:	learn: 19.5655190	total: 85.7ms	remaining: 48.2ms
# 64:	learn: 19.5260922	total: 87.5ms	remaining: 47.1ms
# 65:	learn: 19.4827286	total: 88.8ms	remaining: 45.7ms
# 66:	learn: 19.4491594	total: 90ms	remaining: 44.3ms
# 67:	learn: 19.4177105	total: 91.1ms	remaining: 42.9ms
# 68:	learn: 19.3905248	total: 92.3ms	remaining: 41.5ms
# 69:	learn: 19.3667764	total: 93.5ms	remaining: 40.1ms
# 70:	learn: 19.3421573	total: 94.7ms	remaining: 38.7ms
# 71:	learn: 19.3002819	total: 95.8ms	remaining: 37.3ms
# 72:	learn: 19.2643083	total: 97.1ms	remaining: 35.9ms
# 73:	learn: 19.2281522	total: 98.2ms	remaining: 34.5ms
# 74:	learn: 19.2014295	total: 99.3ms	remaining: 33.1ms
# 75:	learn: 19.1890501	total: 100ms	remaining: 31.7ms
# 76:	learn: 19.1586895	total: 102ms	remaining: 30.3ms
# 77:	learn: 19.1283368	total: 103ms	remaining: 29ms
# 78:	learn: 19.1220328	total: 104ms	remaining: 27.6ms
# 79:	learn: 19.0820682	total: 105ms	remaining: 26.3ms
# 80:	learn: 19.0442089	total: 106ms	remaining: 24.9ms
# 81:	learn: 19.0415075	total: 107ms	remaining: 23.5ms
# 82:	learn: 19.0154796	total: 108ms	remaining: 22.2ms
# 83:	learn: 18.9866184	total: 109ms	remaining: 20.8ms
# 84:	learn: 18.9796067	total: 111ms	remaining: 19.5ms
# 85:	learn: 18.9772200	total: 112ms	remaining: 18.2ms
# 86:	learn: 18.9515099	total: 113ms	remaining: 16.9ms
# 87:	learn: 18.9165495	total: 114ms	remaining: 15.6ms
# 88:	learn: 18.9116347	total: 115ms	remaining: 14.2ms
# 89:	learn: 18.8828598	total: 116ms	remaining: 12.9ms
# 90:	learn: 18.8493457	total: 117ms	remaining: 11.6ms
# 91:	learn: 18.8431134	total: 119ms	remaining: 10.3ms
# 92:	learn: 18.8045377	total: 120ms	remaining: 9.01ms
# 93:	learn: 18.7692578	total: 121ms	remaining: 7.72ms
# 94:	learn: 18.7400319	total: 122ms	remaining: 6.42ms
# 95:	learn: 18.7105003	total: 123ms	remaining: 5.13ms
# 96:	learn: 18.6775680	total: 124ms	remaining: 3.85ms
# 97:	learn: 18.6754348	total: 125ms	remaining: 2.56ms
# 98:	learn: 18.6534208	total: 126ms	remaining: 1.28ms
# 99:	learn: 18.6494283	total: 128ms	remaining: 0us
# 0:	learn: 27.8676225	total: 1.56ms	remaining: 154ms
# 1:	learn: 26.6006950	total: 2.82ms	remaining: 138ms
# 2:	learn: 25.4408088	total: 3.87ms	remaining: 125ms
# 3:	learn: 24.4224165	total: 4.95ms	remaining: 119ms
# 4:	learn: 23.4469916	total: 6.13ms	remaining: 117ms
# 5:	learn: 22.5991666	total: 6.91ms	remaining: 108ms
# 6:	learn: 21.8623819	total: 7.68ms	remaining: 102ms
# 7:	learn: 21.1780360	total: 8.73ms	remaining: 100ms
# 8:	learn: 20.5609056	total: 9.63ms	remaining: 97.3ms
# 9:	learn: 20.0681859	total: 10.5ms	remaining: 94.5ms
# 10:	learn: 19.5959028	total: 11.2ms	remaining: 90.9ms
# 11:	learn: 19.1710544	total: 12ms	remaining: 87.9ms
# 12:	learn: 18.7485467	total: 12.8ms	remaining: 85.4ms
# 13:	learn: 18.4377208	total: 13.7ms	remaining: 84.3ms
# 14:	learn: 18.1546904	total: 14.7ms	remaining: 83.2ms
# 15:	learn: 17.8574663	total: 15.7ms	remaining: 82.6ms
# 16:	learn: 17.5987219	total: 16.6ms	remaining: 81.2ms
# 17:	learn: 17.3279040	total: 17.5ms	remaining: 79.7ms
# 18:	learn: 17.0948779	total: 18.2ms	remaining: 77.8ms
# 19:	learn: 16.9044197	total: 19ms	remaining: 76.1ms
# 20:	learn: 16.7192392	total: 19.9ms	remaining: 74.8ms
# 21:	learn: 16.5056759	total: 21ms	remaining: 74.3ms
# 22:	learn: 16.3361069	total: 21.9ms	remaining: 73.5ms
# 23:	learn: 16.1688013	total: 22.7ms	remaining: 71.7ms
# 24:	learn: 16.0087560	total: 23.4ms	remaining: 70.2ms
# 25:	learn: 15.8431721	total: 24.1ms	remaining: 68.7ms
# 26:	learn: 15.6980850	total: 24.8ms	remaining: 67.1ms
# 27:	learn: 15.5216388	total: 25.5ms	remaining: 65.7ms
# 28:	learn: 15.3673399	total: 26.3ms	remaining: 64.4ms
# 29:	learn: 15.2487917	total: 27ms	remaining: 63.1ms
# 30:	learn: 15.1230268	total: 27.8ms	remaining: 62ms
# 31:	learn: 15.0159080	total: 28.6ms	remaining: 60.8ms
# 32:	learn: 14.8745093	total: 29.3ms	remaining: 59.5ms
# 33:	learn: 14.7459298	total: 30ms	remaining: 58.2ms
# 34:	learn: 14.6422429	total: 30.7ms	remaining: 57ms
# 35:	learn: 14.5518138	total: 31.4ms	remaining: 55.7ms
# 36:	learn: 14.4362740	total: 32.1ms	remaining: 54.7ms
# 37:	learn: 14.3174082	total: 32.8ms	remaining: 53.6ms
# 38:	learn: 14.1970531	total: 33.6ms	remaining: 52.6ms
# 39:	learn: 14.0944121	total: 34.4ms	remaining: 51.6ms
# 40:	learn: 13.9902709	total: 35.3ms	remaining: 50.8ms
# 41:	learn: 13.8786310	total: 36ms	remaining: 49.8ms
# 42:	learn: 13.7987996	total: 36.7ms	remaining: 48.7ms
# 43:	learn: 13.7167505	total: 37.4ms	remaining: 47.6ms
# 44:	learn: 13.6438185	total: 38.1ms	remaining: 46.5ms
# 45:	learn: 13.5536990	total: 38.9ms	remaining: 45.7ms
# 46:	learn: 13.4479630	total: 39.9ms	remaining: 44.9ms
# 47:	learn: 13.3722357	total: 40.8ms	remaining: 44.2ms
# 48:	learn: 13.2764642	total: 41.7ms	remaining: 43.4ms
# 49:	learn: 13.2053651	total: 42.8ms	remaining: 42.8ms
# 50:	learn: 13.1027265	total: 43.9ms	remaining: 42.2ms
# 51:	learn: 12.9970182	total: 44.9ms	remaining: 41.4ms
# 52:	learn: 12.9184653	total: 45.9ms	remaining: 40.7ms
# 53:	learn: 12.8765589	total: 46.8ms	remaining: 39.9ms
# 54:	learn: 12.8215607	total: 47.7ms	remaining: 39ms
# 55:	learn: 12.7385852	total: 48.7ms	remaining: 38.2ms
# 56:	learn: 12.6300030	total: 49.7ms	remaining: 37.5ms
# 57:	learn: 12.5649445	total: 50.4ms	remaining: 36.5ms
# 58:	learn: 12.4941356	total: 51.1ms	remaining: 35.5ms
# 59:	learn: 12.4018960	total: 51.7ms	remaining: 34.5ms
# 60:	learn: 12.3465741	total: 52.4ms	remaining: 33.5ms
# 61:	learn: 12.2851269	total: 53.1ms	remaining: 32.6ms
# 62:	learn: 12.2293883	total: 54ms	remaining: 31.7ms
# 63:	learn: 12.1782693	total: 54.9ms	remaining: 30.9ms
# 64:	learn: 12.1034776	total: 55.7ms	remaining: 30ms
# 65:	learn: 12.0528749	total: 56.4ms	remaining: 29ms
# 66:	learn: 12.0059604	total: 57.1ms	remaining: 28.1ms
# 67:	learn: 11.9783522	total: 57.9ms	remaining: 27.2ms
# 68:	learn: 11.9054796	total: 58.6ms	remaining: 26.3ms
# 69:	learn: 11.8548531	total: 59.4ms	remaining: 25.5ms
# 70:	learn: 11.7720231	total: 60.2ms	remaining: 24.6ms
# 71:	learn: 11.7381194	total: 60.9ms	remaining: 23.7ms
# 72:	learn: 11.6689902	total: 61.7ms	remaining: 22.8ms
# 73:	learn: 11.6045719	total: 62.5ms	remaining: 22ms
# 74:	learn: 11.5440612	total: 63.3ms	remaining: 21.1ms
# 75:	learn: 11.4949157	total: 64.1ms	remaining: 20.2ms
# 76:	learn: 11.4407456	total: 64.9ms	remaining: 19.4ms
# 77:	learn: 11.4058325	total: 65.6ms	remaining: 18.5ms
# 78:	learn: 11.3403181	total: 66.4ms	remaining: 17.6ms
# 79:	learn: 11.2633118	total: 67.1ms	remaining: 16.8ms
# 80:	learn: 11.2407627	total: 67.9ms	remaining: 15.9ms
# 81:	learn: 11.1695936	total: 68.6ms	remaining: 15.1ms
# 82:	learn: 11.1094657	total: 69.3ms	remaining: 14.2ms
# 83:	learn: 11.0775321	total: 70ms	remaining: 13.3ms
# 84:	learn: 11.0096765	total: 70.7ms	remaining: 12.5ms
# 85:	learn: 10.9467233	total: 71.4ms	remaining: 11.6ms
# 86:	learn: 10.8826265	total: 72.2ms	remaining: 10.8ms
# 87:	learn: 10.8573344	total: 72.9ms	remaining: 9.94ms
# 88:	learn: 10.8238263	total: 73.6ms	remaining: 9.09ms
# 89:	learn: 10.7728760	total: 74.3ms	remaining: 8.26ms
# 90:	learn: 10.7123125	total: 75ms	remaining: 7.42ms
# 91:	learn: 10.6680402	total: 75.8ms	remaining: 6.59ms
# 92:	learn: 10.6284404	total: 76.7ms	remaining: 5.77ms
# 93:	learn: 10.5849236	total: 77.7ms	remaining: 4.96ms
# 94:	learn: 10.5264109	total: 78.8ms	remaining: 4.15ms
# 95:	learn: 10.5032722	total: 80ms	remaining: 3.33ms
# 96:	learn: 10.4306890	total: 80.8ms	remaining: 2.5ms
# 97:	learn: 10.4114964	total: 81.9ms	remaining: 1.67ms
# 98:	learn: 10.3493497	total: 82.8ms	remaining: 836us
# 99:	learn: 10.3270670	total: 83.7ms	remaining: 0us
# 0:	learn: 28.8925579	total: 1.29ms	remaining: 127ms
# 1:	learn: 27.6376172	total: 2.49ms	remaining: 122ms
# 2:	learn: 26.5142358	total: 3.41ms	remaining: 110ms
# 3:	learn: 25.5330006	total: 4.4ms	remaining: 106ms
# 4:	learn: 24.6749906	total: 5.27ms	remaining: 100ms
# 5:	learn: 23.8746725	total: 6.12ms	remaining: 95.9ms
# 6:	learn: 23.2171430	total: 7.24ms	remaining: 96.1ms
# 7:	learn: 22.5981943	total: 8.34ms	remaining: 95.9ms
# 8:	learn: 22.0692645	total: 9.51ms	remaining: 96.2ms
# 9:	learn: 21.5821759	total: 10.6ms	remaining: 95.6ms
# 10:	learn: 21.1438284	total: 11.9ms	remaining: 96.1ms
# 11:	learn: 20.8021055	total: 13ms	remaining: 95.6ms
# 12:	learn: 20.4454993	total: 14.1ms	remaining: 94.1ms
# 13:	learn: 20.1713770	total: 15.2ms	remaining: 93.3ms
# 14:	learn: 19.8589414	total: 16.2ms	remaining: 92.1ms
# 15:	learn: 19.5958861	total: 17.3ms	remaining: 91.1ms
# 16:	learn: 19.3512094	total: 18.6ms	remaining: 90.7ms
# 17:	learn: 19.1296771	total: 19.7ms	remaining: 89.9ms
# 18:	learn: 18.9461711	total: 20.8ms	remaining: 88.6ms
# 19:	learn: 18.7749819	total: 22ms	remaining: 87.9ms
# 20:	learn: 18.6094910	total: 23ms	remaining: 86.7ms
# 21:	learn: 18.4589601	total: 24.2ms	remaining: 85.9ms
# 22:	learn: 18.3105613	total: 25.3ms	remaining: 84.7ms
# 23:	learn: 18.1756317	total: 26.3ms	remaining: 83.4ms
# 24:	learn: 18.0412956	total: 27.3ms	remaining: 82ms
# 25:	learn: 17.9330589	total: 28.4ms	remaining: 80.7ms
# 26:	learn: 17.8176367	total: 29.2ms	remaining: 79.1ms
# 27:	learn: 17.7042406	total: 30.2ms	remaining: 77.6ms
# 28:	learn: 17.6012942	total: 31.1ms	remaining: 76ms
# 29:	learn: 17.4944809	total: 32ms	remaining: 74.6ms
# 30:	learn: 17.4070119	total: 32.9ms	remaining: 73.3ms
# 31:	learn: 17.3171357	total: 33.9ms	remaining: 72ms
# 32:	learn: 17.2078831	total: 34.9ms	remaining: 70.8ms
# 33:	learn: 17.1343835	total: 35.8ms	remaining: 69.6ms
# 34:	learn: 17.0409904	total: 36.8ms	remaining: 68.4ms
# 35:	learn: 16.9396494	total: 37.9ms	remaining: 67.3ms
# 36:	learn: 16.8621931	total: 38.8ms	remaining: 66.1ms
# 37:	learn: 16.7801880	total: 40.1ms	remaining: 65.3ms
# 38:	learn: 16.7192460	total: 41.1ms	remaining: 64.3ms
# 39:	learn: 16.6364534	total: 42.2ms	remaining: 63.3ms
# 40:	learn: 16.5559712	total: 43.1ms	remaining: 62ms
# 41:	learn: 16.5010224	total: 44.1ms	remaining: 60.8ms
# 42:	learn: 16.4307792	total: 44.9ms	remaining: 59.5ms
# 43:	learn: 16.3492669	total: 45.9ms	remaining: 58.5ms
# 44:	learn: 16.2871829	total: 46.9ms	remaining: 57.3ms
# 45:	learn: 16.2138019	total: 47.8ms	remaining: 56.1ms
# 46:	learn: 16.1613626	total: 48.7ms	remaining: 54.9ms
# 47:	learn: 16.0898727	total: 49.8ms	remaining: 53.9ms
# 48:	learn: 16.0607763	total: 50.7ms	remaining: 52.8ms
# 49:	learn: 15.9885624	total: 51.7ms	remaining: 51.7ms
# 50:	learn: 15.9285264	total: 52.7ms	remaining: 50.7ms
# 51:	learn: 15.8644089	total: 53.8ms	remaining: 49.6ms
# 52:	learn: 15.8175355	total: 54.7ms	remaining: 48.5ms
# 53:	learn: 15.7825098	total: 55.7ms	remaining: 47.4ms
# 54:	learn: 15.7627769	total: 56.7ms	remaining: 46.4ms
# 55:	learn: 15.7207230	total: 57.9ms	remaining: 45.5ms
# 56:	learn: 15.6651794	total: 58.8ms	remaining: 44.4ms
# 57:	learn: 15.6009472	total: 59.7ms	remaining: 43.2ms
# 58:	learn: 15.5632923	total: 60.5ms	remaining: 42.1ms
# 59:	learn: 15.5135793	total: 61.4ms	remaining: 40.9ms
# 60:	learn: 15.4605017	total: 62.4ms	remaining: 39.9ms
# 61:	learn: 15.4125395	total: 63.3ms	remaining: 38.8ms
# 62:	learn: 15.3820675	total: 64.2ms	remaining: 37.7ms
# 63:	learn: 15.3388687	total: 65ms	remaining: 36.6ms
# 64:	learn: 15.2761352	total: 66ms	remaining: 35.6ms
# 65:	learn: 15.2231456	total: 67ms	remaining: 34.5ms
# 66:	learn: 15.1896258	total: 67.9ms	remaining: 33.4ms
# 67:	learn: 15.1438956	total: 68.9ms	remaining: 32.4ms
# 68:	learn: 15.0902090	total: 69.8ms	remaining: 31.3ms
# 69:	learn: 15.0317078	total: 70.8ms	remaining: 30.3ms
# 70:	learn: 15.0146357	total: 71.6ms	remaining: 29.2ms
# 71:	learn: 14.9748660	total: 72.5ms	remaining: 28.2ms
# 72:	learn: 14.9314893	total: 73.4ms	remaining: 27.1ms
# 73:	learn: 14.8888638	total: 74.4ms	remaining: 26.1ms
# 74:	learn: 14.8328690	total: 75.3ms	remaining: 25.1ms
# 75:	learn: 14.7841935	total: 76.3ms	remaining: 24.1ms
# 76:	learn: 14.7481660	total: 77.2ms	remaining: 23.1ms
# 77:	learn: 14.7142823	total: 78.3ms	remaining: 22.1ms
# 78:	learn: 14.7001481	total: 79.3ms	remaining: 21.1ms
# 79:	learn: 14.6431258	total: 80.5ms	remaining: 20.1ms
# 80:	learn: 14.5957420	total: 81.7ms	remaining: 19.2ms
# 81:	learn: 14.5352654	total: 82.8ms	remaining: 18.2ms
# 82:	learn: 14.4926388	total: 83.7ms	remaining: 17.2ms
# 83:	learn: 14.4583611	total: 84.7ms	remaining: 16.1ms
# 84:	learn: 14.4081636	total: 85.7ms	remaining: 15.1ms
# 85:	learn: 14.3483529	total: 86.9ms	remaining: 14.1ms
# 86:	learn: 14.3078204	total: 88ms	remaining: 13.1ms
# 87:	learn: 14.2741827	total: 89ms	remaining: 12.1ms
# 88:	learn: 14.2317226	total: 89.8ms	remaining: 11.1ms
# 89:	learn: 14.2020562	total: 90.6ms	remaining: 10.1ms
# 90:	learn: 14.1685051	total: 91.3ms	remaining: 9.03ms
# 91:	learn: 14.1094959	total: 92.1ms	remaining: 8.01ms
# 92:	learn: 14.0573325	total: 93ms	remaining: 7ms
# 93:	learn: 14.0271245	total: 93.8ms	remaining: 5.99ms
# 94:	learn: 13.9908322	total: 94.6ms	remaining: 4.98ms
# 95:	learn: 13.9734417	total: 95.4ms	remaining: 3.97ms
# 96:	learn: 13.9348323	total: 96.2ms	remaining: 2.97ms
# 97:	learn: 13.8698594	total: 97.1ms	remaining: 1.98ms
# 98:	learn: 13.8387114	total: 98ms	remaining: 989us
# 99:	learn: 13.8233747	total: 98.7ms	remaining: 0us
# 0:	learn: 30.4647394	total: 1.4ms	remaining: 138ms
# 1:	learn: 29.1793540	total: 2.89ms	remaining: 142ms
# 2:	learn: 28.0290496	total: 4.36ms	remaining: 141ms
# 3:	learn: 27.0040093	total: 5.75ms	remaining: 138ms
# 4:	learn: 26.0673553	total: 7.06ms	remaining: 134ms
# 5:	learn: 25.2614307	total: 8.38ms	remaining: 131ms
# 6:	learn: 24.5609438	total: 9.81ms	remaining: 130ms
# 7:	learn: 23.9360738	total: 11.2ms	remaining: 129ms
# 8:	learn: 23.4013159	total: 12.5ms	remaining: 127ms
# 9:	learn: 22.8847366	total: 14ms	remaining: 126ms
# 10:	learn: 22.4211048	total: 15.4ms	remaining: 125ms
# 11:	learn: 22.0418701	total: 16.7ms	remaining: 123ms
# 12:	learn: 21.7039076	total: 18.1ms	remaining: 121ms
# 13:	learn: 21.3993750	total: 19.4ms	remaining: 119ms
# 14:	learn: 21.1166792	total: 20.5ms	remaining: 116ms
# 15:	learn: 20.8739059	total: 21.6ms	remaining: 114ms
# 16:	learn: 20.6521777	total: 23ms	remaining: 112ms
# 17:	learn: 20.4514106	total: 24.2ms	remaining: 110ms
# 18:	learn: 20.2550519	total: 25.6ms	remaining: 109ms
# 19:	learn: 20.0733469	total: 26.8ms	remaining: 107ms
# 20:	learn: 19.9147842	total: 28ms	remaining: 105ms
# 21:	learn: 19.7654612	total: 29.2ms	remaining: 103ms
# 22:	learn: 19.6335471	total: 30.2ms	remaining: 101ms
# 23:	learn: 19.5289496	total: 31ms	remaining: 98.1ms
# 24:	learn: 19.4092300	total: 31.9ms	remaining: 95.8ms
# 25:	learn: 19.2761617	total: 33.1ms	remaining: 94.3ms
# 26:	learn: 19.1710614	total: 34.3ms	remaining: 92.8ms
# 27:	learn: 19.0906232	total: 35.7ms	remaining: 91.7ms
# 28:	learn: 18.9825315	total: 36.9ms	remaining: 90.3ms
# 29:	learn: 18.8790754	total: 38ms	remaining: 88.7ms
# 30:	learn: 18.7901519	total: 39.2ms	remaining: 87.3ms
# 31:	learn: 18.6963149	total: 40.4ms	remaining: 85.9ms
# 32:	learn: 18.5822257	total: 41.5ms	remaining: 84.3ms
# 33:	learn: 18.4847751	total: 42.7ms	remaining: 82.8ms
# 34:	learn: 18.3901340	total: 43.9ms	remaining: 81.6ms
# 35:	learn: 18.3342787	total: 44.9ms	remaining: 79.8ms
# 36:	learn: 18.2705927	total: 45.9ms	remaining: 78.1ms
# 37:	learn: 18.2014789	total: 46.8ms	remaining: 76.4ms
# 38:	learn: 18.1222610	total: 47.8ms	remaining: 74.8ms
# 39:	learn: 18.0498919	total: 48.8ms	remaining: 73.1ms
# 40:	learn: 17.9887183	total: 49.7ms	remaining: 71.5ms
# 41:	learn: 17.9045584	total: 50.7ms	remaining: 70ms
# 42:	learn: 17.8528200	total: 51.7ms	remaining: 68.5ms
# 43:	learn: 17.8066885	total: 52.6ms	remaining: 66.9ms
# 44:	learn: 17.7537010	total: 53.5ms	remaining: 65.4ms
# 45:	learn: 17.6971973	total: 54.4ms	remaining: 63.9ms
# 46:	learn: 17.6492613	total: 55.5ms	remaining: 62.5ms
# 47:	learn: 17.5702124	total: 56.6ms	remaining: 61.3ms
# 48:	learn: 17.5256843	total: 57.5ms	remaining: 59.8ms
# 49:	learn: 17.4701284	total: 58.3ms	remaining: 58.3ms
# 50:	learn: 17.3970977	total: 59.4ms	remaining: 57.1ms
# 51:	learn: 17.3283893	total: 60.5ms	remaining: 55.8ms
# 52:	learn: 17.2781914	total: 61.7ms	remaining: 54.7ms
# 53:	learn: 17.2154475	total: 63.3ms	remaining: 53.9ms
# 54:	learn: 17.1688512	total: 64.4ms	remaining: 52.7ms
# 55:	learn: 17.1382585	total: 65.4ms	remaining: 51.4ms
# 56:	learn: 17.0817734	total: 66.5ms	remaining: 50.2ms
# 57:	learn: 17.0356001	total: 67.6ms	remaining: 48.9ms
# 58:	learn: 16.9973629	total: 68.6ms	remaining: 47.7ms
# 59:	learn: 16.9436586	total: 69.9ms	remaining: 46.6ms
# 60:	learn: 16.9001955	total: 71.1ms	remaining: 45.5ms
# 61:	learn: 16.8453448	total: 72.4ms	remaining: 44.4ms
# 62:	learn: 16.7921787	total: 73.7ms	remaining: 43.3ms
# 63:	learn: 16.7538315	total: 74.8ms	remaining: 42.1ms
# 64:	learn: 16.6861510	total: 75.8ms	remaining: 40.8ms
# 65:	learn: 16.6446705	total: 76.8ms	remaining: 39.6ms
# 66:	learn: 16.5890675	total: 77.9ms	remaining: 38.4ms
# 67:	learn: 16.5383842	total: 78.8ms	remaining: 37.1ms
# 68:	learn: 16.4908345	total: 79.7ms	remaining: 35.8ms
# 69:	learn: 16.4627799	total: 80.8ms	remaining: 34.6ms
# 70:	learn: 16.4127783	total: 81.8ms	remaining: 33.4ms
# 71:	learn: 16.3786408	total: 82.9ms	remaining: 32.2ms
# 72:	learn: 16.3316133	total: 83.9ms	remaining: 31ms
# 73:	learn: 16.2871682	total: 84.8ms	remaining: 29.8ms
# 74:	learn: 16.2516774	total: 85.6ms	remaining: 28.5ms
# 75:	learn: 16.2183135	total: 86.5ms	remaining: 27.3ms
# 76:	learn: 16.1703035	total: 87.5ms	remaining: 26.1ms
# 77:	learn: 16.1432541	total: 88.4ms	remaining: 24.9ms
# 78:	learn: 16.1018549	total: 89.4ms	remaining: 23.8ms
# 79:	learn: 16.0699531	total: 90.4ms	remaining: 22.6ms
# 80:	learn: 16.0272113	total: 91.4ms	remaining: 21.4ms
# 81:	learn: 15.9825861	total: 92.5ms	remaining: 20.3ms
# 82:	learn: 15.9251786	total: 93.4ms	remaining: 19.1ms
# 83:	learn: 15.8795588	total: 94.5ms	remaining: 18ms
# 84:	learn: 15.8405979	total: 95.4ms	remaining: 16.8ms
# 85:	learn: 15.7935726	total: 96.5ms	remaining: 15.7ms
# 86:	learn: 15.7809468	total: 97.5ms	remaining: 14.6ms
# 87:	learn: 15.7454761	total: 98.3ms	remaining: 13.4ms
# 88:	learn: 15.7057437	total: 99.3ms	remaining: 12.3ms
# 89:	learn: 15.6704418	total: 100ms	remaining: 11.2ms
# 90:	learn: 15.6327041	total: 101ms	remaining: 10ms
# 91:	learn: 15.5994015	total: 102ms	remaining: 8.89ms
# 92:	learn: 15.5680225	total: 103ms	remaining: 7.78ms
# 93:	learn: 15.5318121	total: 104ms	remaining: 6.67ms
# 94:	learn: 15.4965669	total: 106ms	remaining: 5.56ms
# 95:	learn: 15.4412047	total: 107ms	remaining: 4.45ms
# 96:	learn: 15.4126389	total: 108ms	remaining: 3.34ms
# 97:	learn: 15.3710167	total: 109ms	remaining: 2.23ms
# 98:	learn: 15.3365684	total: 110ms	remaining: 1.11ms
# 99:	learn: 15.3082868	total: 112ms	remaining: 0us
# 0:	learn: 31.7902684	total: 1.58ms	remaining: 157ms
# 1:	learn: 30.4335751	total: 2.75ms	remaining: 135ms
# 2:	learn: 29.2131357	total: 3.94ms	remaining: 128ms
# 3:	learn: 28.1412605	total: 5.2ms	remaining: 125ms
# 4:	learn: 27.1883253	total: 6.5ms	remaining: 123ms
# 5:	learn: 26.3870516	total: 7.71ms	remaining: 121ms
# 6:	learn: 25.6523233	total: 9ms	remaining: 120ms
# 7:	learn: 25.0371262	total: 10.2ms	remaining: 118ms
# 8:	learn: 24.5014405	total: 11.5ms	remaining: 116ms
# 9:	learn: 24.0158061	total: 12.6ms	remaining: 114ms
# 10:	learn: 23.6008784	total: 13.9ms	remaining: 113ms
# 11:	learn: 23.2273454	total: 15.1ms	remaining: 110ms
# 12:	learn: 22.9000067	total: 16.2ms	remaining: 109ms
# 13:	learn: 22.5813363	total: 17.5ms	remaining: 108ms
# 14:	learn: 22.3298317	total: 18.8ms	remaining: 106ms
# 15:	learn: 22.0674032	total: 19.9ms	remaining: 104ms
# 16:	learn: 21.8539667	total: 21.1ms	remaining: 103ms
# 17:	learn: 21.6553298	total: 22.2ms	remaining: 101ms
# 18:	learn: 21.4663063	total: 23.3ms	remaining: 99.2ms
# 19:	learn: 21.3066943	total: 24.4ms	remaining: 97.6ms
# 20:	learn: 21.1439570	total: 25.5ms	remaining: 95.9ms
# 21:	learn: 20.9810516	total: 26.7ms	remaining: 94.7ms
# 22:	learn: 20.8325545	total: 28ms	remaining: 93.7ms
# 23:	learn: 20.7028987	total: 29.2ms	remaining: 92.4ms
# 24:	learn: 20.5848731	total: 30.4ms	remaining: 91.1ms
# 25:	learn: 20.4595556	total: 31.5ms	remaining: 89.5ms
# 26:	learn: 20.3596422	total: 32.9ms	remaining: 88.9ms
# 27:	learn: 20.2642624	total: 34.2ms	remaining: 88ms
# 28:	learn: 20.1448410	total: 35.5ms	remaining: 86.8ms
# 29:	learn: 20.0542649	total: 36.7ms	remaining: 85.6ms
# 30:	learn: 19.9761561	total: 37.8ms	remaining: 84.2ms
# 31:	learn: 19.8628917	total: 39ms	remaining: 82.8ms
# 32:	learn: 19.7722232	total: 40.2ms	remaining: 81.7ms
# 33:	learn: 19.6929375	total: 41.3ms	remaining: 80.2ms
# 34:	learn: 19.6115123	total: 42.4ms	remaining: 78.8ms
# 35:	learn: 19.5382982	total: 43.5ms	remaining: 77.3ms
# 36:	learn: 19.4663765	total: 44.6ms	remaining: 75.9ms
# 37:	learn: 19.3844233	total: 45.6ms	remaining: 74.4ms
# 38:	learn: 19.3092246	total: 46.7ms	remaining: 73.1ms
# 39:	learn: 19.2463920	total: 47.9ms	remaining: 71.9ms
# 40:	learn: 19.1816903	total: 49.1ms	remaining: 70.7ms
# 41:	learn: 19.1144387	total: 50.3ms	remaining: 69.5ms
# 42:	learn: 19.0491082	total: 51.4ms	remaining: 68.2ms
# 43:	learn: 18.9847261	total: 52.5ms	remaining: 66.8ms
# 44:	learn: 18.9351700	total: 53.5ms	remaining: 65.4ms
# 45:	learn: 18.8699387	total: 54.6ms	remaining: 64.1ms
# 46:	learn: 18.8186568	total: 55.7ms	remaining: 62.8ms
# 47:	learn: 18.7703658	total: 57.2ms	remaining: 61.9ms
# 48:	learn: 18.7158696	total: 58.2ms	remaining: 60.6ms
# 49:	learn: 18.6609858	total: 59.3ms	remaining: 59.3ms
# 50:	learn: 18.5991386	total: 60.3ms	remaining: 58ms
# 51:	learn: 18.5449600	total: 61.3ms	remaining: 56.6ms
# 52:	learn: 18.5032290	total: 62.4ms	remaining: 55.3ms
# 53:	learn: 18.4549652	total: 63.5ms	remaining: 54.1ms
# 54:	learn: 18.3941826	total: 64.7ms	remaining: 52.9ms
# 55:	learn: 18.3353680	total: 65.8ms	remaining: 51.7ms
# 56:	learn: 18.2904571	total: 66.8ms	remaining: 50.4ms
# 57:	learn: 18.2404692	total: 67.9ms	remaining: 49.1ms
# 58:	learn: 18.2075764	total: 68.9ms	remaining: 47.9ms
# 59:	learn: 18.1607997	total: 70ms	remaining: 46.7ms
# 60:	learn: 18.1174201	total: 71.1ms	remaining: 45.4ms
# 61:	learn: 18.0769365	total: 72.1ms	remaining: 44.2ms
# 62:	learn: 18.0289605	total: 73.1ms	remaining: 42.9ms
# 63:	learn: 17.9772590	total: 74ms	remaining: 41.6ms
# 64:	learn: 17.9378484	total: 75ms	remaining: 40.4ms
# 65:	learn: 17.8980714	total: 76.3ms	remaining: 39.3ms
# 66:	learn: 17.8542254	total: 77.3ms	remaining: 38.1ms
# 67:	learn: 17.8328169	total: 78.4ms	remaining: 36.9ms
# 68:	learn: 17.7932246	total: 79.5ms	remaining: 35.7ms
# 69:	learn: 17.7616768	total: 80.6ms	remaining: 34.5ms
# 70:	learn: 17.7221024	total: 81.6ms	remaining: 33.3ms
# 71:	learn: 17.6954787	total: 82.7ms	remaining: 32.1ms
# 72:	learn: 17.6747928	total: 83.7ms	remaining: 31ms
# 73:	learn: 17.6359132	total: 84.9ms	remaining: 29.8ms
# 74:	learn: 17.5936212	total: 86ms	remaining: 28.7ms
# 75:	learn: 17.5539122	total: 87.4ms	remaining: 27.6ms
# 76:	learn: 17.5126774	total: 88.6ms	remaining: 26.5ms
# 77:	learn: 17.4682799	total: 89.6ms	remaining: 25.3ms
# 78:	learn: 17.4306165	total: 90.7ms	remaining: 24.1ms
# 79:	learn: 17.4012920	total: 91.8ms	remaining: 22.9ms
# 80:	learn: 17.3743072	total: 92.9ms	remaining: 21.8ms
# 81:	learn: 17.3362817	total: 94ms	remaining: 20.6ms
# 82:	learn: 17.3125294	total: 95.1ms	remaining: 19.5ms
# 83:	learn: 17.2710811	total: 96.2ms	remaining: 18.3ms
# 84:	learn: 17.2448297	total: 97.3ms	remaining: 17.2ms
# 85:	learn: 17.2008766	total: 98.3ms	remaining: 16ms
# 86:	learn: 17.1593776	total: 99.9ms	remaining: 14.9ms
# 87:	learn: 17.1216741	total: 101ms	remaining: 13.8ms
# 88:	learn: 17.0800272	total: 103ms	remaining: 12.7ms
# 89:	learn: 17.0508503	total: 104ms	remaining: 11.6ms
# 90:	learn: 17.0206755	total: 105ms	remaining: 10.4ms
# 91:	learn: 16.9975578	total: 107ms	remaining: 9.29ms
# 92:	learn: 16.9570671	total: 108ms	remaining: 8.14ms
# 93:	learn: 16.9413282	total: 109ms	remaining: 6.97ms
# 94:	learn: 16.9177003	total: 110ms	remaining: 5.8ms
# 95:	learn: 16.8850333	total: 111ms	remaining: 4.64ms
# 96:	learn: 16.8629339	total: 112ms	remaining: 3.48ms
# 97:	learn: 16.8334007	total: 114ms	remaining: 2.32ms
# 98:	learn: 16.7981570	total: 115ms	remaining: 1.16ms
# 99:	learn: 16.7616908	total: 116ms	remaining: 0us
# 0:	learn: 33.1108272	total: 1.78ms	remaining: 176ms
# 1:	learn: 31.6710888	total: 3.4ms	remaining: 167ms
# ...
# 209:	learn: 18.1509130	total: 798ms	remaining: 1.1s
# 210:	learn: 18.1332268	total: 802ms	remaining: 1.1s
# 211:	learn: 18.1145632	total: 805ms	remaining: 1.09s
# 212:	learn: 18.0890733	total: 809ms	remaining: 1.09s
# 213:	learn: 18.0671238	total: 812ms	remaining: 1.08s
# 214:	learn: 18.0427016	total: 816ms	remaining: 1.08s
# 215:	learn: 18.0201625	total: 820ms	remaining: 1.08s
# 216:	learn: 17.9928374	total: 824ms	remaining: 1.07s
# 217:	learn: 17.9686947	total: 829ms	remaining: 1.07s
# 218:	learn: 17.9403571	total: 833ms	remaining: 1.07s
# 219:	learn: 17.9124872	total: 837ms	remaining: 1.06s
# 220:	learn: 17.8810784	total: 841ms	remaining: 1.06s
# 221:	learn: 17.8605947	total: 845ms	remaining: 1.06s
# 222:	learn: 17.8418258	total: 848ms	remaining: 1.05s
# 223:	learn: 17.8178409	total: 852ms	remaining: 1.05s
# 224:	learn: 17.8098978	total: 856ms	remaining: 1.04s
# 225:	learn: 17.7922722	total: 859ms	remaining: 1.04s
# 226:	learn: 17.7652996	total: 863ms	remaining: 1.04s
# 227:	learn: 17.7396420	total: 866ms	remaining: 1.03s
# 228:	learn: 17.7136323	total: 870ms	remaining: 1.03s
# 229:	learn: 17.6871888	total: 874ms	remaining: 1.02s
# 230:	learn: 17.6675376	total: 878ms	remaining: 1.02s
# 231:	learn: 17.6446598	total: 882ms	remaining: 1.02s
# 232:	learn: 17.6164062	total: 886ms	remaining: 1.01s
# 233:	learn: 17.5831069	total: 889ms	remaining: 1.01s
# 234:	learn: 17.5662584	total: 893ms	remaining: 1.01s
# 235:	learn: 17.5423970	total: 897ms	remaining: 1s
# 236:	learn: 17.5306685	total: 901ms	remaining: 1s
# 237:	learn: 17.5033785	total: 905ms	remaining: 996ms
# 238:	learn: 17.4793251	total: 909ms	remaining: 993ms
# 239:	learn: 17.4543427	total: 912ms	remaining: 988ms
# 240:	learn: 17.4417918	total: 917ms	remaining: 985ms
# 241:	learn: 17.4193926	total: 921ms	remaining: 982ms
# 242:	learn: 17.3986021	total: 925ms	remaining: 978ms
# 243:	learn: 17.3890621	total: 929ms	remaining: 974ms
# 244:	learn: 17.3630832	total: 933ms	remaining: 971ms
# 245:	learn: 17.3397187	total: 936ms	remaining: 967ms
# 246:	learn: 17.3178622	total: 941ms	remaining: 964ms
# 247:	learn: 17.3051508	total: 945ms	remaining: 960ms
# 248:	learn: 17.2906110	total: 949ms	remaining: 957ms
# 249:	learn: 17.2697967	total: 953ms	remaining: 953ms
# 250:	learn: 17.2534141	total: 956ms	remaining: 948ms
# 251:	learn: 17.2447465	total: 960ms	remaining: 945ms
# 252:	learn: 17.2226022	total: 964ms	remaining: 941ms
# 253:	learn: 17.2064200	total: 968ms	remaining: 937ms
# 254:	learn: 17.1832441	total: 971ms	remaining: 933ms
# 255:	learn: 17.1653243	total: 975ms	remaining: 929ms
# 256:	learn: 17.1496949	total: 979ms	remaining: 925ms
# 257:	learn: 17.1391145	total: 982ms	remaining: 921ms
# 258:	learn: 17.1121128	total: 986ms	remaining: 918ms
# 259:	learn: 17.0942535	total: 989ms	remaining: 913ms
# 260:	learn: 17.0682497	total: 993ms	remaining: 910ms
# 261:	learn: 17.0492799	total: 997ms	remaining: 906ms
# 262:	learn: 17.0273274	total: 1s	remaining: 902ms
# 263:	learn: 17.0091162	total: 1s	remaining: 899ms
# 264:	learn: 16.9862133	total: 1.01s	remaining: 895ms
# 265:	learn: 16.9670031	total: 1.01s	remaining: 890ms
# 266:	learn: 16.9430941	total: 1.01s	remaining: 886ms
# 267:	learn: 16.9330123	total: 1.02s	remaining: 882ms
# 268:	learn: 16.9042889	total: 1.02s	remaining: 878ms
# 269:	learn: 16.8874547	total: 1.03s	remaining: 875ms
# 270:	learn: 16.8670552	total: 1.03s	remaining: 870ms
# 271:	learn: 16.8518793	total: 1.03s	remaining: 867ms
# 272:	learn: 16.8266502	total: 1.04s	remaining: 863ms
# 273:	learn: 16.8040316	total: 1.04s	remaining: 860ms
# 274:	learn: 16.7774242	total: 1.05s	remaining: 856ms
# 275:	learn: 16.7640135	total: 1.05s	remaining: 853ms
# 276:	learn: 16.7378647	total: 1.05s	remaining: 850ms
# 277:	learn: 16.7166409	total: 1.06s	remaining: 846ms
# 278:	learn: 16.6996755	total: 1.06s	remaining: 842ms
# 279:	learn: 16.6790271	total: 1.07s	remaining: 839ms
# 280:	learn: 16.6591732	total: 1.07s	remaining: 835ms
# 281:	learn: 16.6339444	total: 1.07s	remaining: 831ms
# 282:	learn: 16.6139798	total: 1.08s	remaining: 827ms
# 283:	learn: 16.5961755	total: 1.08s	remaining: 824ms
# 284:	learn: 16.5798791	total: 1.09s	remaining: 820ms
# 285:	learn: 16.5620461	total: 1.09s	remaining: 816ms
# 286:	learn: 16.5360758	total: 1.09s	remaining: 812ms
# 287:	learn: 16.5098080	total: 1.1s	remaining: 809ms
# 288:	learn: 16.4927852	total: 1.1s	remaining: 805ms
# 289:	learn: 16.4764515	total: 1.11s	remaining: 802ms
# 290:	learn: 16.4547201	total: 1.11s	remaining: 798ms
# 291:	learn: 16.4380584	total: 1.11s	remaining: 794ms
# 292:	learn: 16.4153345	total: 1.12s	remaining: 789ms
# 293:	learn: 16.3950413	total: 1.12s	remaining: 785ms
# 294:	learn: 16.3740907	total: 1.12s	remaining: 782ms
# 295:	learn: 16.3560324	total: 1.13s	remaining: 777ms
# 296:	learn: 16.3400026	total: 1.13s	remaining: 774ms
# 297:	learn: 16.3200072	total: 1.14s	remaining: 770ms
# 298:	learn: 16.2951574	total: 1.14s	remaining: 767ms
# 299:	learn: 16.2764365	total: 1.14s	remaining: 763ms
# 300:	learn: 16.2579133	total: 1.15s	remaining: 759ms
# 301:	learn: 16.2419475	total: 1.15s	remaining: 755ms
# 302:	learn: 16.2265127	total: 1.16s	remaining: 751ms
# 303:	learn: 16.2132770	total: 1.16s	remaining: 747ms
# 304:	learn: 16.1950666	total: 1.16s	remaining: 743ms
# 305:	learn: 16.1698781	total: 1.17s	remaining: 739ms
# 306:	learn: 16.1496366	total: 1.17s	remaining: 735ms
# 307:	learn: 16.1279983	total: 1.17s	remaining: 731ms
# 308:	learn: 16.1215907	total: 1.18s	remaining: 727ms
# 309:	learn: 16.1039284	total: 1.18s	remaining: 723ms
# 310:	learn: 16.0896741	total: 1.18s	remaining: 719ms
# 311:	learn: 16.0692966	total: 1.19s	remaining: 715ms
# 312:	learn: 16.0529475	total: 1.19s	remaining: 711ms
# 313:	learn: 16.0277961	total: 1.19s	remaining: 707ms
# 314:	learn: 16.0129418	total: 1.2s	remaining: 704ms
# 315:	learn: 16.0063083	total: 1.2s	remaining: 700ms
# 316:	learn: 15.9880535	total: 1.21s	remaining: 696ms
# 317:	learn: 15.9561491	total: 1.21s	remaining: 693ms
# 318:	learn: 15.9361653	total: 1.21s	remaining: 689ms
# 319:	learn: 15.9168384	total: 1.22s	remaining: 686ms
# 320:	learn: 15.8979061	total: 1.22s	remaining: 682ms
# 321:	learn: 15.8844905	total: 1.23s	remaining: 678ms
# 322:	learn: 15.8664824	total: 1.23s	remaining: 674ms
# 323:	learn: 15.8474976	total: 1.23s	remaining: 670ms
# 324:	learn: 15.8332260	total: 1.24s	remaining: 666ms
# 325:	learn: 15.8135160	total: 1.24s	remaining: 662ms
# 326:	learn: 15.8029923	total: 1.24s	remaining: 658ms
# 327:	learn: 15.7932530	total: 1.25s	remaining: 654ms
# 328:	learn: 15.7717382	total: 1.25s	remaining: 650ms
# 329:	learn: 15.7604630	total: 1.25s	remaining: 646ms
# 330:	learn: 15.7515244	total: 1.26s	remaining: 642ms
# 331:	learn: 15.7382920	total: 1.26s	remaining: 639ms
# 332:	learn: 15.7142200	total: 1.27s	remaining: 635ms
# 333:	learn: 15.7044445	total: 1.27s	remaining: 631ms
# 334:	learn: 15.6862256	total: 1.27s	remaining: 627ms
# 335:	learn: 15.6717713	total: 1.28s	remaining: 623ms
# 336:	learn: 15.6539794	total: 1.28s	remaining: 620ms
# 337:	learn: 15.6366696	total: 1.28s	remaining: 616ms
# 338:	learn: 15.6187855	total: 1.29s	remaining: 612ms
# 339:	learn: 15.6046223	total: 1.29s	remaining: 608ms
# 340:	learn: 15.5879132	total: 1.3s	remaining: 605ms
# 341:	learn: 15.5720886	total: 1.3s	remaining: 601ms
# 342:	learn: 15.5647661	total: 1.3s	remaining: 597ms
# 343:	learn: 15.5457119	total: 1.31s	remaining: 593ms
# 344:	learn: 15.5339814	total: 1.31s	remaining: 589ms
# 345:	learn: 15.5146526	total: 1.31s	remaining: 585ms
# 346:	learn: 15.4956817	total: 1.32s	remaining: 582ms
# 347:	learn: 15.4766390	total: 1.32s	remaining: 578ms
# 348:	learn: 15.4610424	total: 1.33s	remaining: 574ms
# 349:	learn: 15.4463139	total: 1.33s	remaining: 570ms
# 350:	learn: 15.4183124	total: 1.33s	remaining: 566ms
# 351:	learn: 15.4036730	total: 1.34s	remaining: 563ms
# 352:	learn: 15.3879706	total: 1.34s	remaining: 559ms
# 353:	learn: 15.3671760	total: 1.34s	remaining: 555ms
# 354:	learn: 15.3617465	total: 1.35s	remaining: 551ms
# 355:	learn: 15.3547789	total: 1.35s	remaining: 547ms
# 356:	learn: 15.3403873	total: 1.36s	remaining: 543ms
# 357:	learn: 15.3282211	total: 1.36s	remaining: 539ms
# 358:	learn: 15.3147128	total: 1.36s	remaining: 536ms
# 359:	learn: 15.3120096	total: 1.37s	remaining: 532ms
# 360:	learn: 15.3027513	total: 1.37s	remaining: 528ms
# 361:	learn: 15.2779424	total: 1.37s	remaining: 524ms
# 362:	learn: 15.2604849	total: 1.38s	remaining: 520ms
# 363:	learn: 15.2486128	total: 1.38s	remaining: 517ms
# 364:	learn: 15.2379668	total: 1.39s	remaining: 513ms
# 365:	learn: 15.2223077	total: 1.39s	remaining: 509ms
# 366:	learn: 15.2095707	total: 1.39s	remaining: 505ms
# 367:	learn: 15.1937661	total: 1.4s	remaining: 501ms
# 368:	learn: 15.1756422	total: 1.4s	remaining: 498ms
# 369:	learn: 15.1579461	total: 1.41s	remaining: 494ms
# 370:	learn: 15.1426268	total: 1.41s	remaining: 490ms
# 371:	learn: 15.1348146	total: 1.41s	remaining: 486ms
# 372:	learn: 15.1245362	total: 1.42s	remaining: 482ms
# 373:	learn: 15.1075252	total: 1.42s	remaining: 478ms
# 374:	learn: 15.0905657	total: 1.42s	remaining: 475ms
# 375:	learn: 15.0739471	total: 1.43s	remaining: 471ms
# 376:	learn: 15.0625573	total: 1.43s	remaining: 467ms
# 377:	learn: 15.0497326	total: 1.43s	remaining: 463ms
# 378:	learn: 15.0252836	total: 1.44s	remaining: 459ms
# 379:	learn: 15.0108359	total: 1.44s	remaining: 455ms
# 380:	learn: 14.9971153	total: 1.45s	remaining: 451ms
# 381:	learn: 14.9813130	total: 1.45s	remaining: 448ms
# 382:	learn: 14.9640150	total: 1.45s	remaining: 444ms
# 383:	learn: 14.9513559	total: 1.46s	remaining: 440ms
# 384:	learn: 14.9387703	total: 1.46s	remaining: 436ms
# 385:	learn: 14.9258020	total: 1.46s	remaining: 433ms
# 386:	learn: 14.9137161	total: 1.47s	remaining: 429ms
# 387:	learn: 14.9088253	total: 1.47s	remaining: 425ms
# 388:	learn: 14.8904276	total: 1.48s	remaining: 421ms
# 389:	learn: 14.8782109	total: 1.48s	remaining: 417ms
# 390:	learn: 14.8615193	total: 1.48s	remaining: 414ms
# 391:	learn: 14.8443868	total: 1.49s	remaining: 410ms
# 392:	learn: 14.8257813	total: 1.49s	remaining: 406ms
# 393:	learn: 14.8071288	total: 1.49s	remaining: 402ms
# 394:	learn: 14.7936322	total: 1.5s	remaining: 398ms
# 395:	learn: 14.7764756	total: 1.5s	remaining: 394ms
# 396:	learn: 14.7603059	total: 1.5s	remaining: 391ms
# 397:	learn: 14.7420724	total: 1.51s	remaining: 387ms
# 398:	learn: 14.7398178	total: 1.51s	remaining: 383ms
# 399:	learn: 14.7277510	total: 1.52s	remaining: 379ms
# 400:	learn: 14.7128683	total: 1.52s	remaining: 375ms
# 401:	learn: 14.6960460	total: 1.52s	remaining: 371ms
# 402:	learn: 14.6764273	total: 1.53s	remaining: 368ms
# 403:	learn: 14.6582049	total: 1.53s	remaining: 364ms
# 404:	learn: 14.6391822	total: 1.53s	remaining: 360ms
# 405:	learn: 14.6253654	total: 1.54s	remaining: 357ms
# 406:	learn: 14.6093884	total: 1.54s	remaining: 353ms
# 407:	learn: 14.5956952	total: 1.55s	remaining: 349ms
# 408:	learn: 14.5790713	total: 1.55s	remaining: 345ms
# 409:	learn: 14.5581879	total: 1.55s	remaining: 341ms
# 410:	learn: 14.5482576	total: 1.56s	remaining: 338ms
# 411:	learn: 14.5323373	total: 1.56s	remaining: 334ms
# 412:	learn: 14.5155812	total: 1.57s	remaining: 330ms
# 413:	learn: 14.5031932	total: 1.57s	remaining: 326ms
# 414:	learn: 14.4844707	total: 1.57s	remaining: 322ms
# 415:	learn: 14.4731156	total: 1.58s	remaining: 319ms
# 416:	learn: 14.4595047	total: 1.58s	remaining: 315ms
# 417:	learn: 14.4474814	total: 1.58s	remaining: 311ms
# 418:	learn: 14.4322157	total: 1.59s	remaining: 307ms
# 419:	learn: 14.4200957	total: 1.59s	remaining: 303ms
# 420:	learn: 14.4049365	total: 1.6s	remaining: 300ms
# 421:	learn: 14.4028890	total: 1.6s	remaining: 296ms
# 422:	learn: 14.3911305	total: 1.6s	remaining: 292ms
# 423:	learn: 14.3754866	total: 1.61s	remaining: 288ms
# 424:	learn: 14.3639265	total: 1.61s	remaining: 285ms
# 425:	learn: 14.3554145	total: 1.62s	remaining: 281ms
# 426:	learn: 14.3533701	total: 1.62s	remaining: 277ms
# 427:	learn: 14.3392672	total: 1.63s	remaining: 273ms
# 428:	learn: 14.3240032	total: 1.63s	remaining: 270ms
# 429:	learn: 14.3099110	total: 1.63s	remaining: 266ms
# 430:	learn: 14.3003191	total: 1.64s	remaining: 262ms
# 431:	learn: 14.2845380	total: 1.64s	remaining: 258ms
# 432:	learn: 14.2800589	total: 1.64s	remaining: 254ms
# 433:	learn: 14.2667066	total: 1.65s	remaining: 250ms
# 434:	learn: 14.2556988	total: 1.65s	remaining: 247ms
# 435:	learn: 14.2381108	total: 1.65s	remaining: 243ms
# 436:	learn: 14.2264295	total: 1.66s	remaining: 239ms
# 437:	learn: 14.2072444	total: 1.66s	remaining: 235ms
# 438:	learn: 14.1935663	total: 1.66s	remaining: 231ms
# 439:	learn: 14.1781763	total: 1.67s	remaining: 227ms
# 440:	learn: 14.1658313	total: 1.67s	remaining: 224ms
# 441:	learn: 14.1512141	total: 1.68s	remaining: 220ms
# 442:	learn: 14.1334014	total: 1.68s	remaining: 216ms
# 443:	learn: 14.1201095	total: 1.68s	remaining: 212ms
# 444:	learn: 14.1118229	total: 1.69s	remaining: 208ms
# 445:	learn: 14.0920794	total: 1.69s	remaining: 205ms
# 446:	learn: 14.0731337	total: 1.69s	remaining: 201ms
# 447:	learn: 14.0602322	total: 1.7s	remaining: 197ms
# 448:	learn: 14.0464494	total: 1.7s	remaining: 193ms
# 449:	learn: 14.0296801	total: 1.7s	remaining: 189ms
# 450:	learn: 14.0193206	total: 1.71s	remaining: 186ms
# 451:	learn: 14.0017685	total: 1.71s	remaining: 182ms
# 452:	learn: 13.9884005	total: 1.72s	remaining: 178ms
# 453:	learn: 13.9740798	total: 1.72s	remaining: 174ms
# 454:	learn: 13.9626709	total: 1.72s	remaining: 171ms
# 455:	learn: 13.9509220	total: 1.73s	remaining: 167ms
# 456:	learn: 13.9398419	total: 1.73s	remaining: 163ms
# 457:	learn: 13.9248595	total: 1.73s	remaining: 159ms
# 458:	learn: 13.9140590	total: 1.74s	remaining: 155ms
# 459:	learn: 13.9006706	total: 1.74s	remaining: 152ms
# 460:	learn: 13.8904780	total: 1.75s	remaining: 148ms
# 461:	learn: 13.8753443	total: 1.75s	remaining: 144ms
# 462:	learn: 13.8660393	total: 1.75s	remaining: 140ms
# 463:	learn: 13.8562724	total: 1.76s	remaining: 136ms
# 464:	learn: 13.8442903	total: 1.76s	remaining: 133ms
# 465:	learn: 13.8295250	total: 1.77s	remaining: 129ms
# 466:	learn: 13.8141287	total: 1.77s	remaining: 125ms
# 467:	learn: 13.8056535	total: 1.77s	remaining: 121ms
# 468:	learn: 13.7844024	total: 1.78s	remaining: 118ms
# 469:	learn: 13.7681491	total: 1.78s	remaining: 114ms
# 470:	learn: 13.7563834	total: 1.79s	remaining: 110ms
# 471:	learn: 13.7406713	total: 1.79s	remaining: 106ms
# 472:	learn: 13.7227335	total: 1.79s	remaining: 102ms
# 473:	learn: 13.7139463	total: 1.8s	remaining: 98.7ms
# 474:	learn: 13.6952894	total: 1.8s	remaining: 94.9ms
# 475:	learn: 13.6832152	total: 1.81s	remaining: 91.1ms
# 476:	learn: 13.6689246	total: 1.81s	remaining: 87.3ms
# 477:	learn: 13.6569359	total: 1.81s	remaining: 83.5ms
# 478:	learn: 13.6382662	total: 1.82s	remaining: 79.7ms
# 479:	learn: 13.6210918	total: 1.82s	remaining: 75.9ms
# 480:	learn: 13.5983841	total: 1.82s	remaining: 72.1ms
# 481:	learn: 13.5881569	total: 1.83s	remaining: 68.3ms
# 482:	learn: 13.5708054	total: 1.83s	remaining: 64.5ms
# 483:	learn: 13.5623516	total: 1.84s	remaining: 60.7ms
# 484:	learn: 13.5503500	total: 1.84s	remaining: 56.9ms
# 485:	learn: 13.5407851	total: 1.84s	remaining: 53.1ms
# 486:	learn: 13.5202593	total: 1.85s	remaining: 49.3ms
# 487:	learn: 13.5164992	total: 1.85s	remaining: 45.5ms
# 488:	learn: 13.5009863	total: 1.85s	remaining: 41.7ms
# 489:	learn: 13.4837232	total: 1.86s	remaining: 37.9ms
# 490:	learn: 13.4748849	total: 1.86s	remaining: 34.1ms
# 491:	learn: 13.4627789	total: 1.86s	remaining: 30.3ms
# 492:	learn: 13.4495494	total: 1.87s	remaining: 26.5ms
# 493:	learn: 13.4322820	total: 1.87s	remaining: 22.7ms
# 494:	learn: 13.4205246	total: 1.88s	remaining: 19ms
# 495:	learn: 13.4069190	total: 1.88s	remaining: 15.2ms
# 496:	learn: 13.4010086	total: 1.88s	remaining: 11.4ms
# 497:	learn: 13.3906506	total: 1.89s	remaining: 7.59ms
# 498:	learn: 13.3807261	total: 1.89s	remaining: 3.79ms
# 499:	learn: 13.3787097	total: 1.9s	remaining: 0us
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=<catboost.core.CatBoostRegressor object at 0x00000119CB47DA90>,
#                    param_distributions={'depth': [4, 6, 8],
#                                         'iterations': [100, 500, 1000],
#                                         'l2_leaf_reg': [1, 3, 5],
#                                         'learning_rate': [0.01, 0.05, 0.1],
#                                         'random_strength': [0.1, 0.5, 1]},
#                    random_state=42)

# %%
# сделаем предсказание на тренировочной выборке

y_train_pred_3 = rs_3.predict(X_train)

# %%
# посчитаем метрику RMSE

rmse_train_3 = mean_squared_error(y_train, y_train_pred_3, squared=False)

# %%
# выведем результат на экран

print('RMSE на тренировочной выборке:', rmse_train_3)
# Out:
# RMSE на тренировочной выборке: 13.378709717244144

# %% [markdown]
# ---
#
# <div style="background-color: rgba(255, 255, 255, 0.8); padding: 20px; font-size: 25px; color: rgba(28, 28, 28, 1);">
# Выбор лучшей модели
# </div>
#
# ---

# %%
# создадим таблицу, чтобы визуализировать разницу моделей

result = {
    'model': ['linear_regression', 'decision_tree_regressor', 'cat_boost_regressor'],
    'rmse_train': [rmse_train_1, rmse_train_2, rmse_train_3]}

models = pd.DataFrame(result)

# %%
# оценим итоговый результат

models.set_index('model')
# Out:
#                          rmse_train
# model
# linear_regression         23.286511
# decision_tree_regressor   21.591714
# cat_boost_regressor       13.378710

# %% [markdown]
# <div style="border: 1px solid rgba(0, 0, 0, 0.2); border-radius: 10px; background-color: rgba(255, 255, 255, 0.8); padding: 10px;">
#
# Под главный критерий задачи подходят все три модели, но лучшей из них является `CatBoostRegressor` с метрикой RMSE, равной ~13.4
#
# </div>

# %% [markdown]
# ---
#
# <div style="background-color: rgba(255, 255, 255, 0.8); padding: 20px; font-size: 25px; color: rgba(28, 28, 28, 1);">
# Тестирование лучшей модели
# </div>
#
# ---

# %%
# выполним предсказание лучшей модели на тестовой выборке

y_test_pred_3 = rs_3.predict(X_test)

# %%
# вычислим метрику RMSE на тестовых данных

rmse_test_3 = mean_squared_error(y_test, y_test_pred_3, squared=False)
print(f"Среднеквадратичная ошибка (RMSE) на тестовой выборке: {rmse_test_3}")
# Out:
# Среднеквадратичная ошибка (RMSE) на тестовой выборке: 38.81889270290209

# %% [markdown]
# *RMSE* на тестовой выборке отвечает главному критерию задачи — целевая метрика должна быть меньше 48

# %%
# выведем на экран лучшие параметры модели

print('Лучшие параметры модели CatBoostRegressor:')
print(' ')
print(rs_3.best_params_)
# Out:
# Лучшие параметры модели CatBoostRegressor:
#
# {'random_strength': 1, 'learning_rate': 0.05, 'l2_leaf_reg': 1, 'iterations': 500, 'depth': 6}

# %% [markdown]
# Инициализируем и обучим модель DummyRegressor, а затем сравним её метрику с метрикой нашей лучшей модели, чтобы оценить адекватность проделанной работы. DummyRegressor предсказывает средние значения, и если его метрики будут выше метрик нашей модели, это будет значить, что даже эта базовая модель работает лучше, а получившаяся модель `CatBoostRegressor` не принесёт пользы

# %%
def dummy_regressor_test(best_model_name):
    
    """
    Функция dummy_regressor_test инициализирует модель Dummy Regressor,
    обучает её на тренировочной выборке, выполняет предсказания на тестовой выборке,
    вычисляет метрику RMSE, а затем строит сравнительную таблицу для тестовых значений
    лучшей модели и модели Dummy Regressor 
    
    Аргументы:
    best_model_name (str) : название лучшей модели
    
    Возвращает:
    dummy_result (DataFrame) : таблица со сравнительным результатом
    
    """
    
    dummy = DummyRegressor(strategy='mean')
    dummy.fit(X_train, y_train)
    dummy_pred = dummy.predict(X_test)
    dummy_rmse = mean_squared_error(y_test, dummy_pred, squared=False)
    
    dummy_result = {
        'model': [best_model_name, 'dummy_regressor'],
        'RMSE': [rmse_test_3, dummy_rmse]
    }
    
    dummy_result = pd.DataFrame(dummy_result)
    
    return dummy_result

# %%
# применим функцию dummy_regressor_test

dummy_result = dummy_regressor_test('cat_boost_regressor')

# оценим результат

dummy_result
# Out:
#                  model       RMSE
# 0  cat_boost_regressor  38.818893
# 1      dummy_regressor  84.589229

# %% [markdown]
# <div style="border: 1px solid rgba(0, 0, 0, 0.2); border-radius: 10px; background-color: rgba(255, 255, 255, 0.8); padding: 10px;">
#
# Проверка прошла успешно: очевидно, наша лучшая модель не является бесполезной. Чем метрика RMSE ниже, тем лучше — а у DummyRegressor она гораздо выше
#
# </div>

# %%
# сравним реальные значения с предсказанными

y_test_pred_3 = pd.Series(y_test_pred_3, index=y_test.index)

plt.figure(figsize=(15, 5))

plt.plot(y_test['2018-08-20':'2018-08-25'], label='Реальные значения')
plt.plot(y_test_pred_3['2018-08-20':'2018-08-25'], label='Предсказанные значения', color='crimson')

plt.xlabel('Дата и время')
plt.ylabel('Число заказов')
plt.title('Cравнение реальных и предсказанных значений за 5 суток', fontsize=16)

plt.legend()
plt.show()

# %% [markdown]
# <div style="border: 1px solid rgba(0, 0, 0, 0.2); border-radius: 10px; background-color: rgba(255, 255, 255, 0.8); padding: 10px;">
#
# Видим на графике, что слабое место модели — это резкие взлёты и падения в количестве заказов. То есть, модель хуже справится с ситуацией, когда внезапное изменение погоды или ещё какой-то непредвиденный фактор приведут к резкому возрастанию спроса на такси
#
# </div>

# %% [markdown]
# ---
#
# <div style="background-color: rgba(255, 255, 255, 0.8); padding: 20px; font-size: 25px; color: rgba(28, 28, 28, 1);">
# Общий вывод
# </div>
#
# ---

# %% [markdown]
# В ходе подготовки данных были подробно изучены сами данные, основные тенденции в них, тренды и сезонность. Созданы новые признаки на основе столбца `num_orders` — *календарные признаки*, такие как месяц, день месяца и день недели, а также *«отстающие значения»* и *скользящее среднее*
#
# Были обучены следующие модели: `LinearRegression`, `DeciisionTreeRegressor` и `CatBoostRegressor`. По итогам обучения лучшей оказалась модель `CatBoostRegressor` со следующими гиперпараметрами:
#
# - `random_strength`: 0.1
# - `learning_rate`: 0.05
# - `l2_leaf_reg`: 5
# - `iterations`: 500
# - `depth`: 6
#
# Лучшая модель имеет следующие значения RMSE:
#
# - `RMSE на тренировочной выборке`: 13.378709717244144
# - `RMSE на тестовой выборке`: 38.81889270290209
#
# Лучшая модель также прошла проверку на адекватность, совершённую с помощью константной модели `Dummy Regressor`:
#
# - `RMSE на тестовой выборке для модели CatBoostRegressor`: 38.818893
# - `RMSE на тестовой выборке для модели DummyRegressor`: 84.589229

# %% [markdown]
# ---
