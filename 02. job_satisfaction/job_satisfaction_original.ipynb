# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Александра, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Комментарий ревьюера </b>
#
# Александра, обрати внимание, что твой код упал с ошибкой при загрузке из альтернативного источника - в этом случае используются некорректные имена переменных, которые далее не используются в проекте.
#
# Убедись, пожалуйста, что оба способа загрузки данных работают, чтобы мы смогли продолжить работу над проектом.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Прошу прощения за такую ошибку. Исправила.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ничего, поехали:)

# %% [markdown]
# # `Разработка моделей МО для предотвращения оттока сотрудников`

# %% [markdown]
# ## Общая информация о проекте

# %% [markdown]
# ### Описание проекта, цели и задачи

# %% [markdown]
# Компания «Работа с заботой» предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
#
# Основной задачей проекта является разработка предложения, которое поможет компании избежать финансовых потерь и оттока сотрудников; разработка двух моделей машинного обучения, которые прогнозируют уровень удовлетворённости сотрудника и его увольнение.

# %% [markdown]
# ### План выполнения работы

# %% [markdown]
# `Задача 1. Предсказание уровня удовлетворённости сотрудника`
# Построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
# Почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
#
# `Задача 2. Предсказание увольнения сотрудника из компании`
# Построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.
#
# Для каждой из двух задач выполняются следующие шаги:
# - Загрузка и предварительное изучение данных
# - Предобработка данных
# - Исследовательский анализ данных
# - Корреляционный анализ данных
# - Подготовка данных
# - Обучение моделей
#
# Общий вывод по обоим шагам завершает проект.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %% [markdown]
# ## Импорт библиотек, описание функций

# %%
# установка необходимой версии sklearn

# !pip install scikit-learn==1.1.3 -q

# !pip install scikit-learn -q

# %%
#!pip install --upgrade scikit-learn -q

# %%
# установка модуля phik

#!pip install phik -q

# %%
# установка модуля shap

#!pip install shap -q

# %%
# обновление seaborn

#!pip install --upgrade seaborn -q

# %%
# импорт библиотек

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

#import shap
import phik

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.dummy import DummyRegressor

from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import  SimpleImputer

from sklearn.metrics import roc_auc_score, f1_score, mean_squared_error
from sklearn.metrics import make_scorer

from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import LabelEncoder

from IPython.display import display

# %%
# константа

RANDOM_STATE = 42

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %%
# функция preprocess

def preprocess(df):

    # подсчёт количества дубликатов и, если они присутствуют, удаление
    duplicates_count = df.duplicated().sum()
    print(f'Дубликатов найдено: {duplicates_count}')
    if duplicates_count > 0:
        df.drop_duplicates(inplace=True)
        print(f'Дубликатов удалено: {data.duplicated().sum()}')
    print(' ')

    # подсчёт пропусков в каждом столбце
    for col in df.columns:
        nan_count = df[col].isnull().sum()
        if nan_count > 0:
            print(f'Пропусков найдено в столбце {col}: {nan_count}')
    print(' ')

    # проверка на наличие неявных дубликатов
    cat_cols = df.select_dtypes(include=['object']).columns
    for col in cat_cols:
        unique_values = df[col].unique()
        print(f'Уникальные значения в столбце {col}: {unique_values}')

# %%
# функция barplot принимает на входе датафрейм, столбец-признак и название оси x

def barplot(data, column, xlabel, title):

    plt.figure(figsize=(9, 6))
    data_new = data[column].value_counts()
    data_new_ = data_new.reset_index()
    data_new_.columns = [column, 'count']
    sns.barplot(x=column, y='count', data=data_new_, hue=column, legend=False)

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Частота')

    plt.show()

# %%
# функция histogram принимает на входе датафрейм, столбец-признак, название оси x и количество корзин для гистограммы

def histogram(data, column, xlabel, title, bins):

    plt.figure(figsize=(9, 6))
    sns.set()
    sns.histplot(data=data, x=column, kde=True, bins=bins)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Количество людей')

    plt.show()

# %%
# функция violinplot принимает на входе датафрейм, столбец-признак, название оси y и название графика

def violinplot(data, column, ylabel, title):

    plt.figure(figsize=(9, 6))
    sns.violinplot(data=data, y=column).set(title=title, xlabel=' ', ylabel=ylabel)
    sns.cubehelix_palette(start=.5, rot=-.5, as_cmap=True)

    plt.show()

# %%
# функция paired_boxplot принимает на входе датафрейм, два столбца, подписи осей х и у и название графика

def paired_boxplot(data, column_1, column_2, xlabel, ylabel, title):

    plt.figure(figsize=(9, 6))
    sns.boxplot(x=column_1, y=column_2, data=data, color='#B0E0E6')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    plt.show()

# %%
# функция paired_violins принимает на входе два датафрейма, столбец и название графика
# выводит парные скрипичные диаграммы

def paired_violins(data_1, data_2, col, title):

    fig, ax = plt.subplots(1, 2, figsize=(15, 6))
    sns.violinplot(x=data_1[col], ax=ax[0], color='#B0E0E6')
    ax[0].set_title('Тренировочная выборка')
    ax[0].set_ylabel('Количество людей')

    sns.violinplot(x=data_2[col], ax=ax[1], color='#B0E0E6')
    ax[1].set_title('Тестовая выборка')
    ax[1].set_ylabel('Количество людей')

    ax_title = fig.add_axes([0.5, -0.1, 0.1, 0.1])
    ax_title.set_axis_off()
    ax_title.text(0, 0, title, ha='center', va='center', fontsize=16)

    plt.show()

# %%
# функция hist_norm принимает на входе датафрейм, столбец-признак, название оси x и количество корзин для гистограммы

def hist_norm(data, column, xlabel, title, bins):

    plt.figure(figsize=(9, 6))
    sns.set()
    sns.histplot(data=data, x=column, kde=True, bins=bins, stat='density', common_norm=False)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Плотность распределения')

    plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Привет. Это первый комментарий, который увидишь,но не первый, который я написала. Поэтому здороваюсь 2 раза. Можно ли попросить объяснить, как в этой функции для парных скрипичных диаграмм изменить их ориентацию? Ниже в исследовательском анализе данных я построила пару графиков (для столбца employment_years, например) с помощью этой функции и можно увидеть, что она непривычно повёрнута горизонтально. Пыталась передать sns.violinplot параметр orient='v', но была ошибка, что указана только ось X.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> При использовании параметра `orient='v'` данные нужно передавать не в `x`, а в `y`.

# %%
# функция phik принимает на входе датафрейм и переменную с непрерывными столбцами
# возвращает матрицу корреляции phik

def phik(data, interval_cols):

    phik_matrix = data.phik_matrix(interval_cols=interval_cols)
    cmap = sns.color_palette("ch:start=.2,rot=-.3", as_cmap=True)

    plt.figure(figsize=(10, 9))
    sns.heatmap(phik_matrix, annot=True, cmap=cmap, center=0, square=True, linewidths=.5)
    plt.xticks(rotation=60)
    plt.title(r'Матрица корреляции $\phi_K$')

    plt.show()

# %%
# функция paired_barplots принимает на входе два датафрейма, столбец и название графика
# выводит парные столбчатые диаграммы

def paired_barplots(data_1, data_2, col, title):

    fig, ax = plt.subplots(1, 2, figsize=(15, 6))

    (data_1[col].value_counts(normalize=True)*100).plot(kind='bar', ax=ax[0], color='#CD5C5C')
    ax[0].set_title('Уволившиеся сотрудники')
    ax[0].set_ylabel('Процент сотрудников')

    (data_2[col].value_counts(normalize=True)*100).plot(kind='bar', ax=ax[1], color='#9ACD32')
    ax[1].set_title('Сотрудники, которые не уволились')
    ax[1].set_ylabel('Процент сотрудников')

    ax_title = fig.add_axes([0.5, -0.1, 0.1, 0.1])
    ax_title.set_axis_off()
    ax_title.text(0, 0, title, ha='center', va='center', fontsize=16)

    plt.show()

# %%
# функция для вычисления метрики SMAPE

def smape(y_test, pred):
    error = abs(y_test - pred)
    scale = (abs(y_test) + abs(pred)) / 2 + 0.000000001
    result = 100 * (error / scale).mean()
    return result

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> А зачем мы тут прибавляем `0.000000001`?

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> В чате писали так: в знаменатель нужно добавить +0.00000001 чтобы не было деления на ноль
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Нулевых значений у нас нет, поэтому действите лишнее. Но окей, перестраховка не помешает:)

# %%
# функция paired_violins принимает на входе два датафрейма, столбец и название графика
# выводит парные скрипичные диаграммы

def paired_violins_quit(data_1, data_2, col, title):

    fig, ax = plt.subplots(1, 2, figsize=(15, 6))
    sns.violinplot(x=data_1[col], ax=ax[0], color='#B0E0E6')
    ax[0].set_title('Уволившиеся сотрудники')
    ax[0].set_ylabel('Количество людей')

    sns.violinplot(x=data_2[col], ax=ax[1], color='#B0E0E6')
    ax[1].set_title('Сотрудники, которые не уволились')
    ax[1].set_ylabel('Количество людей')

    ax_title = fig.add_axes([0.5, -0.1, 0.1, 0.1])
    ax_title.set_axis_off()
    ax_title.text(0, 0, title, ha='center', va='center', fontsize=16)

    plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Здорово, что функции вынесены в начало проекта.

# %% [markdown]
# ## Задача 1. Предсказание уровня удовлетворённости сотрудника

# %% [markdown]
# ### Загрузка и предварительное изучение данных

# %% [markdown]
# Для этой задачи заказчик предоставил данные с признаками:
#
# - `id` — уникальный идентификатор сотрудника
# - `dept` — отдел, в котором работает сотрудник
# - `level` — уровень занимаемой должности
# - `workload` — уровень загруженности сотрудника
# - `employment_years` — длительность работы в компании (в годах)
# - `last_year_promo` — показывает, было ли повышение за последний год
# - `last_year_violations` — показывает, нарушал ли сотрудник трудовой договор за последний год
# - `supervisor_evaluation` — оценка качества работы сотрудника, которую дал руководитель
# - `salary` — ежемесячная зарплата сотрудника
# - `job_satisfaction_rate` — уровень удовлетворённости сотрудника работой в компании, целевой признак

# %%
# загрузка данных

try:
    train_data = pd.read_csv('/datasets/train_job_satisfaction_rate.csv', sep = ',', decimal='.')
    test_features = pd.read_csv('/datasets/test_features.csv', sep = ',', decimal='.')
    test_target = pd.read_csv('/datasets/test_target_job_satisfaction_rate.csv', sep = ',', decimal='.')
except:
    train_data = pd.read_csv('https://code.s3.yandex.net/datasets/train_job_satisfaction_rate.csv', sep = ',', decimal='.')
    test_features = pd.read_csv('https://code.s3.yandex.net/datasets/test_features.csv', sep = ',', decimal='.')
    test_target = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_job_satisfaction_rate.csv', sep = ',', decimal='.')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Данные загрузили - отлично!
#
# Здорово, что ты используешь конструкцию ``try-except`` для путей файлов. Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных задать индекс-столбец- за это действие отвечает параметр `index_col`.

# %%
# изучим таблицу train_data

display(train_data.head(), train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# ...

# %% [markdown]
# - таблица содержит 4000 строк и 10 столбцов
# - данные содержат все 10 признаков
# - обнаружены пропуски в столбцах `dept` и `level`

# %%
# изучим таблицу test_features

display(test_features.head(), test_features.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# ...

# %% [markdown]
# - таблица содержит 2000 строк и 9 столбцов
# - в таблице перечислены все входные признаки, но не целевой
# - обнаружены пропуски в столбцах `dept` и `level`, как и в предыдущей таблице

# %%
# изучим таблицу test_target

display(test_target.head(), test_target.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08
# None

# %% [markdown]
# - таблица содержит 2000 строк и 2 cтолбца
# - таблица состоит из одного целевого признака

# %% [markdown]
# **Загруженные данные соответствуют описанию, типы данных во всех трёх таблицах определены верно. Названия столбцов не требуют переименования.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Первичный осмотр данных выполнен.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### `train_data`

# %%
# применим функцию preprocess

preprocess(train_data)
# Out:
# Дубликатов найдено: 0
#
# Пропусков найдено в столбце dept: 6
# Пропусков найдено в столбце level: 4
#
# Уникальные значения в столбце dept: ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan]
# Уникальные значения в столбце level: ['junior' 'middle' 'sinior' nan]
# Уникальные значения в столбце workload: ['medium' 'high' 'low']
# Уникальные значения в столбце last_year_promo: ['no' 'yes']
# Уникальные значения в столбце last_year_violations: ['no' 'yes']

# %%
# заменим ошибку в столбце level

train_data['level'].replace('sinior', 'senior', inplace=True)

# %%
# проверим результат

train_data['level'].unique()
# Out:
# array(['junior', 'middle', 'senior', nan], dtype=object)

# %% [markdown]
# #### `test_features`

# %%
# применим функцию preprocess

preprocess(test_features)
# Out:
# Дубликатов найдено: 0
#
# Пропусков найдено в столбце dept: 2
# Пропусков найдено в столбце level: 1
#
# Уникальные значения в столбце dept: ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
# Уникальные значения в столбце level: ['junior' 'middle' 'sinior' nan]
# Уникальные значения в столбце workload: ['medium' 'low' 'high' ' ']
# Уникальные значения в столбце last_year_promo: ['no' 'yes']
# Уникальные значения в столбце last_year_violations: ['no' 'yes']

# %%
# заменим аналогичную ошибку в столбце level

test_features['level'].replace('sinior', 'senior', inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что заметила эту ошибку.

# %%
# заменим пробелы в значениях на значения nan для последующей обработки

test_features['dept'].replace(' ', np.nan, inplace=True)
test_features['workload'].replace(' ', np.nan, inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Аномалия обработана корректно. В целом она могла бы быть обработана и в `Pipeline`, при настройке энкодеров на обработку новых значений признаков, которые не были на момент обучения энкодера.

# %%
# проверим результат

display(test_features['level'].unique(), test_features['dept'].unique(), test_features['workload'].unique())
# Out:
# array(['junior', 'middle', 'senior', nan], dtype=object)
# array(['marketing', 'hr', 'sales', 'purchasing', 'technology', nan],
#       dtype=object)
# array(['medium', 'low', 'high', nan], dtype=object)

# %% [markdown]
# #### `test_target`

# %%
# проверим таблицу на наличие дубликатов

print(f'Дубликатов найдено: {test_target.duplicated().sum()}')
# Out:
# Дубликатов найдено: 0

# %% [markdown]
# **Предобработка данных завершена. Дубликатов в данных нет, ошибки в значениях столбцов устранены, пробелы заменены на NaN. Обработка пропусков будет произведена в пайплайне.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# С предобработкой порядок.

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### `dept`

# %%
# выведем на экран числовое распределение данных

print(f'Распределение данных в столбце dept в таблице train_data:')
print(' ')
print(train_data['dept'].value_counts())
print(' ')

print(f'Распределение данных в столбце dept в таблице test_features:')
print(' ')
print(test_features['dept'].value_counts())
# Out:
# Распределение данных в столбце dept в таблице train_data:
#
# dept
# sales         1512
# technology     866
# purchasing     610
# marketing      550
# hr             456
# Name: count, dtype: int64
#
# Распределение данных в столбце dept в таблице test_features:
#
# dept
# sales         763
# technology    455
# marketing     279
# purchasing    273
# hr            227
# Name: count, dtype: int64

# %%
# построим пару столбчатых диаграмм для таблиц train_data и test_features

barplot(
    train_data, 'dept',
    'Отдел, в котором работает сотрудник',
    'Столбец dept в тренировочной выборке'
),
barplot(
    test_features, 'dept',
    'Отдел, в котором работает сотрудник',
    'Столбец dept в тестовой выборке'
)

# %% [markdown]
# Если в тренировочной выборке отдел `purchasing` находится на третьем месте по численности сотрудников, а `marketing` - на четвёртом, то в тестовой выборке они поменялись местами. В остальном распределение людей по отделам идентично. Так, больше всего сотрудников сосредоточены в отделе продаж, на втором месте — отдел технологий, на последнем — HR.

# %% [markdown]
# #### `level`

# %%
# выведем на экран числовое распределение данных

print(f'Распределение данных в столбце level в таблице train_data:')
print(' ')
print(train_data['level'].value_counts())
print(' ')

print(f'Распределение данных в столбце level в таблице test_features:')
print(' ')
print(test_features['level'].value_counts())
# Out:
# Распределение данных в столбце level в таблице train_data:
#
# level
# junior    1894
# middle    1744
# senior     358
# Name: count, dtype: int64
#
# Распределение данных в столбце level в таблице test_features:
#
# level
# junior    974
# middle    854
# senior    171
# Name: count, dtype: int64

# %%
# построим пару столбчатых диаграмм для таблиц train_data и test_features

barplot(
    train_data, 'level',
    'Уровень занимаемой должности',
    'Столбец level в тренировочной выборке'
),
barplot(
    test_features, 'level',
    'Уровень занимаемой должности',
    'Столбец level в тестовой выборке'
)

# %% [markdown]
# Эти графики показывают распределение сотрудников по уровню занимаемой должности. Так, в обеих выборках большую часть сотрудников ожидаемо составляют джуниоры, на втором месте (с не очень большим отрывом) находятся миддлы, в третьей же группе — самые опытные сотрудники, и их число не превышает 8% для каждой из выборок.

# %% [markdown]
# #### `workload`

# %%
# выведем на экран числовое распределение данных

print(f'Распределение данных в столбце workload в таблице train_data:')
print(' ')
print(train_data['workload'].value_counts())
print(' ')

print(f'Распределение данных в столбце workload в таблице test_features:')
print(' ')
print(test_features['workload'].value_counts())
# Out:
# Распределение данных в столбце workload в таблице train_data:
#
# workload
# medium    2066
# low       1200
# high       734
# Name: count, dtype: int64
#
# Распределение данных в столбце workload в таблице test_features:
#
# workload
# medium    1043
# low        593
# high       363
# Name: count, dtype: int64

# %%
# построим пару столбчатых диаграмм для таблиц train_data и test_features

barplot(
    train_data, 'workload',
    'Уровень загруженности сотрудника',
    'Столбец workload в тренировочной выборке'
),
barplot(
    test_features, 'workload',
    'Уровень загруженности сотрудника',
    'Столбец workload в тестовой выборке'
)

# %% [markdown]
# Видим, что около 50% в каждой выборке составляют сотрудники со средним уровнем занятости. Чуть меньше — люди с низким уровнем загруженности. Высокий уровень загруженности имеет самая малочисленная группа сотрудников. Интересно было бы посмотреть, есть ли взаимосвязь между уровнем загруженности сотрудника, его опытностью и количеством лет, проведённых в компании.

# %% [markdown]
# #### `employment_years`

# %%
# выведем на экран числовое описание данных

print('Числовое описание столбца supervisor_evaluation в таблице train_data:')
print(' ')
print(train_data['employment_years'].describe())
print(' ')

print('Числовое описание столбца supervisor_evaluation в таблице test_features:')
print(' ')
print(test_features['employment_years'].describe())
# Out:
# Числовое описание столбца supervisor_evaluation в таблице train_data:
#
# count    4000.000000
# mean        3.718500
# std         2.542513
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64
#
# Числовое описание столбца supervisor_evaluation в таблице test_features:
#
# count    2000.000000
# mean        3.666500
# std         2.537222
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64

# %% [markdown]
# В двух выборках немного различается граница первого квартиля, отделяющего 25% данных — в тренировочной выборке он равен 2, а в тестовой — 1. Из этого следует, что первая выборка содержит в себе больше сотрудников, проработавших в компании два и более года, нежели вторая выборка. В среднем же сотрудники компании трудоустроились чуть больше трёх лет назад.

# %%
# построим пару столбчатых диаграмм для таблиц train_data и test_features

barplot(
    train_data, 'employment_years',
    'Длительность работы в компании, кол-во лет',
    'Столбец employment_years в тренировочной выборке'
),
barplot(
    test_features, 'employment_years',
    'Длительность работы в компании, кол-во лет',
    'Столбец employment_years в тестовой выборке'
)

# %%
# построим пару скрипичных диаграмм для таблиц train_data и test_features

paired_violins(train_data, test_features, 'employment_years', 'Длительность работы в компании, кол-во лет')

# %%
# построим пару скрипичных диаграмм для таблиц train_data и test_features

# violinplot(
#    train_data, 'employment_years',
#    'Длительность работы в компании, кол-во лет',
#    'Столбец employment_years в тренировочной выборке'
# )

# violinplot(
#    test_features, 'employment_years',
#    'Длительность работы в компании, кол-во лет',
#    'Столбец employment_years в тестовой выборке'
# )

# %% [markdown]
# Снова видим, что в тестовой выборке данные, находящиеся посередине шкалы, немного отличаются от тренировочных данных. Большую часть сотрудников составляют люди, проработавшие в компании от одного до трёх лет. Является ли такой показатель следствием масштабного набора сотрудников в последние три года или же высокой текучкой — неизвестно. Можно точно сказать, что сотрудники, проработавшие больше пяти лет, уже имеют определённый уровень лояльности к компании и, оптимистично предположим, высокий уровень удовлетворённости от работы.

# %% [markdown]
# #### `last_year_promo`

# %%
# выведем на экран числовое распределение данных

print(f'Распределение данных в столбце last_year_promo в таблице train_data:')
print(' ')
print(train_data['last_year_promo'].value_counts())
print(' ')

print(f'Распределение данных в столбце last_year_promo в таблице test_features:')
print(' ')
print(test_features['last_year_promo'].value_counts())
# Out:
# Распределение данных в столбце last_year_promo в таблице train_data:
#
# last_year_promo
# no     3880
# yes     120
# Name: count, dtype: int64
#
# Распределение данных в столбце last_year_promo в таблице test_features:
#
# last_year_promo
# no     1937
# yes      63
# Name: count, dtype: int64

# %%
# построим пару столбчатых диаграмм для таблиц train_data и test_features

barplot(
    train_data, 'last_year_promo',
    'Было ли повышение за последний год',
    'Столбец last_year_promo в тренировочной выборке'
),
barplot(
    test_features, 'last_year_promo',
    'Было ли повышение за последний год',
    'Столбец last_year_promo в тестовой выборке'
)

# %% [markdown]
# В каждой из выборок процент сотрудников, получивших повышение, не превышает 3%.

# %% [markdown]
# #### `last_year_violations`

# %%
# выведем на экран числовое распределение данных

print(f'Распределение данных в столбце last_year_violations в таблице train_data:')
print(' ')
print(train_data['last_year_violations'].value_counts())
print(' ')

print(f'Распределение данных в столбце last_year_violations в таблице test_features:')
print(' ')
print(test_features['last_year_violations'].value_counts())
# Out:
# Распределение данных в столбце last_year_violations в таблице train_data:
#
# last_year_violations
# no     3441
# yes     559
# Name: count, dtype: int64
#
# Распределение данных в столбце last_year_violations в таблице test_features:
#
# last_year_violations
# no     1738
# yes     262
# Name: count, dtype: int64

# %%
# построим пару столбчатых диаграмм для таблиц train_data и test_features

barplot(
    train_data, 'last_year_violations',
    'Нарушал ли сотрудник трудовой договор за последний год',
    'Столбец last_year_violations в тренировочной выборке'
),
barplot(
    test_features, 'last_year_violations',
    'Нарушал ли сотрудник трудовой договор за последний год',
    'Столбец last_year_violations в тестовой выборке'
)

# %% [markdown]
# 13% сотрудников за последний год хотя бы раз нарушали трудовой договор. Интересно было бы взглянуть, коррелирует ли нарушение договора с низким уровнем удовлетворённости работой.

# %% [markdown]
# #### `supervisor_evaluation`

# %%
# выведем на экран числовое распределение данных

print('Распределение данных в столбце supervisor_evaluation в таблице train_data:')
print(' ')
print(train_data['supervisor_evaluation'].value_counts())
print(' ')

print('Распределение данных в столбце supervisor_evaluation в таблице test_features:')
print(' ')
print(test_features['supervisor_evaluation'].value_counts())
# Out:
# Распределение данных в столбце supervisor_evaluation в таблице train_data:
#
# supervisor_evaluation
# 4    1603
# 3    1263
# 5     546
# 2     387
# 1     201
# Name: count, dtype: int64
#
# Распределение данных в столбце supervisor_evaluation в таблице test_features:
#
# supervisor_evaluation
# 4    857
# 3    575
# 5    284
# 2    196
# 1     88
# Name: count, dtype: int64

# %%
# построим пару столбчатых диаграмм для таблиц train_data и test_features

barplot(
    train_data, 'supervisor_evaluation',
    'Оценка качества работы сотрудника, данная руководителем',
    'Столбец supervisor_evaluation в тренировочной выборке'
),
barplot(
    test_features, 'supervisor_evaluation',
    'Оценка качества работы сотрудника, данная руководителем',
    'Столбец supervisor_evaluation в тестовой выборке'
)

# %% [markdown]
# Данные в обеих выборках распределены совершенно одинаково. Так, работу большинства сотрудников руководители оценивают на четвёрку и тройку, и лишь малый процент людей получает самую высокую или самые низкие оценки. Здесь также было бы интересно взглянуть, есть ли взаимосвязь между качеством работы сотрудника и его удовлетворённостью. Это показало бы и объективность оценок, данных руководителем.

# %%
# построим пару скрипичных диаграмм для таблиц train_data и test_features

paired_violins(train_data, test_features, 'supervisor_evaluation', 'Оценка качества работы сотрудника, данная руководителем')

# %%
# построим пару скрипичных диаграмм для таблиц train_data и test_features

# violinplot(
#    train_data, 'supervisor_evaluation',
#    'Оценка качества работы сотрудника, данная руководителем',
#    'Столбец supervisor_evaluation в тренировочной выборке'
# )

# violinplot(
#    test_features, 'supervisor_evaluation',
#    'Оценка качества работы сотрудника, данная руководителем',
#    'Столбец supervisor_evaluation в тестовой выборке'
# )

# %% [markdown]
# Скрипичные диаграммы являются практически идентичными для обеих выборок. Заметные выпуклые части графика связаны с тем, что значения оценок являются не непрерывными, а дискретными.

# %% [markdown]
# #### `salary`

# %%
# выведем на экран числовое описание данных

print('Числовое описание столбца salary в таблице train_data:')
print(' ')
print(train_data['salary'].describe())
print(' ')

print('Числовое описание столбца salary в таблице test_features:')
print(' ')
print(test_features['salary'].describe())
# Out:
# Числовое описание столбца salary в таблице train_data:
#
# count     4000.000000
# mean     33926.700000
# std      14900.703838
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      98400.000000
# Name: salary, dtype: float64
#
# Числовое описание столбца salary в таблице test_features:
#
# count     2000.000000
# mean     34066.800000
# std      15398.436729
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64

# %% [markdown]
# В среднем, люди в этой компании получают зарплату 33-34 тысячи рублей. Минимальной зарплатой в компании является 12 тысяч рублей, максимальной — 96 тысяч рублей. Можно посмотреть внимательнее, в каком отделе сотрудники получают более высокую зарплату, а также зависит ли от зарплаты удовлетворённость сотрудника — хотя и кажется, что эти факты однозначно коррелируют, вполне может оказаться так, что в компании есть проблема, которая влияет на целевой признак даже несмотря на высокую зарплату сотрудника.

# %%
# построим пару гистограмм для таблиц train_data и test_features

histogram(
    train_data, 'salary',
    'Ежемесячная зарплата сотрудника', 'Столбец salary в тренировочной выборке', 63
)

histogram(
    test_features, 'salary',
    'Ежемесячная зарплата сотрудника', 'Столбец salary в тестовой выборке', 63
)

# %% [markdown]
# Основная масса людей сосредоточена здесь в диапазоне от 12 тысяч рублей до примерно 40 тысяч рублей. Можно предположить, что высокую зарплату получают опытные сеньоры, сотрудники, работающие больше трёх-пяти лет или люди с высоким уровнем загруженности, а их количество относительно остальных сотрудников также является очень небольшим. Помним, что чуть больше половины от общего количества людей составляют джуниоры и сотрудники, проработавшие в компании менее трёх лет.

# %%
# построим пару скрипичных диаграмм для таблиц train_data и test_features

paired_violins(train_data, test_features, 'salary', 'Ежемесячная зарплата сотрудника')

# %%
# построим пару скрипичных диаграмм для таблиц train_data и test_features

# violinplot(
#    train_data, 'salary',
#    'Ежемесячная зарплата сотрудника',
#    'Столбец salary в тренировочной выборке'
# )

# violinplot(
#    test_features, 'salary',
#    'Ежемесячная зарплата сотрудника',
#    'Столбец salary в тестовой выборке'
# )

# %% [markdown]
# Видим, что в тренировочной выборке данные распределяются более плавно. Скорее всего, это связано с бОльшим количеством наблюдений.

# %% [markdown]
# #### `job_satisfaction_rate`

# %%
# выведем на экран числовое описание целевого признака в тренировочной и тестовой выборках

print('Числовое описание столбца job_satisfaction_rate в таблице train_data:')
print(' ')
print(train_data['job_satisfaction_rate'].describe())

print('Числовое описание столбца job_satisfaction_rate в таблице test_target:')
print(' ')
print(test_target['job_satisfaction_rate'].describe())
# Out:
# Числовое описание столбца job_satisfaction_rate в таблице train_data:
#
# count    4000.000000
# mean        0.533995
# std         0.225327
# min         0.030000
# 25%         0.360000
# 50%         0.560000
# 75%         0.710000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64
# Числовое описание столбца job_satisfaction_rate в таблице test_target:
#
# count    2000.00000
# mean        0.54878
# std         0.22011
# min         0.03000
# 25%         0.38000
# 50%         0.58000
# 75%         0.72000
# max         1.00000
# Name: job_satisfaction_rate, dtype: float64

# %%
# построим гистограммы для целевого признака в тренировочной и тестовой выборках

histogram(
    train_data, 'job_satisfaction_rate',
    'Уровень удовлетворённости сотрудника работой в компании',
    'Столбец job_satisfaction_rate в тренировочной выборке', 63
)

histogram(
    test_target, 'job_satisfaction_rate',
    'Уровень удовлетворённости сотрудника работой в компании',
    'Столбец job_satisfaction_rate в тестовой выборке', 63
)

# %%
# построим скрипичные диаграммы для целевого признака в тренировочной и тестовой выборках

violinplot(
    train_data, 'job_satisfaction_rate',
    'Уровень удовлетворённости сотрудника работой в компании',
    'Столбец job_satisfaction_rate в тренировочной выборке'
)

violinplot(
    test_target, 'job_satisfaction_rate',
    'Уровень удовлетворённости сотрудника работой в компании',
    'Столбец job_satisfaction_rate в тестовой выборке'
)

# %% [markdown]
# Видим в данных целевого признака три *горба*: значения, сосредоточенные на отметках в 0.2, 0.4 и 0.7. Очень мало людей, имеющих уровень удовлетворённости выше 0.8, а распределение в столбце не отличаются у тестовой и тренировочной выборок.

# %% [markdown]
# **Каждый из имеющихся признаков исследован более подробно. В данных нет выбросов и аномалий, все они выглядят адекватно и реалистично.**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Отличный EDA признаков - здорово, что сравниваешь `train` и `test` выборку в ходе его проведения, чтобы убедиться, что существенных различий в выборках нет.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Стоит добавить также анализ `job_satisfaction_rate` по `test` выборке - этот признак у нас есть в отдельной переменной.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Добавила в этот пункт describe(), гистограмму и скрипичную диаграмму для целевого признака из тестовых данных
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Учтено.

# %%
# high_satisfaction = train_data[train_data['job_satisfaction_rate'] >= 0.8]
# display(high_satisfaction.info(), high_satisfaction.describe())

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Привет. У меня есть по этому шагу вопрос. Знаю, что исследовательский анализ данных лучше всего делать в разрезе целевого признака. То есть, например, первым шагом внимательно рассмотреть столбец с целевым признаком в обеих выборках, узнать, насколько сильно он различается, далее определить, что является высоким показателем нашего целевого признака, а что низким. Разъединить обе выборки по этому признаку и посмотреть отдельно на данные о тех людях, которые имеют высокую удовлетворённость (сразу будет понятно и какие это люди, с каким опытом, с какой зарплатой, и в каком отделе трудятся, и другие показатели). Но, получается, у нас и так уже есть разделение надвое - думаю, что просто необходимо посмотреть наглядно, как различаются тренировочная и тестовая выборка. Хотя я сейчас я призадумалась, а действительно ли необходимо так уж близко рассматривать именно это? Ведь, по сути, на этапе предобработки уже видно, что с данными поработали (как будто бы), они чистые, с уже приведенными к стандартам столбцами, ну, то есть, подготовленные, что ли. Значит, стоило бы просто мельком проверить, убедиться, что распределения данных совпадают в обеих выборках, так? Что там нет какого-то жуткого различия. Если из такой логики исходить, как это сделать? На каждый признак сравнительно выводить числовые описания? Или оставить те графики, которые я уже построила? Оставить их, вторым шагом взять, допустим, тренировочную выборку (мы же убедились, что распределение данных одинаковое, значит, ничего кардинально не поменяется от тестовой к тренировочной), разделить её в соответствии с целевым признаком и уже посмотреть, какие там особенности. То есть, ещё раз пройтись графиками по всем признакам, и тоже парно их сопоставить, чтоб разницу было видно. Эти рассуждения верны? Можно ли попросить дать развёрнутый комментарий по этому вопросу? Как здесь лучше поступить?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Текущий EDA лучше всего подходит для анализа выборок в случаях, когда целевой признак - непрерывная величина. В целом анализ в разрезе целевого признака - полезный шаг, его можно делать как по `train`, так и по `test`, но только в случае, когда наш целевой признак дискретизирован (для задач бинарной или мультиклассовой классификации).
#
# В текущей выборке альтернатива - сделать какой-то дополнительный признак, основанный на границе целевого признака: `1 if job_satisfaction_rate > x else 0`, но тут нужно хорошенько обосновать границу `x`, чтобы было понятно, почему взято именно такое разделение.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Ещё один вопрос. Про графики. Прошу обратить внимание на все столбчатые диаграммы, которые тут построены (функцией barplot). Сейчас они у меня окрашены в вырвиглазную палитру, а рамка является очень ярко-чёрной. Фон - белый, а не красивый бледно-серый. Меня этот вопрос мучает последние 2 проекта, не считая этого. Я пыталась найти проблему в интернете, почитать внимательно документацию seaborn, в общем, сделать так, чтобы графики были красивые - чтобы у них был красивый фон, мягкая не вырвиглазная палитра (с переливами какими-нибудь), пастельного цвета, например, рамка не чёрная, а серая.
#
# И проблема эта решилась, я сделала upgrade seaborn (в начале проекта), перезапускала ядро и снова воспроизводила ячейку, ну вроде всё как надо делала. Также в саму функцию barplot я добавила аргумент hue и legend=False, в функцию violinplot добавила строку sns.cubehelix_palette(start=.5, rot=-.5, as_cmap=True). И это заработало, графики стали красивые...лишь на время.
#
# Сейчас, после обновления страницы проекта в браузере, всё опять вернулось на круги своя. Я и очищала ядро, заново запускала, всё равно эти вырвиглазные цвета. Ещё бывает такое, что у меня строчки, которые sns.set_palette и подобные просто не дают никакого результата, ну ничего не меняют. Я уже настолько долго с этой проблемой мучаюсь, я просто не понимаю, что я делаю не так, как мне регулировать эти цвета, и чтобы они не менялись, а стабильно одинаково отображались. Можешь ли подсказать, каким кодом я могу построить столбчатую диаграмму, чтобы в ней точно были красивые цвета? Какие функции seaborn мне надо применять? Может, есть какие-то суперполезные ссылки на эту тему, где всё было бы понятно и доступно объяснено? Потому что пока что способы из Интернета, которые я пробовала - не работают.
#
# А, ещё. Я добавляла в функцию barplot параметр palette (при построении самого графика). Сейчас он тоже кажется указан. Нашла два возможных значения этого параметра: 'Paired' и 'Pastel1', второй, конечно, делает график поприятнее, но всё равно это совершенно не то, что нужно. И эти палетки работают по-разному от случая к случаю. Еще читала, что можно сделать как-то кастомную палетку и в ней прописать как бы цвета, которые тебе нужны, но этот способ я не попробовала.
#
# Вообще в целом, есть ли где-то прописанный чёткий алгоритм для построения графика с помощью seaborn? Либо я запуталась, либо правда такое впечатление, что это какой-то хаос из настроек, которые например в столбчатой диаграмме работают, а в другом графике будут не работать, и например эта строчка sns.cubehelix_palette(start=.5, rot=-.5, as_cmap=True) при добавлении в violinplot изменила его цвет, а при добавлении в barplot вообще ничего не сделала, вообщеееее ничего.
#
# upd: я убрала аргумент palette из функции barplot, потому что если он там есть, он изменяет И графики для столбца 'workload'(и иже с ним), И графики по типу как в столбце 'employment_years', это вроде обе столбчатые диаграммы, но отображаются по факту по разному, возможно, из-за количества категорий. БЕЗ аргумента palette первые графики выглядят ужасно, а вторые имеют красивую фиолетово-бежевую палитру, но если я установлю palette='Pastel1', то они будут ВСЕ выглядеть одинаково ужасно. Я очень сильно извиняюсь за такой длинный и душный вопрос, правда прошу прощения.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Первую часть вопроса лучше задать поддержке: если один и тот же код в разное время строит разные графики - это вопрос к функциональности платформы, который смогут решить только они.
#
# Второй вопрос - да, у каждого графика свой набор настроек, в том числе по цвету, поэтому одно и то же решение может или не работать, или приводить к неожиданному результату, для разных графиков. В целом тут я затрудняюсь что-то посоветовать, потому что в своих работах никогда не делаю акцент на визуальной составляющей - рекомендую обратиться за консультацией к преподавателю или наставнику, этот вопрос касается, скорее, части курса, которая посвящена визуализации данных, которая, к сожалению, не моя специализация:)

# %% [markdown]
# ### Корреляционный анализ данных

# %%
# избавимся от столбца id, сделав его индексом

train_data_corr = train_data.set_index('id')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Хорошее решение - перевести `id` в индекс: так мы и не используем признак для анализа корреляции, но сможем к нему обратиться при необходимости.

# %%
# создадим список с наименованиями непрерывных признаков

interval_cols = ['salary', 'job_satisfaction_rate']

# %%
# объединим входные и целевой признаки для тестовых данных

test_data_corr = test_features.merge(test_target, on='id')
test_data_corr = test_data_corr.sort_values(by='id', ascending=True).set_index('id')

# %%
# сравним матрицы корреляции для тренировочной и тестовой выборок

print('Матрица корреляции для тренировочной выборки:')
print(' ')
phik(train_data_corr, interval_cols)
print(' ')
print('Матрица корреляции для тестовой выборки:')
print(' ')
phik(test_data_corr, interval_cols)
# Out:
# Матрица корреляции для тренировочной выборки:
#
# Матрица корреляции для тестовой выборки:

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Есть анализ корреляции - молодец, что используешь `phik` для анализа и нелинейных зависимостей, а также настраиваешь `interval_cols` для корректной оценки корреляции для переменных разного типа.
#
# При использовании `sns.heatmap()` могу порекомендовать сочетание признаков `cmap='coolwarm', center=0, annot=True` - на мой взгляд, очень удачное сочетание цветов палитры, которая позволяет эффективно искать мультиколлинеарность.

# %% [markdown]
# Взаимосвязь между уровнем загруженности сотрудника и его опытностью действительно есть и составляет от 0.42 до 0.47 в зависимости от выборки. Взаимосвязь положительная — это значит, что чем сотрудник опытнее, тем больше у него обязанностей в этой компании. Также уровень опыта сотрудника взаимосвязан с количеством лет его трудоустройства в компании, что абсолютно ожидаемо и логично.
#
# Больше всего целевой признак положительно коррелирует с количеством лет трудоустройства (как было предположено на этапе исследовательского анализа данных), имеющимся повышением, имеющимися нарушениями трудового договора (это неожиданно, ведь предполагалось обратное) и, сильнее всего, с оценкой качества работы, данной руководителем (признаки перечислены по мере возрастания корреляции). Ощутимая положительная корреляция последнего признака с целевым всё же не говорит об однозначной объективности оценки работы сотрудника. Непонятно, повышается ли уровень удовлетворённости от этой оценки, или наоборот — чем выше изначальный уровень удовлетворённости, тем лучше работает сотрудник и, следовательно, его хорошо оценивают.
#
# Уровень зарплаты также ожидаемо высоко коррелирует с опытностью сотрудника, количеством лет, которые он проработал в компании, размером его загруженности и — несильно — с отделом, в котором он работает. Никаких других интересных взаимосвязей с зарплатой не найдено. Можно было бы предположить, что чем выше зарплата, тем выше и целевой признак, но это не так — корреляция в 0.14 - 0.15 говорит о том, что связь очень незначительная.
#
# Признак `dept` не влияет абсолютно ни на один другой признак, кроме зарплаты.
#
# Ни один коэффициент корреляции не является настолько высоким, чтобы говорить о мультиколлинеарности (как правило, о ней говорят при значении коэффициента корреляции от 0.9 до 0.95 по модулю). Значит, можно переходить к следующему шагу.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Анализ данных в порядке - хорошая работа.

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> После удаления `id` нужно проверить наличие новых дубликатов в данных: так как мы удалили часть лишних признаков, у нас могут появиться новые явные дубликаты: чем меньше признаков остаётся, тем выше шанс, что значения остальных признаков будут пересекаться. При этом ценности для модели такие наблюдения уже не принесут, поэтому стоит проверить дубликаты также в финальной версии таблицы.
#
# При этом важно проверить только `train`: наличие дубликатов в `test` нам никак не мешает, но это правильное решение с точки зрения неприкосновенности `test`, ведь реальный поток данных (который имитирует `test` выборка) мы исправить не сможем. А вот наличие дубликатов в `train` не только не принесёт пользы модели, но может и навредить.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправила
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Учтено.

# %%
# тренировочные данные со столбцом id

train_target = train_data['job_satisfaction_rate']
train_features = train_data.drop('job_satisfaction_rate', axis=1)

display(train_data.shape, train_target.shape, train_features.shape, train_features.head())
# Out:
# (4000, 10)
# (4000,)
# (4000, 9)
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      1   24000
# 1                   no                      5   38400
# 2                   no                      2   12000
# 3                   no                      2   18000
# 4                   no                      3   22800

# %%
# тренировочные данные без столбца id

train_data_no_id = train_data.set_index('id')
train_target_no_id = train_data_no_id['job_satisfaction_rate']
train_features_no_id = train_data_no_id.drop('job_satisfaction_rate', axis=1)

display(train_data_no_id.shape, train_target_no_id.shape, train_features_no_id.shape, train_features_no_id.head())
# Out:
# (4000, 9)
# (4000,)
# (4000, 8)
#               dept   level workload  employment_years last_year_promo  \
# id
# 155278       sales  junior   medium                 2              no
# 653870          hr  junior     high                 2              no
# 184592       sales  junior      low                 1              no
# 171431  technology  junior      low                 4              no
# 693419          hr  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary
# id
# 155278                   no                      1   24000
# 653870                   no                      5   38400
# 184592                   no                      2   12000
# 171431                   no                      2   18000
# 693419                   no                      3   22800

# %%
# проверим на наличие дубликатов

display(train_data_no_id.duplicated().sum(), train_target_no_id.duplicated().sum(), train_features_no_id.duplicated().sum())
# Out:
# 245
# 3902
# 1492

# %%
# удалим обнаруженные дубликаты

train_data_no_id = train_data_no_id.drop_duplicates()
train_target_no_id = train_target_no_id.drop_duplicates()
train_features_no_id = train_features_no_id.drop_duplicates()

# %%
# проверим результат

display(train_data_no_id.duplicated().sum(), train_target_no_id.duplicated().sum(), train_features_no_id.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
# тестовые данные со столбцом id

test_data = test_features.merge(test_target, on='id')

display(test_data.shape, test_target.shape, test_features.shape, test_data.head())
# Out:
# (2000, 10)
# (2000, 2)
# (2000, 9)
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      5   28800                   0.79
# 1                   no                      4   30000                   0.72
# 2                   no                      4   19200                   0.64
# 3                   no                      4   19200                   0.60
# 4                   no                      5   40800                   0.75

# %%
# тестовые данные без столбца id

test_data_no_id = test_data.set_index('id')
test_target_no_id = test_data_no_id['job_satisfaction_rate']
test_features_no_id = test_data_no_id.drop('job_satisfaction_rate', axis=1)

display(test_data_no_id.shape, test_target_no_id.shape, test_features_no_id.shape)
# Out:
# (2000, 9)
# (2000,)
# (2000, 8)

# %%
# запишем признаки в переменные в соответствии с выбранным для них методом кодирования

ord_cols = ['level', 'workload']
ohe_cols = ['dept', 'last_year_promo', 'last_year_violations']
num_cols = ['employment_years', 'supervisor_evaluation']

# %%
# OneHotEncoder

ohe_pipe = Pipeline(
    [
        (
            'simpleImputer_ohe',
            SimpleImputer(strategy='most_frequent')
        ),
        (
            'ohe',
            OneHotEncoder(drop='first', handle_unknown='ignore', sparse=False)
        )
    ]
)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> `OneHotEncoder` нужно настроить так, чтобы он обрабатывал новые значения признаков, а не выбрасывал ошибку - при текущей настройке `handle_unknown` в случае возникновения новых значений у признаков, которых не было в `train`, модель будет падать, а для многих случаев важна бесперебойность решений.
#
# Тут и во второй задаче.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Если правильно поняла, речь идет о handle_unknown='error'? Исправила везде на 'use_encoded_value`
#     Вспомнила почему у меня стоит error вообще, так как в коде ниже позже возникла ошибка ValueError: handle_unknown should be one of 'error', 'ignore', 'infrequent_if_exist, из этих всех вариантов я предпочла error и поставила его. Поменяю на ignore снова
#
#     upd: поменяла на ignore, теперь выдаёт такую ошибку: ValueError: handle_unknown should be either 'error' or 'use_encoded_value', got ignore. Возвращаю в ohe_pipe 'error'
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Речь про `ignore`: `use_encoded_value` - это для `OrdinalEncoder`. Ошибка, про которую ты пишешь, исправляется обновлением `sklearn` до последней версии.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправила
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# OrdinalEncoder

ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord',
             SimpleImputer(strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'senior'],
                    ['low', 'medium', 'high'],
                ],
                handle_unknown='use_encoded_value',
                unknown_value=np.nan
            )
        ),
        (
            'simpleImputer_after_ord',
            SimpleImputer(strategy='most_frequent')
        )
    ]
)

# %%
# ColumnTransformer

data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_cols),
        ('ord', ord_pipe, ord_cols),
        ('num', StandardScaler(), num_cols),
    ],
    remainder='passthrough'
)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Здорово, что используешь сочетание `ColumnTransformer` и `Pipeline` для соединения разных инструментов в единый модельный объект и настраиваешь бесперебойную работу энкодера в случае появления в данных новых, неизвестных на момент обучения значений признаков - так твоё решение будет более гибким и масштабируемым.

# %% [markdown]
# Этот пайплайн закодирует категориальные данные с помощью `OneHotEncoder` и `OrdinalEncoder`; если в данных во время или вследствие кодирования возникнут пропуски, они заполнятся самым часто встречающимся значением (модой) с помощью `SimpleImputer`. Третья труба `data_preprocessor` применит `OneHotEncoder`и `OrdinalEncoder` к данным, которые требуют кодирования, а также масштабирует количественные данные с помощью `StandardScaler`.
#
# Итоговый пайплайн для подготовки данных будет назван `pipe_final` и объединит подготовку данных и инициализацию базовой модели — `DecisionTreeRegressor`.

# %%
# объединение шагов в итоговом пайплайне

pipe_final = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', DecisionTreeRegressor(random_state=RANDOM_STATE))
    ]
)

# %% [markdown]
# ### Обучение моделей

# %%
# зададим параметры, которые будут перебираться для поиска лучших значений

param_grid = [
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(1, 20),
        'models__max_features': range(2,50),
        'models__min_samples_leaf': range(1,5),
        'models__min_samples_split': range(3, 20),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    {
        'models': [LinearRegression()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Для линейной регрессии оптимизировать гиперпараметры не совсем корректно: так как её обучение сводится к решению системы линейных уравнений, то настройка гиперпараметров зависит от того, каким образом были подготовлены данные. Обратись, пожалуйста, к документации и выполни настройку гиперпараметров из сетки согласно описанию: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html.
#
# Сами гиперпараметры нужно настроить в момент инициализации модели.
#
# Для проведения кросс-валидации можно просто оставить пустой словарь для линейной регрессии, и для неё будет просто выполнена кросс-валидация - так твоё решение не нужно будет сильно перестраивать. Но сами гиперпараметры нужно задать модели в момент инициализации.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Убрала гиперпараметры у линейной регрессии вообше, оставила как в теории - подбор кодировщика только
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Для обучения и предсказания целевого признака, являющегося непрерывным значением, были выбраны такие модели, как `DecisionTreeRegressor` и `LinearRegression`. Линейная регрессия предполагает линейную зависимость между признаками и целевой переменной, а регрессия на основе деревьев использует комбинацию деревьев решений для предсказания целевой переменной.

# %%
# инициализируем модель подбора гиперпараметров

random_search = RandomizedSearchCV(
    pipe_final,
    param_grid,
    cv=5,
    scoring=make_scorer(smape, greater_is_better=False),
    n_jobs=-1,
    random_state=RANDOM_STATE
    )

# %% [markdown]
# В качестве метрики выбрана SMAPE (Symmetric Mean Absolute Percentage Error). Это метрика, которая измеряет процентную ошибку прогноза для временных рядов или прогнозов в общем, учитывает как недооценку, так и переоценку прогнозов. Чем ближе значение SMAPE к 0, тем лучше.

# %%
# запустим подбор гиперпараметров

random_search.fit(train_features, train_target)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %%
# посмотрим на лучшую модель, её параметры и метрику при кросс-валидации

print('Лучшая модель и ее параметры:\n\n', random_search.best_estimator_)
print('Метрика SMAPE при кросс-валидации:', -random_search.best_score_)
# Out:
# Лучшая модель и ее параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['dept', 'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `RandomizedSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Как видишь, твоя метрика имеет отрицательное значение - это особеность работы `make_scorer` с настроенным параметром `greater_is_better=False`: так как метрика `sMAPE` применяется для задач регрессии, то она тем лучше, чем ниже - это нужно учитывать при создании скорринга для кросс-валидации, так как по умолчанию инструменты подбора гиперпараметров и поиска лучшей модели вроде `GridSearchCV` умеют только максимизировать метрику качества. Поэтому при создании скорринга с помощью `make_scorer` важно настроить параметр `greater_is_better=False`, чтобы оптимизируемая метрика минимизировалась, а не максимизировалась - таким образом задача максимизации будет решаться через задачу минимизации обратной функции.
#
# Поэтому при выводе метрики на экран её стоит сделать положительной: взять по модулю, домножить на `-1` или просто указать `-` при выводе на экран, вроде `print(-a)`.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправила, теперь выводится положительное значение
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# сделаем предсказание на тестовой выборке

pred = random_search.predict(test_features)

# %%
# посчитаем метрику SMAPE на тестовой выборке

print(f'Метрика SMAPE на тестовой выборке: {smape(test_target_no_id, pred)}')
# Out:
# Метрика SMAPE на тестовой выборке: 14.414486094636967

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Лучшую модель оценили на `test` - отличный результат!

# %%
# инициализируем модель DummyRegressor

# dummy_reg = DummyRegressor(strategy='mean')

# %%
# обучим модель DummyRegressor на тренировочных данных

# dummy_reg.fit(train_features, train_target)

# %%
# сделаем предсказание с помощью DummyRegressor для тестовой выборки

# dummy_pred = dummy_reg.predict(test_features)

# %%
# вычислим метрику MSE для результатов работы обеих моделей

# tree_mse = mean_squared_error(test_target_no_id, pred)
# dummy_mse = mean_squared_error(test_target_no_id, dummy_pred)

# %%
# выведем значения метрик на экран

# print("MSE для модели DecisionTreeRegressor:")
# print(tree_mse)

# print("MSE для модели DummyRegressor:")
# print(dummy_mse)

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Ещё один очень важный вопрос, на который очень хочется получить комментарий. От другого студента я получила подсказку о том, что можно инициализировать и обучить модель DummyRegressor, а затем сравнить её метрику с метрикой изначальной модели, чтобы оценить адекватность проделанной работы. DummyRegressor предсказывает средние значения, и если его метрики будут выше метрик нашей модели, это будет значить, что даже эта базовая модель работает лучше, а получившаяся модель DecisionTreeRegressor является бесполезной, как и наша работа. Как смогла, обучила DummyRegressor (нет ли ошибок в обучении/расчёте метрики/совершении предсказаний? Быть может, что-то я не учла?), и вот что у меня получилось:
#
# MSE для модели DecisionTreeRegressor:
# 0.0064018995137212955
#
# MSE для модели DummyRegressor:
# 0.04864260782499999
#
# Получается, у Dummy метрика выше. Что мне делать теперь с этой информацией? Зачем я это сделала, что мне это дало? Что делать в таких случаях? Или это какая-то ошибка? Возможно, не стоило пробовать делать такое самостоятельно, ведь в нашей теории этого ещё не было. А может, я выбрала не ту метрику?
#
# Весь код, относящийся к этой ситуации, выше закомментирован и разделён на ячейки, чтобы был понятен процесс.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Константная модель должна оцениваться по той же метрике, по которой оценивается основная модель. Метрика проекта - `sMAPE`, соответственно по `sMAPE` мы должны оценивать адекватность нашего решения с помощью `DummyRegressor`.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Спасибо большое!!!!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Стоит переделать оценку константной модели.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Итак, лучшей оказалась модель `DecisionTreeRegressor` со следующими параметрами:
#
# - `max_depth`: 13
# - `max_features`: 13
# - `min_samples_leaf`: 3
# - `min_samples_split`: 12
#
# SMAPE этой модели при кросс-валидации составила *15.35*. Эта же метрика на тестовой выборке равна *14.41*. Критерий успеха достигнут, на тестовой выборке SMAPE <= 15.
#
# Успех модели регрессии на основе деревьев решений может обусловлен тем, что в данных содержалось много категориальных значений, а также пропусков. Также сам датасет изначально является небольшим, а признаки имеют сложные нелинейные зависимости, и именно с такой задачей хорошо справляется DecisionTreeRegressor.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хороший вывод по машинному обучению.

# %% [markdown]
# ## Задача 2. Предсказание увольнения сотрудника из компании

# %% [markdown]
# ### Загрузка и предварительное изучение данных

# %% [markdown]
# Для этой задачи заказчик предоставил данные с признаками:
#
# - `id` — уникальный идентификатор сотрудника
# - `dept` — отдел, в котором работает сотрудник
# - `level` — уровень занимаемой должности
# - `workload` — уровень загруженности сотрудника
# - `employment_years` — длительность работы в компании (в годах)
# - `last_year_promo` — показывает, было ли повышение за последний год
# - `last_year_violations` — показывает, нарушал ли сотрудник трудовой договор за последний год
# - `supervisor_evaluation` — оценка качества работы сотрудника, которую дал руководитель
# - `salary` — ежемесячная зарплата сотрудника
# - `quit` — уволился ли сотрудник из компании

# %%
# загрузка данных

try:
    train_quit = pd.read_csv('/datasets/train_quit.csv', sep = ',', decimal='.')
    test_target_quit = pd.read_csv('/datasets/test_target_quit.csv', sep = ',', decimal='.')
except:
    train_quit = pd.read_csv('https://code.s3.yandex.net/datasets/train_quit.csv', sep = ',', decimal='.')
    test_target_quit = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_quit.csv', sep = ',', decimal='.')

# %%
# изучим таблицу train_quit

display(train_quit.head(), train_quit.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# ...

# %%
# изучим таблицу test_target_quit

display(test_target_quit.head(), test_target_quit.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes
# None

# %% [markdown]
# - типы данных в обеих таблицах отображены корректно
# - данные соответствуют описанию
# - пропуски отсутствуют
# - все признаки остались теми же, изменился только целевой

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### `train_quit`

# %%
# применим функцию preprocess

preprocess(train_quit)
# Out:
# Дубликатов найдено: 0
#
#
# Уникальные значения в столбце dept: ['sales' 'purchasing' 'marketing' 'technology' 'hr']
# Уникальные значения в столбце level: ['middle' 'junior' 'sinior']
# Уникальные значения в столбце workload: ['high' 'medium' 'low']
# Уникальные значения в столбце last_year_promo: ['no' 'yes']
# Уникальные значения в столбце last_year_violations: ['no' 'yes']
# Уникальные значения в столбце quit: ['no' 'yes']

# %% [markdown]
# Видим ту же ошибку, что и в `train_data`.

# %%
# заменим ошибку в столбце level

train_quit['level'].replace('sinior', 'senior', inplace=True)

# %%
# проверим результат

train_quit['level'].unique()
# Out:
# array(['middle', 'junior', 'senior'], dtype=object)

# %% [markdown]
# #### `test_target_quit`

# %%
# применим функцию preprocess

preprocess(test_target_quit)
# Out:
# Дубликатов найдено: 0
#
#
# Уникальные значения в столбце quit: ['yes' 'no']

# %% [markdown]
# **Предобработка данных завершена. Дубликатов в данных нет, ошибки в значениях столбца устранены; пробелы, пустые строки и NaN отсутствуют.**

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### `job_satisfaction_rate` — добавление признака

# %%
# сделаем предсказание на тренировочных данных из train_quit с помощью лучшей модели из предыдущего шага

pred_satisfaction_train = random_search.predict(train_quit)

# %%
# добавим в train_quit получившийся новый признак

train_quit['job_satisfaction_rate'] = pred_satisfaction_train

# %%
# оценим результат

display(train_quit.info(), train_quit.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
#  10  job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 343.9+ KB
# None
#        id        dept   level workload  employment_years last_year_promo  \
# ...

# %% [markdown]
# #### `quit`

# %% [markdown]
# В прошлой задаче на этом этапе было рассмотрено, как именно тестовые данные отличаются от тренировочных. И, так как данные (кроме целевого признака) остались прежними, для этой задачи попробуем посмотреть на данные в разрезе целевого признака. Рассматривать на этот раз мы будем тренировочную выборку.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Есть ли какие-то методы, чтобы в такой ситуации "быстро" оценить адекватность разделения данных на выборки? Посмотреть, сопоставляются ли они, принадлежат ли одному источнику? Нужно ли это делать? В этой ситуации всё вроде как очевидно, но ситуации бывают разные, наверное.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Можно оценивать стабильность выборок, чтобы убедиться, что между ними нет существенных различий (делать это нужно, правда, по каждому признаку отдельно). Обычно на практике используются:
#
# - статистические тесты на принадлежность какому-то распределению или просто тесты на равенство выборок;
#
# - показатели стабильности популяции - PCI и CSI (https://habr.com/ru/companies/plarium/articles/515178/).

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Ещё у меня есть небольшое сомнение, правильно ли я делаю, сравнивая попарно эти два сегмента, учитывая что у них разный размер. Не могу это чётко пока сформулировать, но как будто бы иногда именно различие в количестве данных обеих выборок мешает прям адекватно оценить различия
#
# upd: вопрос исчерпан, я догадалась про normalize=True

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Окей, разобрались:) В случае непрерывных признаков также стоит использовать нормированную гистограмму, которая нивелирует разницу в размере выборок.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Спасибо! А как использовать нормированную гистограмму? Я разумеется погуглю, но зачем выбирать один способ, если можно и тут спросить...

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> О нормированной гистограмме писал ниже:)

# %%
# построим столбчатую диаграмму для столбца quit таблицы train_quit

barplot(
    train_quit, 'quit',
    'Уволился ли сотрудник из компании',
    'Столбец quit в таблице train_quit'
)

# %%
# разделим тренировочные данные на две категории по значению целевого признака

train_quit_yes = train_quit.query('quit == "yes"')
train_quit_no = train_quit.query('quit == "no"')

# проверим результат

print('Размер таблицы, содержащей данные об уволившихся сотрудниках:')
print(train_quit_yes.shape)
print('Таблица содержит уникальные значения:')
print(train_quit_yes['quit'].unique())
print(' ')
print('Размер таблицы, содержащей данные о сотрудниках, которые не уволились:')
print(train_quit_no.shape)
print('Таблица содержит уникальные значения:')
print(train_quit_no['quit'].unique())
# Out:
# Размер таблицы, содержащей данные об уволившихся сотрудниках:
# (1128, 11)
# Таблица содержит уникальные значения:
# ['yes']
#
# Размер таблицы, содержащей данные о сотрудниках, которые не уволились:
# (2872, 11)
# Таблица содержит уникальные значения:
# ['no']

# %% [markdown]
# Видим, что относительно имеющихся данных количество уволившихся сотрудников составило 1128 человек или 28% от общего числа.

# %% [markdown]
# #### `job_satisfaction_rate`

# %%
# выведем на экран числовое описание данных

print('Числовое описание столбца job_satisfaction_rate в таблице train_quit_yes:')
print(' ')
print(train_quit_yes['job_satisfaction_rate'].describe())
print(' ')

print('Числовое описание столбца job_satisfaction_rate в таблице train_quit_no:')
print(' ')
print(train_quit_no['job_satisfaction_rate'].describe())
# Out:
# Числовое описание столбца job_satisfaction_rate в таблице train_quit_yes:
#
# count    1128.000000
# mean        0.403479
# std         0.188147
# min         0.060000
# 25%         0.253750
# 50%         0.373333
# 75%         0.529091
# max         0.898889
# Name: job_satisfaction_rate, dtype: float64
#
# Числовое описание столбца job_satisfaction_rate в таблице train_quit_no:
#
# count    2872.000000
# mean        0.591091
# std         0.202348
# min         0.071000
# 25%         0.430577
# 50%         0.647500
# 75%         0.775143
# max         0.964286
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# У уволившихся сотрудников уровень удовлетворённости работой в среднем составил 0.40, а по медиане — 0.37, у оставшихся, в среднем, удовлетворённость оценивается в 0.59, по медиане — 0.64. Среди уволившихся максимальным уровенем удовлетворённости являлось значение в 0.89, среди оставшихся оно равно 0.96.

# %%
# построим пару гистограмм для таблиц train_quit_yes и train_quit_no

histogram(
    train_quit_yes, 'job_satisfaction_rate',
    'Уровень удовлетворённости сотрудника работой в компании', 'Уволившиеся сотрудники', 33
)

histogram(
    train_quit_no, 'job_satisfaction_rate',
    'Уровень удовлетворённости сотрудника работой в компании', 'Сотрудники, которые не уволились', 53
)

# %%
# построим диаграммы размаха, чтобы оценить распределение данных об удовлетворённости работой

paired_boxplot(
    train_quit, 'quit', 'job_satisfaction_rate',
    'Уволился ли сотрудник', 'Уровень удовлетворённости работой',
    'Распределение данных'
)

# %% [markdown]
# И на гистограмме, и на диаграмме размаха отчётливо видно, что в сегменте уволившихся сотрудников основная масса наблюдений находится в диапазоне от 0.2 до 0.6, что значительно ниже, чем у тех людей, которые остались работать в компании.

# %% [markdown]
# #### `dept`

# %%
## выведем на экран числовое распределение данных

print(f'Распределение данных в столбце dept в таблице train_quit_yes:')
print(' ')
print(train_quit_yes['dept'].value_counts(normalize=True))
print(' ')

print(f'Распределение данных в столбце dept в таблице train_quit_no:')
print(' ')
print(train_quit_no['dept'].value_counts(normalize=True))
# Out:
# Распределение данных в столбце dept в таблице train_quit_yes:
#
# dept
# sales         0.360816
# technology    0.244681
# purchasing    0.147163
# marketing     0.144504
# hr            0.102837
# Name: proportion, dtype: float64
#
# Распределение данных в столбце dept в таблице train_quit_no:
#
# dept
# sales         0.358983
# technology    0.227019
# purchasing    0.146936
# marketing     0.145891
# hr            0.121170
# Name: proportion, dtype: float64

# %%
# построим пару столбчатых диаграмм для таблиц train_quit_yes и train_quit_no

paired_barplots(train_quit_yes, train_quit_no, 'dept', 'Отдел, в котором работает сотрудник')

# %% [markdown]
# Отличий в распределении данных не наблюдается. Согласно этим графикам, увольнения ***не*** происходят преимущественно в каком-то определённом отделе компании, хотя увольнений в отделе `technology` немного больше (на 2%).

# %% [markdown]
# #### `level`

# %%
# выведем на экран числовое распределение данных

print(f'Распределение данных в столбце level в таблице train_quit_yes:')
print(' ')
print(train_quit_yes['level'].value_counts(normalize=True))
print(' ')

print(f'Распределение данных в столбце level в таблице train_quit_no:')
print(' ')
print(train_quit_no['level'].value_counts(normalize=True))
# Out:
# Распределение данных в столбце level в таблице train_quit_yes:
#
# level
# junior    0.889184
# middle    0.095745
# senior    0.015071
# Name: proportion, dtype: float64
#
# Распределение данных в столбце level в таблице train_quit_no:
#
# level
# middle    0.552228
# junior    0.329387
# senior    0.118384
# Name: proportion, dtype: float64

# %%
# построим пару столбчатых диаграмм для таблиц train_quit_yes и train_quit_no

paired_barplots(train_quit_yes, train_quit_no, 'level', 'Уровень занимаемой должности')

# %% [markdown]
# Меньше всего увольняются наиболее опытные сотрудники — сеньоры. Миддлы также являются очень стабильной группой сотрудников, а наибольшая текучка происходит среди самых младших сотрудников. Если посмотреть на числовое распределение данных, можно наметить вывод, что, если общее количество джуниоров во всех данных составляет 1949 человек (практически половина всех сотрудников), то увольняются из этого числа около 51%. А если взглянуть на процентность от общего числа всех уволившихся (1128 человек), то джуниоров из них аж 88%! Конечно, это не статистические данные, а подсчёт уволившихся в определённой компании с помощью определённых ограниченных данных, но, тем не менее, это позволяет сделать вывод, что джуниоры являются основной группой риска. Это может быть связано с самыми разными причинами, от разочарования компанией до разочарования профессией в целом.

# %% [markdown]
# #### `workload`

# %%
# выведем на экран числовое распределение данных

print(f'Распределение данных в столбце workload в таблице train_quit_yes:')
print(' ')
print(train_quit_yes['workload'].value_counts(normalize=True))
print(' ')

print(f'Распределение данных в столбце workload в таблице train_quit_no:')
print(' ')
print(train_quit_no['workload'].value_counts(normalize=True))
# Out:
# Распределение данных в столбце workload в таблице train_quit_yes:
#
# workload
# low       0.460106
# medium    0.432624
# high      0.107270
# Name: proportion, dtype: float64
#
# Распределение данных в столбце workload в таблице train_quit_no:
#
# workload
# medium    0.567549
# low       0.239903
# high      0.192549
# Name: proportion, dtype: float64

# %%
# построим пару столбчатых диаграмм для таблиц train_quit_yes и train_quit_no

paired_barplots(train_quit_yes, train_quit_no, 'workload', 'Уровень загруженности сотрудника')

# %% [markdown]
# Среди уволившихся самые частые показатели загруженности — низкий и средний (46% и 43% соответственно). Было бы интересно взглянуть на уровни загруженности по признаку опытности сотрудника, чтобы узнать, в какой группе какой уровень загруженности преобладает больше всего. Такое распределение данных в группе уволившихся можно объяснить тем, что, раз джуниоры увольняются чаще, то и логичнее будет увидеть их уровень загруженности на этих графиках. Если сотрудники со средним уровнем загруженности увольняются почти так же часто, как и с низким, то, возможно, это были именно те джуниоры, которые не смогли выдержать сильной нагрузки/высокого количества обязанностей и ответственности.

# %% [markdown]
# #### `employment_years`

# %%
# выведем на экран числовое описание данных

print('Числовое описание столбца supervisor_evaluation в таблице train_quit_yes:')
print(' ')
print(train_quit_yes['employment_years'].describe())
print(' ')

print('Числовое описание столбца supervisor_evaluation в таблице train_quit_no:')
print(' ')
print(train_quit_no['employment_years'].describe())
# Out:
# Числовое описание столбца supervisor_evaluation в таблице train_quit_yes:
#
# count    1128.000000
# mean        1.844858
# std         1.274920
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        10.000000
# Name: employment_years, dtype: float64
#
# Числовое описание столбца supervisor_evaluation в таблице train_quit_no:
#
# count    2872.000000
# mean        4.430710
# std         2.544635
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64

# %%
# построим пару столбчатых диаграмм для таблиц train_quit_yes и train_quit_no

paired_barplots(
    train_quit_yes, train_quit_no,
    'employment_years', 'Оценка стажа работы сотрудника'
)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Анализ дискретных признаков также нужно выполнить с помощью относительных величин.

# %%
# построим пару столбчатых диаграмм для таблиц train_quit_yes и train_quit_no

barplot(
    train_quit_yes, 'employment_years',
    'Длительность работы в компании, кол-во лет',
    'Уволившиеся сотрудники'
),
barplot(
    train_quit_no, 'employment_years',
    'Длительность работы в компании, кол-во лет',
    'Сотрудники, которые не уволились'
)

# %%
# построим пару скрипичных диаграмм для таблиц train_quit_yes и train_quit_no

violinplot(
    train_quit_yes, 'employment_years',
    'Длительность работы в компании, кол-во лет',
    'Уволившиеся сотрудники'
)

violinplot(
    train_quit_no, 'employment_years',
    'Длительность работы в компании, кол-во лет',
    'Сотрудники, которые не уволились'
)

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Не поняла этот комментарий, что он значит. Здесь сравниваю с помощью показателей из describe(). И точно также выполнен для этого столбца анализ в предыдущей задаче, абсолютно аналогичны образом

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# В этом разделе ты анализируешь портрет уходящего работника, и все признаки, кроме дискретных, ты анализируешь с помощью относительных показателей. А только дискретные - с помощью абсолютных. Поэтому дискретные признаки тоже стоит проанализировать с помощью относительных показателей.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправлено, добавила ниже нормированную гистограмму

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# построим пару нормированных гистограмм для таблиц train_quit_yes и train_quit_no

hist_norm(
    train_quit_yes, 'employment_years',
    'Длительность работы в компании, кол-во лет', 'Уволившиеся сотрудники', 50
)

hist_norm(
    train_quit_no, 'employment_years',
    'Длительность работы в компании, кол-во лет', 'Сотрудники, которые не уволились', 50
)

# %% [markdown]
# Снова находим подтверждение предыдущим выводам: увольняются те сотрудники, которые проработали в компании меньше трёх лет, и подавляющее большинство из них (75% данных, третий квартиль) уволились в течение одного-двух лет после трудоустройства.

# %% [markdown]
# #### `last_year_promo`

# %%
# выведем на экран числовое распределение данных

print(f'Распределение данных в столбце last_year_promo в таблице train_quit_yes:')
print(' ')
print(train_quit_yes['last_year_promo'].value_counts(normalize=True))
print(' ')

print(f'Распределение данных в столбце last_year_promo в таблице train_quit_no:')
print(' ')
print(train_quit_no['last_year_promo'].value_counts(normalize=True))
# Out:
# Распределение данных в столбце last_year_promo в таблице train_quit_yes:
#
# last_year_promo
# no     0.999113
# yes    0.000887
# Name: proportion, dtype: float64
#
# Распределение данных в столбце last_year_promo в таблице train_quit_no:
#
# last_year_promo
# no     0.961003
# yes    0.038997
# Name: proportion, dtype: float64

# %%
# построим пару столбчатых диаграмм для таблиц train_quit_yes и train_quit_no

paired_barplots(train_quit_yes, train_quit_no, 'last_year_promo', 'Было ли повышение за последний год')

# %% [markdown]
# Лишь один человек, получивший повышение за последний год, впоследствии решил уволиться. Влияние повышения на последующее увольнение хоть и не слишком сильное, но то, что оно существует — отрицать нельзя. Так, среди уволившихся повышение ***не*** получили на 3% людей больше, чем среди тех, кто остался.

# %% [markdown]
# #### `last_year_violations`

# %%
# выведем на экран числовое распределение данных

print(f'Распределение данных в столбце last_year_violations в таблице train_quit_yes:')
print(' ')
print(train_quit_yes['last_year_violations'].value_counts(normalize=True))
print(' ')

print(f'Распределение данных в столбце last_year_violations в таблице train_quit_no:')
print(' ')
print(train_quit_no['last_year_violations'].value_counts(normalize=True))
# Out:
# Распределение данных в столбце last_year_violations в таблице train_quit_yes:
#
# last_year_violations
# no     0.797872
# yes    0.202128
# Name: proportion, dtype: float64
#
# Распределение данных в столбце last_year_violations в таблице train_quit_no:
#
# last_year_violations
# no     0.889624
# yes    0.110376
# Name: proportion, dtype: float64

# %%
# построим пару столбчатых диаграмм для таблиц train_quit_yes и train_quit_no

paired_barplots(train_quit_yes, train_quit_no, 'last_year_violations', 'Нарушал ли сотрудник трудовой договор за последний год')

# %% [markdown]
# Среди тех, кто уволился из компании, процент нарушивших трудовой договор меньше примерно на 9%. Неожиданный результат.

# %% [markdown]
# #### `supervisor_evaluation`

# %%
# выведем на экран числовое распределение данных

print('Распределение данных в столбце supervisor_evaluation в таблице train_quit_yes:')
print(' ')
print(train_quit_yes['supervisor_evaluation'].value_counts(normalize=True))
print(' ')

print('Распределение данных в столбце supervisor_evaluation в таблице train_quit_no:')
print(' ')
print(train_quit_no['supervisor_evaluation'].value_counts(normalize=True))
# Out:
# Распределение данных в столбце supervisor_evaluation в таблице train_quit_yes:
#
# supervisor_evaluation
# 3    0.463652
# 4    0.253546
# 2    0.145390
# 1    0.084220
# 5    0.053191
# Name: proportion, dtype: float64
#
# Распределение данных в столбце supervisor_evaluation в таблице train_quit_no:
#
# supervisor_evaluation
# 4    0.476323
# 3    0.247214
# 5    0.160167
# 2    0.079039
# 1    0.037256
# Name: proportion, dtype: float64

# %%
# построим пару столбчатых диаграмм для таблиц train_quit_yes и train_quit_no

paired_barplots(
    train_quit_yes, train_quit_no,
    'supervisor_evaluation', 'Оценка качества работы сотрудника, данная руководителем'
)

# %% [markdown]
# Среди уволившихся преобладают сотрудники, которые получили оценку 3 от руководителя, а среди действующих сотрудников — оценку 4. Меньше всего среди тех, кто уволился — людей, получивших высшую оценку качества работы, а среди оставшихся — получвших 1, что вполне ожидаемо.

# %% [markdown]
# #### `salary`

# %%
# выведем на экран числовое описание данных

print('Числовое описание столбца salary в таблице train_quit_yes:')
print(' ')
print(train_quit_yes['salary'].describe())
print(' ')

print('Числовое описание столбца salary в таблице train_quit_no:')
print(' ')
print(train_quit_no['salary'].describe())
# Out:
# Числовое описание столбца salary в таблице train_quit_yes:
#
# count     1128.000000
# mean     23885.106383
# std       9351.599505
# min      12000.000000
# 25%      16800.000000
# 50%      22800.000000
# 75%      27600.000000
# max      79200.000000
# Name: salary, dtype: float64
#
# Числовое описание столбца salary в таблице train_quit_no:
#
# count     2872.000000
# mean     37702.228412
# std      15218.977339
# min      12000.000000
# 25%      25200.000000
# 50%      34800.000000
# 75%      46800.000000
# max      96000.000000
# Name: salary, dtype: float64

# %% [markdown]
# Средняя зарплата среди уволившихся сотрудников составила 23 тысячи 885 рублей, по медиане — 22 тысячи 800 рублей, а максимальное значение зарплаты не превышает 79 тысяч 200 рублей. 75% данных по правую сторону занимают сотрудники с зарплатой до 27 тысяч 600 рублей.
#
# Среди тех, кто остался, средняя зарплата составляет 37 тысяч 702 рубля, по медиане — 34 тысячи 800 рублей, максимальное значение — 96 тысяч рублей (является максимальным и для всего несегментированного набора данных), а третий квартиль отделяет тех сотрудников, которые зарабатывают 46 тысяч 800 рублей и меньше.

# %%
# построим пару гистограмм для таблиц train_quit_yes и train_quit_no

histogram(
    train_quit_yes, 'salary',
    'Ежемесячная зарплата сотрудника', 'Уволившиеся сотрудники', 33
)

histogram(
    train_quit_no, 'salary',
    'Ежемесячная зарплата сотрудника', 'Сотрудники, которые не уволились', 53
)

# %%
# построим пару скрипичных диаграмм для таблиц train_quit_yes и train_quit_no

paired_violins_quit(train_quit_yes, train_quit_no, 'salary', 'Ежемесячная зарплата сотрудника')

# %%
# построим пару скрипичных диаграмм для таблиц train_quit_yes и train_quit_no

# violinplot(
#    train_quit_yes, 'salary',
#    'Ежемесячная зарплата сотрудника',
#    'Уволившиеся сотрудники'
# )

# violinplot(
#    train_quit_no, 'salary',
#    'Ежемесячная зарплата сотрудника',
#    'Сотрудники, которые не уволились'
# )

# %% [markdown]
# Основное количество данных об уволившихся сотрудниках сосредоточено в диапазоне от минимума до примерно 50 тысяч рублей. То есть, сотрудники, которые получают зарплату выше этой суммы — это, скорее всего, какие-то особые единичные случаи, например, люди, которые нашли место работы получше или ушли из компании по личным причинам. В данных об оставшихся сотрудниках график зарплаты нисходит в правую сторону более плавно.
#
# Всё же, высокие значения зарплаты у уволившихся выбросами считать нельзя. Модель должна учитывать этот опыт в предсказании увольнения сотрудников, даже если человек получает хорошую зарплату.
#
# И, опять же, графики говорят нам о том, что увольняются чаще сотрудники с более низкой зарплатой.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть анализ портрета уходяшего клиента - молодец, что используешь относительные величины для анализа категориальных признаков и сравниваешь средние для непрерывных.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не выполнено `3.3. Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник. Проверьте это утверждение: визуализируйте и сравните распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Используйте данные с обоими целевыми признаками тестовой выборки`. Несколько советов о том, как сделать правильно:
#
# 1. Анализ должен быть выполнен по `test` выборке (см.условие проекта) - для этого по `id` в новую выборку нужно соединить целевые признаки обеих задач.
#
# 2. Здесь мы имеем дело с непрерывной величиной - для анализа её распределения стоит использовать нормированную гистограмму (например, `shs.histplot()` с параметрами `stat='density', common_norm=False` или `sns.kdeplot()`): гистограммы такого типа позволяют нивелировать разницу в размерах выборок при анализе распределений. Обрати также внимание, что при использовании нормированных гистограмм по оси Y будет уже не частота значений, а плотность распределения.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# #### `job_satisfaction_rate` — сравнение по `quit` на тестовой выборке

# %%
# посмотрим на таблицы, которые будем объединять для этой задачи

display(test_target_quit.head(), test_data.head())
# Out:
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      5   28800                   0.79
# 1                   no                      4   30000                   0.72
# 2                   no                      4   19200                   0.64
# 3                   no                      4   19200                   0.60
# ...

# %% [markdown]
# Обе таблицы принадлежат тестовой выборкой, в первой содержится целевой признак второй задачи, а в другой таблице — все входные и целевой признак из первой задачи. Объединим их.

# %%
# объединим данные

test_job_quit = test_data.merge(test_target_quit, on='id')

# проверим результат

test_job_quit.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate  \
# 0                   no                      5   28800                   0.79
# 1                   no                      4   30000                   0.72
# 2                   no                      4   19200                   0.64
# 3                   no                      4   19200                   0.60
# 4                   no                      5   40800                   0.75
#
#   quit
# 0   no
# 1   no
# 2   no
# 3   no
# 4   no

# %%
# разделим тестовые данные на две категории по значению целевого признака текущей задачи

test_job_quit_yes = test_job_quit.query('quit == "yes"')
test_job_quit_no = test_job_quit.query('quit == "no"')

# %%
# построим пару нормированных гистограмм для таблиц test_job_quit_yes и test_job_quit_no

hist_norm(
    test_job_quit_yes, 'job_satisfaction_rate',
    'Удовлетворённость сотрудника работой', 'Уволившиеся сотрудники', 50
)

hist_norm(
    test_job_quit_no, 'job_satisfaction_rate',
    'Удовлетворённость сотрудника работой', 'Сотрудники, которые не уволились', 50
)

# %% [markdown]
# Действительно, удовлетворённость сильно влияет на целевой признак. Среди сотрудников, которые остались в компании, удовлетворённость гораздо выше

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#     Исправлено
# <br>

# %% [markdown]
# ### Корреляционный анализ данных

# %%
# избавимся от столбца id, сделав его индексом

train_quit_corr = train_quit.set_index('id')

# %%
# создадим список с наименованиями непрерывных признаков

interval_cols = ['salary', 'job_satisfaction_rate']

# %%
# построим матрицу корреляции

print(' ')
print('Матрица корреляции для train_quit:')
print(' ')
phik(train_quit_corr, interval_cols)
# Out:
#
# Матрица корреляции для train_quit:

# %% [markdown]
# Видим, что целевой признак имеет некоторую связь с такими признаками, как опытность, количество лет в компании (возможно, такие люди, набравшись опыта, уходят на поиски новых возможностей), оценка работы руководителем, зарплата и удовлетворённость работой. Сильнее всего на увольнение, согласно этой матрице, влияют зарплата, количество проведённых с компанией лет и удовлетворённость сотрудника.
#
# Основные взаимосвязи в данных остались такими же, новых закономерностей между входными признаками тут нет, как и мультиколлинеарности.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что не забыла про корреляционный анализ новой выборки.

# %% [markdown]
# ### Подготовка данных

# %%
# создадим новую переменную test_quit, в которой сохраним тестовые данные с новым целевым признаком

test_quit = test_features.copy()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Делая копию или срез какой-то таблицы, стоит использовать метод `copy()`: используя простое присвивание вида `a=b`, мы в переменную `a` помещаем не новый и самостоятельный объект в памяти, а всего лишь новую ссылку на объект в памяти, на который ссылается `b`. Как итог, внеся изменения в `a`, ты увидишь их и в `b`, и наоборот. Метод `copy()` позволяет создавать именно новые объекты в памяти.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# добавим в test_quit столбец с предсказанными значениями из предыдущей задачи

test_quit['job_satisfaction_rate'] = pred

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В выборки добавили новые признаки на основе предсказаний предыдущей модели.

# %%
# проверим результат

display(test_quit.info(), test_quit.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1997 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               1999 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
#  9   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 156.4+ KB
# None
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# ...

# %%
# упорядочим train_quit по возрастанию id

train_quit = train_quit.sort_values(by='id', ascending=True)

# проверим результат

train_quit.head()
# Out:
#           id        dept   level workload  employment_years last_year_promo  \
# 2600  100222       sales  junior   medium                 3              no
# 717   100459  purchasing  junior   medium                 3              no
# 2455  100469   marketing  junior   medium                 1              no
# 1592  100601  technology  middle     high                 4              no
# 2657  100858       sales  junior   medium                 2              no
#
#      last_year_violations  supervisor_evaluation  salary quit  \
# 2600                   no                      2   20400  yes
# 717                    no                      3   21600  yes
# 2455                   no                      4   28800   no
# 1592                   no                      4   68400   no
# 2657                   no                      4   25200  yes
#
#       job_satisfaction_rate
# 2600               0.323000
# 717                0.311667
# 2455               0.686667
# ...

# %%
# упорядочим test_quit по возрастанию id

test_quit = test_quit.sort_values(by='id', ascending=True)

# проверим результат

test_quit.head()
# Out:
#           id        dept   level workload  employment_years last_year_promo  \
# 1172  100298          hr  junior      low                 2              no
# 852   100480   marketing  junior      low                 4              no
# 848   100503  purchasing  middle     high                 5              no
# 524   100610       sales  middle   medium                 5              no
# 476   100692       sales  middle     high                 6              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# 1172                   no                      4   19200
# 852                    no                      4   16800
# 848                    no                      4   55200
# 524                    no                      4   43200
# 476                    no                      4   48000
#
#       job_satisfaction_rate
# 1172               0.863636
# 852                0.822000
# 848                0.738000
# 524                0.824127
# ...

# %%
# упорядочим test_target_quit по возрастанию id

test_target_quit = test_target_quit.sort_values(by='id', ascending=True)

# проверим результат

test_target_quit.head()
# Out:
#           id quit
# 1566  100298   no
# 491   100480   no
# 802   100503   no
# 725   100610   no
# 319   100692   no

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Без упорядочивания признаков метрика roc-auc была очень плохой
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Верно, порядок наблюдений не всегда обеспечен изначально, наша задача - это проверить. Отмечу, что сортировка - не всегда лучшее решение, так как признаки могут иметь какие-то другие паттерны размещения в таблице. Поэтому лучше всего использовать явные опреации соединения, как в первой задаче.

# %%
# в тренировочных данных сделаем столбец id индексом

train_quit = train_quit.set_index('id')

# проверим результат

train_quit.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100222       sales  junior   medium                 3              no
# 100459  purchasing  junior   medium                 3              no
# 100469   marketing  junior   medium                 1              no
# 100601  technology  middle     high                 4              no
# 100858       sales  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary quit  \
# id
# 100222                   no                      2   20400  yes
# 100459                   no                      3   21600  yes
# 100469                   no                      4   28800   no
# 100601                   no                      4   68400   no
# 100858                   no                      4   25200  yes
#
#         job_satisfaction_rate
# id
# 100222               0.323000
# 100459               0.311667
# 100469               0.686667
# ...

# %%
# проверим тренировочные данные на наличие дубликатов

train_quit.duplicated().sum()
# Out:
# 1053

# %%
# удалим найденные дубликаты

train_quit = train_quit.drop_duplicates()

# проверим результат

train_quit.duplicated().sum()
# Out:
# 0

# %%
# нормально назовём целевой и входные признаки тренировочной и тестовой выборок

X_train = train_quit.drop('quit', axis=1)
y_train = train_quit['quit']

X_test = test_quit.drop('id', axis=1)
y_test = test_target_quit.set_index('id')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В `train` после удаления `id` нужно проверить дубликаты.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# проверим результат

display(X_train.head(), X_train.shape, y_train.head(), y_train.shape, X_test.head(), X_test.shape, y_test.head(), y_test.shape)
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100222       sales  junior   medium                 3              no
# 100459  purchasing  junior   medium                 3              no
# 100469   marketing  junior   medium                 1              no
# 100601  technology  middle     high                 4              no
# 100858       sales  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 100222                   no                      2   20400
# 100459                   no                      3   21600
# 100469                   no                      4   28800
# 100601                   no                      4   68400
# 100858                   no                      4   25200
#
#         job_satisfaction_rate
# id
# 100222               0.323000
# 100459               0.311667
# 100469               0.686667
# 100601               0.662632
# ...

# %%
# запишем признаки в переменные в соответствии с выбранным для них методом кодирования

ord_cols = ['level', 'workload']
ohe_cols = ['dept', 'last_year_promo', 'last_year_violations']
num_cols = ['employment_years', 'supervisor_evaluation', 'salary', 'job_satisfaction_rate']
label_cols = ['quit']

# %%
# закодируем целевой признак с помощью LabelEncoder

label_encoder = LabelEncoder()
encoded_y_train = label_encoder.fit_transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# проверим результат

display(encoded_y_train, encoded_y_test)
# Out:
# C:\Users\User_\AppData\Roaming\Python\Python311\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([1, 1, 0, ..., 1, 0, 0])
# array([0, 0, 0, ..., 1, 0, 1])

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что используешь `LabelEncoder` для кодирования целевого признака.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не закодирован целевой признак в `test`.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# OneHotEncoder

ohe_pipe = Pipeline(
    [
        (
            'simpleImputer_ohe',
            SimpleImputer(strategy='most_frequent')
        ),
        (
            'ohe',
            OneHotEncoder(drop='first', handle_unknown='error', sparse=False)
        )
    ]
)

# %%
# OrdinalEncoder

ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord',
             SimpleImputer(strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'senior'],
                    ['low', 'medium', 'high'],
                ],
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
        (
            'simpleImputer_after_ord',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# %%
# ColumnTransformer

data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_cols),
        ('ord', ord_pipe, ord_cols),
        ('num', StandardScaler(), num_cols)
    ],
    remainder='passthrough'
)

# %%
# объединение шагов в итоговом пайплайне

pipe_final = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
    ]
)

# %% [markdown]
# Этот пайплайн аналогичен тому, что был создан для предыдущей задачи. В качестве базовой модели выбрана `DecisionTreeClassifier`.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> `DecisionTreeRegressor` - модель регрессии, нам нужна модель классификации.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Исправила
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Обучение моделей

# %%
# зададим параметры, которые будут перебираться для поиска лучших значений

param_grid = [
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 15),
        'models__max_features': range(2, 20),
        'models__min_samples_leaf': range(1, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE, solver='liblinear', penalty='l1')],
        'models__C': [0.1, 1, 10],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': [3, 5, 7],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
]

# %% [markdown]
# Для этой задачи были выбраны такие модели, как `DecisionTreeClassifier`, `LogisticRegression` и `KNeighborsClassifier`. Эти модели хорошо справляются с обработкой категориальных признаков и отлично подходят для задач бинарной классификации.

# %%
# инициализируем модель подбора гиперпараметров

random_search = RandomizedSearchCV(
    pipe_final,
    param_grid,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=RANDOM_STATE)

# %%
# запустим подбор гиперпараметров

random_search.fit(X_train, encoded_y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               sparse=False))]),
#                                                                                ['dept',
# ...

# %%
# посмотрим на лучшую модель, её параметры и метрику при кросс-валидации

print('Лучшая модель и ее параметры:\n\n', random_search.best_estimator_)
print(' ')
print('Метрика лучшей модели при кросс-валидации:', random_search.best_score_)
# Out:
# Лучшая модель и ее параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse=False))]),
#                                                   ['dept', 'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Найдена лучшая модель.

# %%
# сделаем предсказание на тестовой выборке

pred_quit = random_search.predict(X_test)

# %%
# оценим ROC-AUC на тестовой выборке

probas = random_search.predict_proba(X_test)
probas_one = probas[:, 1]

print('Площадь ROC-кривой:', roc_auc_score(y_test, probas_one))
# Out:
# Площадь ROC-кривой: 0.9191663456409649

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный результат работы модели.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Аналогично стоит выполнить оценку модели на адеватность - в случае задачи классификации мы можем использовать  `DummyClassifier` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html#sklearn.dummy.DummyClassifier).

# %% [markdown]
# ### Анализ важности признаков

# %%
# Необходимо оценить вклад признаков в работу модели. Для это используем библиотеку SHAP (SHapley Additive exPlanations). Эта библиотека предоставляет способы объяснения работы моделей машинного обучения с помощью теории игр Шепли.

# выполним подготовку тренировочной и тестовой выборок, обратившись к конкретному шагу пайплайна с помощью named_steps()

# X_train_preprocessor = pipe_final.named_steps['preprocessor'].fit_transform(X_train)
# X_test_preprocessor = pipe_final.named_steps['preprocessor'].transform(X_test)

# создадим экземпляр Explainer, обратившись к лучшей по результатам случайного поиска гиперпараметров модели

# explainer = shap.Explainer(random_search.best_estimator_.named_steps['models'], X_train_preprocessor)

# Этот объект будет использоваться для вычисления SHAP-значений. Эти значения — вклад каждого признака в предсказание модели.

# получим названия признаков

# feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()

# преобразуем подготовленную тестовую выборку в таблицу

# X_train_preprocessor = pd.DataFrame(X_test_preprocessor, columns=feature_names)

# рассчитаем значения SHAP

# shap_values = shap.explainer(X_test_preprocessor)

# построим столбчатую диаграмму для значений SHAP

# shap.plots.bar(shap_values)

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Этот код закомментирован, потому что у меня не получилось сделать анализ важности признаков, хотя очень хотелось. Вот этот код  выше падает с ошибкой. Ошибка вот https://postimg.cc/Mfqvr8Sv (это ссылка на файлообменник, там скриншот). Я абсолютно идентичный код использовала в предыдущем проекте, и он работал, всё было отлично и прекрасно. К сожалению, преподаватель в Пачке не смог(не захотел) мне помочь, сказал, что "у меня закомментирована ячейка с установкой модуля shap", но это очевидно не так. Повторюсь, код работал в предыдущем проекте. Пыталась также делать вывод после выполнения каждой ячейки, то есть смотреть, что именно передаётся в переменные, всё ли верно, проверяла несколько раз, вроде как всё верно и в чём причина не понимаю, однокурсники с такой проблемой не сталкивались, поиск в Интернете ещё больше запутал, чат гпт сказал, что нужно проверить что в переменной Inds, и это ещё больеш запутало. Также обращалась к теории курса, и, согласно ей, всё вроде как должно работать. Мне сказали, что этот пункт - анализ важности признаков - в этом проекте необязательный, поэтому оставляю так, смотря в будущее с надеждой, что код-ревьюер всё объяснит и поможет преодолеть эту трудность.
#
# Также ниже в ячейке приведён код, который полностью позаимствован у однокурсницы, я хотела проверить, будет ли такая ошибка - и да, она есть и с таким кодом, значит, дело всё-таки не в нём, а либо в самих переменных (данных) которые я передаю, либо как в прошлом проекте, что-то не так с какой-нибудь версией чего-нибудь, чему нужно сделать !pip и желательно install... Жёсткий дедлайн близится, поэтому отправляю так, чтобы осталось время на исправления ошибок.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В коде выше ошибка в строке `shap_values = shap.explainer(X_test_preprocessor)`, которая неправильно создаёт объект `Explainer`. Ниже - работающий вариант, немного упростил.
#
#     # Необходимо оценить вклад признаков в работу модели. Для это используем библиотеку SHAP (SHapley Additive exPlanations). Эта библиотека предоставляет способы объяснения работы моделей машинного обучения с помощью теории игр Шепли.
#
#     # выполним подготовку тренировочной и тестовой выборок, обратившись к конкретному шагу пайплайна с помощью named_steps()
#
#     X_train_preprocessor = pipe_final.named_steps['preprocessor'].fit_transform(X_train)
#     X_test_preprocessor = pipe_final.named_steps['preprocessor'].transform(X_test)
#
#     # создадим экземпляр Explainer, обратившись к лучшей по результатам случайного поиска гиперпараметров модели
#
#     explainer = shap.Explainer(random_search.best_estimator_.named_steps['models'], X_train_preprocessor)
#
#     shap_values = explainer.shap_values(X_test_preprocessor)
#
#     # построим диаграмму важности признаков
#     shap.summary_plot(shap_values, X_test_preprocessor, feature_names=pipe_final.steps[0][1].get_feature_names_out())

# %%
# X_encoded_1 = random_search.best_estimator_['preprocessor'].fit_transform(X_train)
# model_1 = random_search.best_estimator_['models'].fit(X_encoded_1, y_train)
# explainer_1 = shap.PermutationExplainer(model_1, X_encoded_1)
# labels_1 = random_search.best_estimator_[:-1].get_feature_names_out()
# plt.title('Оценка важности признаков')
# plt.ylabel('Признаки')
# shap.summary_plot(X_encoded_1, plot_type='bar', feature_names=labels_1)

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Этот код у меня отработал без ошибок - возможно, проблема кроется в разных версиях библиотек в окружениях:
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202024-01-12%20%D0%B2%2012.12.18.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202024-01-12%20%D0%B2%2012.12.18.png)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Для этой задачи лучшей оказалась модель `DecisionTreeClassifier` со следующими параметрами:
#
# - `max_depth`: 8
# - `max_features`: 8
# - `min_samples_leaf`: 5
#
# Метрика ROC-AUC показала результат в 0.93 при кросс-валидации и 0.91 на тестовой выборке, и это можно считать очень высоким показателем.
#
# `DecisionTreeClassifier` хорошо показывет себя в случаях со сложными и нелинейными зависимостями в данных.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть вывод по машинному обучению - отлично!

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# ***Задача:*** разработать решение, которое поможет компании избежать финансовых потерь и оттока сотрудников; разработать две модели машинного обучения, одна из которых будет предсказывать удовлетворённость работой сотрудника, а другая — его увольнение из компании.
#
# ***Исходные данные:*** в нашем распоряжении имелись данные, уже разделённые на тренировочную и тестовые выборки. Таблица `test_features` содержала входные признаки тестовой выборки для обеих задач, таблицы `train_job_satisfaction_rate` и `train_quit` содержали тренировочные выборки для каждой задачи соответственно, а `test_target_job_satisfaction_rate` и `test_target_quit` — целевые признаки.
#
# ***Предобработка данных:*** в ходе предобработки были обнаружены и обработаны пустые строки, а другие пропуски было решено обработать с помощью пайплайна. Дубликатов обнаружено не было, типы данных отображены корректно, сами данные реалистичны и соответствуют описанию; были исправлены незначительные ошибки в написании категорий столбца `level` в каждой из выборок.
#
# ***Подбор лучшей модели:*** для поиска лучшей модели в первой задаче были выбраны такие модели, как `LinearRegression` и `DecisionTreeRegressor`, лучшей из них оказалась `DecisionTreeRegressor`, метрика SMAPE у этой модели равна 14.41 на тестовой выборке. Для второй задачи были выбраны `KNeghborsClassifier`, `DecisionTreeClassifier` и `LogisticRegression` и лучше из них снова оказалась модель, основанная на дереве решений — `DecisionTreeClassifier` с метрикой ROC-AUC, равной 0.91 на тестовой выборке.
#
# Были успешно созданы две модели, которые предсказывают увольнение сотрудника и его неудовлетворённость работой. Компании стоит обратить внимание на тех сотрудников, которые трудостроены меньше двух лет и являются самыми неопытными — это своего рода группа риска, которая в качестве сотрудников является не очень надёжной для компании. Возможно, джуниоров может пугать отсутствие карьерного роста, перспективы, возможностей для развития, интересных задач; очень низкая зарплата и слишком высокий уровень загруженности.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть итоговый вывод и рекомендации - отлично!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Александра, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `RandomizedSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец! Здорово, что используешь сочетание `ColumnTransformer` и `Pipeline` для соединения разных инструментов в единый модельный объект и настраиваешь бесперебойную работу энкодера в случае появления в данных новых, неизвестных на момент обучения значений признаков - так твоё решение будет более гибким и масштабируемым.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: итоговый вывод по проекту.
#
# Александра, все замечания учтены - проект принят!
#
# Спасибо за хорошую работу над проектом, желаю успехов в дальнейшем обучении:)
